# %%
import pandas as pd
import numpy as np
import uuid

def get_uid():
    return '{' + str(uuid.uuid4()).upper() + '}'

def make_city_dict(_df):
    city_list = list(_df[['city_ascii', 'lng', 'lat']].to_records(index=False))
    city_dict = {}
    for val in city_list:
        if val[0] not in city_dict:
            city_dict[val[0]] = []
        city_dict[val[0]].append((val[1], val[2]))
    return city_dict

def coord_equal(row, cds):
    return np.abs(row.Longitude - cds[0]) + np.abs(row.Latitude - cds[1]) < 0.06

def in_city_set(row, _city_dict):
    if row.AccentCity not in _city_dict: 
        return False
    else:
        for cds in _city_dict[row.AccentCity]:
            if coord_equal(row, cds): return True
        return False
    
def output_xml(_df, name):
    lines = ['<?xml version="1.0" encoding="utf-8"?>\n', 
             '<FSData version="9.0">\n']   
            
    _df = _df.sort_values('city_ascii')
    _df['xml'] = _df.apply(lambda x: f'<LandmarkLocation instanceId="{get_uid()}" type="City" name="{x.city_ascii}" lat="{x.lat}" lon="{x.lng}" alt="{x.elevation*3.0}" offset="0.0000" />\n', axis=1)
    
    lines += _df['xml'].values.tolist() + ['</FSData>']
    with open(name, "w", encoding="utf-8") as f:
        f.writelines(lines)
    print(f"OK, written {len(lines)} lines")

# %%
df1 = pd.read_csv("worldcities.csv").sort_values("city_ascii")
df1 = df1[['city_ascii', 'lat', 'lng']]
df1['elevation'] = 0.0
df1.head()
# Out:
#              city_ascii      lat      lng  elevation
# 13574            'Araba  32.8511  35.3386        0.0
# 3659   's-Hertogenbosch  51.6833   5.3167        0.0
# 1695           A Coruna  43.3713  -8.4188        0.0
# 2313             Aachen  50.7762   6.0838        0.0
# 3852            Aalborg  57.0337   9.9166        0.0

# %%
df2 = pd.read_csv("worldcitiespop1.csv", encoding="utf-8")
df2['Latitude'] = df2['Latitude'].apply(lambda x: np.round(x, 4))
df2['Longitude'] = df2['Longitude'].apply(lambda x: np.round(x, 4))
df2.head()
# Out:
#    Unnamed: 0      AccentCity  Latitude  Longitude
# 0      855176        A Coruna   43.3666    -8.4068
# 1     2295214  A dos Cunhados   39.1524    -9.2972
# 2      792982        Aabenraa   55.0362     9.4180
# 3      792989         Aabybro   57.1500     9.7500
# 4      722416          Aachen   50.7708     6.1053

# %%
city_dict = make_city_dict(df1)
len(city_dict)
# Out:
# 23893

# %%
l = []

for i, row in df2.iterrows():
    if not in_city_set(row, city_dict):
        l.append({
            "city_ascii": row.AccentCity,
            "lat": row.Latitude,
            "lng": row.Longitude
        })
        
df3 = df1.append(l)
len(df3)
# Out:
# 60034

# %%
df3 = df3.sort_values('city_ascii')
df3.head(5)
# Out:
#              city_ascii      lat      lng
# 13574            'Araba  32.8511  35.3386
# 3659   's-Hertogenbosch  51.6833   5.3167
# 33372                 A  63.9667  10.2167
# 33373                 A  63.9667  10.2000
# 1695           A Coruna  43.3713  -8.4188

# %%
df3 = df3.append({'city_ascii': 'Zheleznodorozhnyy', 'lat': 37.9927, 'lng': 55.7482}, ignore_index=True).sort_values('city_ascii')
len(df3)
# Out:
# 60035

# %%
df3.to_csv("cities3.csv", index=False)

# %% [markdown]
# #### Начинаем сразу с cities3.csv

# %%
df3 = pd.read_csv('cities3.csv')
df3.head()
# Out:
#          city_ascii      lat      lng
# 0            'Araba  32.8511  35.3386
# 1  's-Hertogenbosch  51.6833   5.3167
# 2                 A  63.9667  10.2167
# 3                 A  63.9667  10.2000
# 4          A Coruna  43.3713  -8.4188

# %% [markdown]
# #### Что делать с двумя миллионами других

# %%
df4 = pd.read_csv("worldcitiespop.csv")
df4 = df4[(df4['Population'].isna()) & ((df4['Country'] == 'fr') | (df4['Country'] == 'it'))]
print(len(df4))
# Out:
# C:\bin\anaconda\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# 84987

# %%
df5 = df4.groupby(['Longitude','Latitude']).agg({'AccentCity': lambda x: list(x)[0]}).reset_index()
df5['AccentCity'] = df5['AccentCity'].apply(lambda x: x.strip())
df5['Latitude'] = df5['Latitude'].apply(lambda x: np.round(x, 4))
df5['Longitude'] = df5['Longitude'].apply(lambda x: np.round(x, 4))
df5 = df5.sort_values('AccentCity')
print(len(df5))
df5.head()

# %%
city_dict = make_city_dict(df3)
len(city_dict)
# Out:
# 52727

# %%
l = []

for i, row in df5.iterrows():
    if not in_city_set(row, city_dict):
        l.append({
            "city_ascii": row.AccentCity,
            "lat": row.Latitude,
            "lng": row.Longitude
        })
        
df7 = pd.DataFrame(l)
len(df7)
# Out:
# 69198

# %%
output_xml(df7, "cities_fr_it.xml")
# Out:
# OK, written 69201 lines

# %% [markdown]
# #### Geonames

# %%
gn = pd.read_csv("cities1000.tsv", sep="\t", header=None)
gn.columns = ["geonameid", "name", "city_ascii", "alternatenames", "lat", "lng", "f1", "f2", "f3", "f4", "f5", "f6", "f7", "f8", "population", "elevation", "f11", "f12", "f13"]
gn = gn[['city_ascii', 'lat', 'lng', 'population', 'elevation']]\
    .append({'city_ascii': 'Zheleznodorozhnyy', 'lat': 37.9927, 'lng': 55.7482}, ignore_index=True).sort_values('city_ascii')
gn['elevation'] = gn['elevation'].fillna(0.0)
gn['lat'] = gn['lat'].apply(lambda x: np.round(x, 4))
gn['lng'] = gn['lng'].apply(lambda x: np.round(x, 4))
gn.head(10)

# %%
gn1 = gn.groupby(['lat', 'lng']).agg({'city_ascii': lambda x: list(x)}).reset_index()
gn1
# Out:
#             lat       lng         city_ascii
# 0      -77.8460  166.6760  [McMurdo Station]
# 1      -54.9336  -67.6096  [Puerto Williams]
# 2      -54.8108  -68.3159          [Ushuaia]
# 3      -54.5108  -67.1955          [Tolhuin]
# 4      -54.2811  -36.5092        [Grytviken]
# ...         ...       ...                ...
# 137478  71.9635  114.0920        [Saskylakh]
# 137479  71.9800  102.4711         [Khatanga]
# 137480  72.7872  -56.1444        [Upernavik]
# 137481  73.5082   80.5292           [Dikson]
# 137482  78.2233   15.6469     [Longyearbyen]
#
# [137483 rows x 3 columns]

# %%
sorted(gn1['city_ascii'].values, key=lambda x: -len(x))
# Out:
# [['Koani', 'Koani Ndogo'],
#  ['Nkoaranga', 'Poli'],
#  ['Prachamtakham', 'Prachantakham'],
#  ['Pa Kham', 'Pakham'],
#  ['San Antonio de la Cuesta', 'San Jeronimo'],
#  ['Benchalak', 'Siao'],
#  ['Pueblo Nuevo', 'San Nicolas'],
#  ['Pimienta Vieja', 'Potrerillos'],
#  ['Mojiman', 'Nueva Esperanza'],
#  ['La Huesa', 'Monterrey'],
#  ['El Rancho', 'Quebrada Seca'],
#  ['Khuean Ubonrat', 'Ubonratana'],
#  ['Sam Chai', 'Samran'],
#  ['Suwanna Khuha', 'Suwannakhuha'],
#  ['Lap Lae', 'Laplae'],
#  ['Phon Phisai', 'Phonphisai'],
#  ['Santa Clara', 'Sumidero'],
#  ['San Carlos', 'Villa Consuelo'],
#  ['Cristo Rey', 'La Agustina'],
#  ['Choshi', 'Hasaki'],
#  ['Faja de Baixo', 'Rosto de Cao'],
#  ['Almisera', 'Llocnou de Sant Jeroni'],
#  ['Benirredra', 'Gandia'],
#  ['Alcantera de Xuquer', 'Beneixida'],
#  ['Montalvinho', 'Montalvo'],
#  ['Albalat dels Sorells', 'Foios'],
#  ['Benifairo de les Valls', 'Quart de les Valls'],
#  ['Furano', 'Shimo-furano'],
#  ['Kastel Novi', 'Kastel Stafilic'],
#  ['Greater Napanee', 'Napanee'],
#  ['Batarasti', 'Glavile'],
#  ['Albestii Pamanteni', 'Albestii de Arges'],
#  ['Pardosi', 'Racoviteni'],
#  ['Grunji', 'Manzalesti'],
#  ['Beresti', 'Beresti-Sat'],
#  ['Landskron', 'Sankt Magdalen'],
#  ['Barcanesti', 'Candesti'],
#  ['Dagata', 'Poienile'],
#  ['Bartholomaeberg', 'Tschagguns'],
#  ['Sinesti', 'Stornesti'],
#  ['Loruens', 'Stallehr'],
#  ['Mieming', 'Obermieming'],
#  ['Oberhofen im Inntal', 'Pfaffenhofen'],
#  ['Rapanasu', 'Tarlisua'],
#  ['Flamanzi', 'Storesti'],
#  ['Dzuunmod', 'Zuunmod'],
#  ['Seekirchen am Wallersee', 'Seewalchen'],
#  ['Tarsolt', 'Tarsoltel'],
#  ['Lemwerder', 'Vegesack'],
#  ["Bol'shaya Setun'", "Setun'"],
#  ['Aby', 'Jursla'],
#  ['McMurdo Station'],
#  ['Puerto Williams'],
#  ['Ushuaia'],
#  ['Tolhuin'],
#  ['Grytviken'],
#  ['Rio Grande'],
#  ['Cameron'],
#  ['Porvenir'],
#  ['Punta Arenas'],
#  ['Puerto Natales'],
#  ['Stanley'],
#  ['Rio Gallegos'],
#  ['28 de Noviembre'],
#  ['Yacimiento Rio Turbio'],
#  ['Rio Turbio'],
#  ['El Calafate'],
#  ['Puerto Santa Cruz'],
#  ['Comandante Luis Piedra Buena'],
#  ['Port-aux-Francais'],
#  ['San Julian'],
#  ['Gobernador Gregores'],
#  ['Puerto Deseado'],
#  ['Cochrane'],
#  ['Pico Truncado'],
#  ['Bluff'],
#  ['Perito Moreno'],
#  ['Papatowai'],
#  ['Los Antiguos'],
#  ['Las Heras'],
#  ['Chile Chico'],
#  ['Caleta Olivia'],
#  ['Invercargill'],
#  ['Riverton'],
#  ['Balclutha'],
#  ['Winton'],
#  ['Milton'],
#  ['Gore'],
#  ['Rada Tilly'],
#  ['Dunedin'],
#  ['Comodoro Rivadavia'],
#  ['Portobello'],
#  ['Rio Mayo'],
#  ['Sarmiento'],
#  ['Coyhaique'],
#  ['Puerto Chacabuco'],
#  ['Te Anau'],
#  ['Puerto Aysen'],
#  ['Kingston'],
#  ['Oamaru'],
#  ['Alto Rio Senguer'],
#  ['Cromwell'],
#  ['Queenstown'],
#  ['Arrowtown'],
#  ['Camarones'],
#  ['Puerto Cisnes'],
#  ['Wanaka'],
#  ['Timaru'],
#  ['Pleasant Point'],
#  ['Rio Pico'],
#  ['Geraldine'],
#  ['Jose de San Martin'],
#  ['Gobernador Costa'],
#  ['La Junta'],
#  ['Waitangi'],
#  ['Tinwald'],
#  ['Ashburton'],
#  ['Paso de Indios'],
#  ['Leeston'],
#  ['Rakaia'],
#  ['Las Plumas'],
#  ['Lincoln'],
#  ['Methven'],
#  ['Palena'],
#  ['Burnham'],
#  ['Rolleston'],
#  ['Prebbleton'],
#  ['Christchurch'],
#  ['Tecka'],
#  ['Darfield'],
#  ['Kaiapoi'],
#  ['Woodend'],
#  ['Pegasus'],
#  ['Dolavon'],
#  ['Rangiora'],
#  ['Rawson'],
#  ['Oxford'],
#  ['Gaiman'],
#  ['Trelew'],
#  ['Futaleufu'],
#  ['Geeveston'],
#  ['Amberley'],
#  ['Cygnet'],
#  ['Quellon'],
#  ['Franklin'],
#  ['Trevelin'],
#  ['Snug'],
#  ['Huonville'],
#  ['Margate'],
#  ['Ranelagh'],
#  ['Blackmans Bay'],
#  ['Kingston Beach'],
#  ['Kingston'],
#  ['Taroona'],
#  ['Sandford'],
#  ['Tranmere'],
#  ['Mount Nelson'],
#  ['Chaiten'],
#  ['Lauderdale'],
#  ['Esquel'],
#  ['Dynnyrne'],
#  ['Oakdowns'],
#  ['Rokeby'],
#  ['South Hobart'],
#  ['Sandy Bay'],
#  ['Battery Point'],
#  ['Clarendon Vale'],
#  ['Howrah'],
#  ['Hobart city centre'],
#  ['Hobart'],
#  ['Acton Park'],
#  ['West Hobart'],
#  ['Bellerive'],
#  ['North Hobart'],
#  ['Mount Stuart'],
#  ['Lenah Valley'],
#  ['Mornington'],
#  ['Seven Mile Beach'],
#  ['New Town'],
#  ['Warrane'],
#  ['Dodges Ferry'],
#  ['West Moonah'],
#  ['Lindisfarne'],
#  ['Moonah'],
#  ['Lutana'],
#  ['Glenorchy'],
#  ['Cambridge'],
#  ['Geilston Bay'],
#  ['Montrose'],
#  ['Goodwood'],
#  ['Rosetta'],
#  ['Berriedale'],
#  ['Risdon Vale'],
#  ['Chigwell'],
#  ['Midway Point'],
#  ['Claremont'],
#  ['New Norfolk'],
#  ['Sorell'],
#  ['Old Beach'],
#  ['Puerto Madryn'],
#  ['Austins Ferry'],
#  ['Granton'],
#  ['Herdsmans Cove'],
#  ['Gagebrook'],
#  ['Bridgewater'],
#  ['Richmond'],
#  ['Hokitika'],
#  ['Brighton'],
#  ['Bagdad'],
#  ['Chonchi'],
#  ['Castro'],
#  ['Greymouth'],
#  ['Telsen'],
#  ['Leleque'],
#  ['Dalcahue'],
#  ['Gastre'],
#  ['Queenstown'],
#  ['Hoyo de Epuyen'],
#  ['Lago Puelo'],
#  ['El Maiten'],
#  ['El Bolson'],
#  ['Ancud'],
#  ['Norquinco'],
#  ['Calbuco'],
#  ['Westport'],
#  ['Cressy'],
#  ['Sierra Grande'],
#  ['Longford'],
#  ['Perth'],
#  ['Evandale'],
#  ['Westbury'],
#  ['Deloraine'],
#  ['Blenheim'],
#  ['Hadspen'],
#  ['Youngtown'],
#  ['Prospect Vale'],
#  ['Kings Meadows'],
#  ['Puerto Montt'],
#  ['Summerhill'],
#  ['Blackstone Heights'],
#  ['Norwood'],
#  ['Saint Leonards'],
#  ['South Launceston'],
#  ['West Launceston'],
#  ['Trevallyn'],
#  ['Newstead'],
#  ['Launceston'],
#  ['East Launceston'],
#  ['Waverley'],
#  ['Launceston city centre'],
#  ['Riverside'],
#  ['Invermay'],
#  ['Ravenswood'],
#  ['Waipawa'],
#  ['Mowbray'],
#  ['Wakefield'],
#  ['Sheffield'],
#  ['Newnham'],
#  ['Mayfield'],
#  ['Brightwater'],
#  ['Rocherlea'],
#  ['Legana'],
#  ['Richmond'],
#  ['Ingeniero Jacobacci'],
#  ['St Helens'],
#  ['Puerto Varas'],
#  ['Brooklyn'],
#  ['Picton'],
#  ['Wellington'],
#  ['Kelburn'],
#  ['Nelson'],
#  ['Mapua'],
#  ['Maquinchao'],
#  ['Latrobe'],
#  ['Khandallah'],
#  ['Spreyton'],
#  ['Petone'],
#  ['Lower Hutt'],
#  ['La Ensenada'],
#  ['Beaconsfield'],
#  ['Miandetta'],
#  ['East Devonport'],
#  ['Devonport'],
#  ['Port Sorell'],
#  ['Beauty Point'],
#  ['Turners Beach'],
#  ['Ulverstone'],
#  ['Scottsdale'],
#  ['Shearwater'],
#  ['West Ulverstone'],
#  ['San Carlos de Bariloche'],
#  ['Upper Hutt'],
#  ['Motueka'],
#  ['Porirua'],
#  ['Pilcaniyeu'],
#  ['Penguin'],
#  ['George Town'],
#  ['Romaine'],
#  ['Upper Burnie'],
#  ['Shorewell Park'],
#  ['Hillcrest'],
#  ['Montello'],
#  ['Burnie'],
#  ['Park Grove'],
#  ['Somerset'],
#  ['Comallo'],
#  ['Bridport'],
#  ['Wynyard'],
#  ['Masterton'],
#  ['Paraparaumu'],
#  ['Purranque'],
#  ['Castlepoint'],
#  ['Takaka'],
#  ['Smithton'],
#  ['Los Menucos'],
#  ['Viedma'],
#  ['Carmen de Patagones'],
#  ['Villa La Angostura'],
#  ['Otaki'],
#  ['San Antonio Oeste'],
#  ['Valcheta'],
#  ['Puyehue'],
#  ['Levin'],
#  ['Sierra Colorada'],
#  ['Osorno'],
#  ['Foxton'],
#  ['Linton Military Camp'],
#  ['Palmerston North'],
#  ['Rio Bueno'],
#  ['La Union'],
#  ['Bulls'],
#  ['San Martin de los Andes'],
#  ['General Conesa'],
#  ['Piedra del Aguila'],
#  ['Junin de los Andes'],
#  ['Whanganui'],
#  ['Currie'],
#  ['El Cuy'],
#  ['Corral'],
#  ['Las Gaviotas'],
#  ['Valdivia'],
#  ['Las Animas'],
#  ['Patea'],
#  ['Panguipulli'],
#  ['Hastings'],
#  ['Hawera'],
#  ['Las Coloradas'],
#  ['Taradale'],
#  ['Picun Leufu'],
#  ['Napier'],
#  ['Waiouru'],
#  ['Opunake'],
#  ['Eltham'],
#  ['Lamarque'],
#  ['Loncoche'],
#  ['Fray Luis Beltran'],
#  ['Choele Choel'],
#  ['Villarrica'],
#  ['Pucon'],
#  ['Alumine'],
#  ['Darwin'],
#  ['Coronel Belisle'],
#  ['Chimpay'],
#  ['Chichinales'],
#  ['Villa Regina'],
#  ['General Enrique Godoy'],
#  ['Ingeniero Luis A. Huergo'],
#  ['Mainque'],
#  ['New Plymouth'],
#  ['Cervantes'],
#  ['General Roca'],
#  ['Wairoa'],
#  ['Senillosa'],
#  ['Waitara'],
#  ['Rio Colorado'],
#  ['Turangi'],
#  ['Pitrufquen'],
#  ['La Adela'],
#  ['Monte Hermoso'],
#  ['Allen'],
#  ['Plottier'],
#  ['General Fernandez Oro'],
#  ['Freire'],
#  ['Neuquen'],
#  ['Cutral-Co'],
#  ['Cipolletti'],
#  ['Plaza Huincul'],
#  ['Zapala'],
#  ['Punta Alta'],
#  ['Centenario'],
#  ['Medanos'],
#  ['Cinco Saltos'],
#  ['Apollo Bay'],
#  ['Mariano Moreno'],
#  ['Vista Alegre'],
#  ['Nueva Imperial'],
#  ['Temuco'],
#  ['Contraalmirante Cordero'],
#  ['Bahia Blanca'],
#  ['Coronel Dorrego'],
#  ['Carahue'],
#  ['Taupo'],
#  ['Vilcun'],
#  ['Gisborne'],
#  ['Foster'],
#  ['Inverloch'],
#  ['Wonthaggi'],
#  ['North Wonthaggi'],
#  ['Yarram'],
#  ['Necochea'],
#  ['Cape Woolamai'],
#  ['Lorne'],
#  ['Lautaro'],
#  ['San Remo'],
#  ['Las Lajas'],
#  ['Timboon'],
#  ['Phillip Island'],
#  ['Leongatha'],
#  ['Murupara'],
#  ['Cowes'],
#  ['Korumburra'],
#  ['Saint Andrews Beach'],
#  ['Anglesea'],
#  ['Mirboo North'],
#  ['Allansford'],
#  ['Port Fairy'],
#  ['Rye'],
#  ['Warrnambool'],
#  ['Somers'],
#  ['Tootgarook'],
#  ['Tres Arroyos'],
#  ['Elliminyt'],
#  ['Balnarring'],
#  ['Hmas Cerberus'],
#  ['Rosebud West'],
#  ['Blairgowrie'],
#  ['Rosebud'],
#  ['Dennington'],
#  ['Anelo'],
#  ['Crib Point'],
#  ['McCrae'],
#  ['San Cayetano'],
#  ['Portland'],
#  ['Jan Juc'],
#  ['Sorrento'],
#  ['Colac'],
#  ['Dromana'],
#  ['Nyora'],
#  ['Cuchillo Co'],
#  ['Bittern'],
#  ['Torquay'],
#  ['Cobden'],
#  ['Safety Beach'],
#  ['Churchill'],
#  ['Hastings'],
#  ['Koroit'],
#  ['Point Lonsdale'],
#  ['Barwon Heads'],
#  ['Miramar'],
#  ['Queenscliff'],
#  ['Hazelwood North'],
#  ['Mount Martha'],
#  ['Lang Lang'],
#  ['Ocean Grove'],
#  ['Tyabb'],
#  ['Traiguen'],
#  ['Winchelsea'],
#  ['Mount Duneed'],
#  ['Terang'],
#  ['Morwell'],
#  ['Camperdown'],
#  ['Tokoroa'],
#  ['Victoria'],
#  ['Armstrong Creek'],
#  ['Wallington'],
#  ['Mornington'],
#  ['Waurn Ponds'],
#  ['Moorooduc'],
#  ['Somerville'],
#  ['Tooradin'],
#  ['Blind Bight'],
#  ['Trafalgar'],
#  ['Yarragon'],
#  ['Pearcedale'],
#  ['Grovedale'],
#  ['Baxter'],
#  ['Koo-Wee-Rup'],
#  ['Traralgon'],
#  ['Leopold'],
#  ['Langwarrin South'],
#  ['St Albans Park'],
#  ['Moolap'],
#  ['Mount Eliza'],
#  ['Otorohanga'],
#  ['Whittington'],
#  ['Moe'],
#  ['Wandana Heights'],
#  ['Belmont'],
#  ['Drysdale'],
#  ['Newborough'],
#  ['Highton'],
#  ['Saint Leonards'],
#  ['Thomson'],
#  ['Langwarrin'],
#  ['Devon Meadows'],
#  ['Newcomb'],
#  ['Frankston South'],
#  ['Longford'],
#  ['Yallourn North'],
#  ['Warragul'],
#  ['Clifton Springs'],
#  ['Loberia'],
#  ['East Geelong'],
#  ['Rosedale'],
#  ['Newtown'],
#  ['Geelong city centre'],
#  ['Geelong'],
#  ['Puelches'],
#  ['Frankston'],
#  ['Indented Head'],
#  ['Botanic Ridge'],
#  ['Geelong West'],
#  ['Rotorua'],
#  ['Manifold Heights'],
#  ['Drouin'],
#  ['Junction Village'],
#  ['Cranbourne South'],
#  ['Herne Hill'],
#  ['Frankston East'],
#  ['Clyde'],
#  ['Heywood'],
#  ['Frankston North'],
#  ['Hamlyn Heights'],
#  ['Clyde North'],
#  ['Glengarry'],
#  ['Wurruk'],
#  ['Portarlington'],
#  ['Cranbourne East'],
#  ['Cranbourne'],
#  ['Longwarry'],
#  ['Sale'],
#  ['North Geelong'],
#  ['Bell Park'],
#  ['Skye'],
#  ['Inverleigh'],
#  ['Norlane'],
#  ['Tornquist'],
#  ['Seaford'],
#  ['Kawerau'],
#  ['Carrum Downs'],
#  ['Bunyip'],
#  ['Cranbourne West'],
#  ['Bell Post Hill'],
#  ['Garfield'],
#  ['Jacinto Arauz'],
#  ['Corio'],
#  ['Carrum'],
#  ['Mortlake'],
#  ['Sandhurst'],
#  ['Cranbourne North'],
#  ['Loncopue'],
#  ['Pakenham'],
#  ['Patterson Lakes'],
#  ['Lovely Banks'],
#  ['Bonbeach'],
#  ['Officer'],
#  ['Lynbrook'],
#  ['Chelsea'],
#  ['Beaconsfield'],
#  ['Bannockburn'],
#  ['Narre Warren South'],
#  ['Edithvale'],
#  ['Teesdale'],
#  ['Chelsea Heights'],
#  ['Hampton Park'],
#  ['Narre Warren'],
#  ['Berwick'],
#  ['Aspendale'],
#  ['Lara'],
#  ['Aspendale Gardens'],
#  ['Neerim South'],
#  ['Hallam'],
#  ['Pakenham Upper'],
#  ['Waterways'],
#  ['Opotiki'],
#  ['Mar del Plata'],
#  ['Mordialloc'],
#  ['Eumemmerring'],
#  ['Beaconsfield Upper'],
#  ['Doveton'],
#  ['Parkdale'],
#  ['Keysborough'],
#  ['Beaumaris'],
#  ['Mentone'],
#  ['Dandenong'],
#  ['Narre Warren North'],
#  ['Edgecumbe'],
#  ['Coronel Pringles'],
#  ['Dingley Village'],
#  ['Heyfield'],
#  ['General San Martin'],
#  ['Endeavour Hills'],
#  ['Black Rock'],
#  ['Maffra'],
#  ['Cheltenham'],
#  ['Little River'],
#  ['Heatherton'],
#  ['Springvale South'],
#  ['Noble Park'],
#  ['Dandenong North'],
#  ['Stratford'],
#  ['Whakatane'],
#  ['Collipulli'],
#  ['Gembrook'],
#  ['Sandringham'],
#  ['Hampton'],
#  ['Highett'],
#  ['Noble Park North'],
#  ['Springvale'],
#  ['Werribee South'],
#  ['Moorabbin'],
#  ['Clarinda'],
#  ['Hampton East'],
#  ['Cockatoo'],
#  ['Clayton South'],
#  ['Rowville'],
#  ['Lysterfield'],
#  ['Belgrave South'],
#  ['Emerald'],
#  ['Mulgrave'],
#  ['Belgrave Heights'],
#  ['Oakleigh South'],
#  ['Bentleigh East'],
#  ['Paynesville'],
#  ['Bentleigh'],
#  ['McKinnon'],
#  ['Clayton'],
#  ['Selby'],
#  ['Point Cook'],
#  ['Belgrave'],
#  ['Huntingdale'],
#  ['North Brighton'],
#  ['Brighton'],
#  ['Notting Hill'],
#  ['Bernasconi'],
#  ['Tecoma'],
#  ['Brighton East'],
#  ['Werribee'],
#  ['Ormond'],
#  ['Murrumbeena'],
#  ['Hughesdale'],
#  ['Oakleigh East'],
#  ['Wheelers Hill'],
#  ['Scoresby'],
#  ['Upwey'],
#  ['Eagle Point'],
#  ['Kallista'],
#  ['Oakleigh'],
#  ['Caulfield South'],
#  ['Carnegie'],
#  ['Glen Huntly'],
#  ['The Patch'],
#  ['Metung'],
#  ['Wyndham Vale'],
#  ['Knoxfield'],
#  ['Chadstone'],
#  ['Elsternwick'],
#  ['Ferntree Gully'],
#  ['Altona Meadows'],
#  ['Ripponlea'],
#  ['Wantirna South'],
#  ['Ferny Creek'],
#  ['Hoppers Crossing'],
#  ['Caulfield'],
#  ['Elwood'],
#  ['Caulfield East'],
#  ['Seabrook'],
#  ['Catriel'],
#  ['Cambridge'],
#  ['Glen Waverley'],
#  ['Mount Waverley'],
#  ['Monbulk'],
#  ['Malvern East'],
#  ['Caulfield North'],
#  ['Kalimna'],
#  ['Altona'],
#  ['Saint Kilda'],
#  ['Lakes Entrance'],
#  ['Balaclava'],
#  ['Glen Iris'],
#  ['Ashburton'],
#  ['Boronia'],
#  ['Sassafras'],
#  ['Ashwood'],
#  ['St Kilda East'],
#  ['Seaholme'],
#  ['Moorak'],
#  ['Williamstown'],
#  ['Malvern'],
#  ['Laverton'],
#  ['Williams Landing'],
#  ['St Kilda West'],
#  ['Vermont South'],
#  ['Armadale'],
#  ['Williamstown North'],
#  ['Windsor'],
#  ['Middle Park'],
#  ['Prahran'],
#  ['Burwood East'],
#  ['Wantirna'],
#  ['Bayswater'],
#  ['The Basin'],
#  ['Olinda'],
#  ['Burwood'],
#  ['Balcarce'],
#  ['Newport'],
#  ['Briagolong'],
#  ['Camberwell'],
#  ['Toorak'],
#  ['Albert Park'],
#  ['Blackburn South'],
#  ['Port Melbourne'],
#  ['South Yarra'],
#  ['Tarneit'],
#  ['Vermont'],
#  ['Altona North'],
#  ['East Bairnsdale'],
#  ['South Melbourne'],
#  ['Glenferrie'],
#  ['Forest Hill'],
#  ['Heathmont'],
#  ['Mount Dandenong'],
#  ['Hawthorn South'],
#  ['Box Hill South'],
#  ['Mount Gambier'],
#  ['Cremorne'],
#  ['South Kingsville'],
#  ['Spotswood'],
#  ['Bayswater North'],
#  ['Hawthorn East'],
#  ['Canterbury'],
#  ['Bairnsdale'],
#  ['Southbank'],
#  ['Nunawading'],
#  ['Kilsyth South'],
#  ['Hawthorn'],
#  ['Blackburn'],
#  ['Box Hill'],
#  ['Richmond'],
#  ['Mont Albert'],
#  ['Truganina'],
#  ['Yarraville'],
#  ['East Melbourne'],
#  ['Surrey Hills'],
#  ['Mitcham'],
#  ['Ringwood'],
#  ['Ringwood East'],
#  ['Montrose'],
#  ['Kalorama'],
#  ['Silvan'],
#  ['Lucknow'],
#  ['Nicholson'],
#  ['Brooklyn'],
#  ['Melbourne City Centre'],
#  ['Docklands'],
#  ['Melbourne'],
#  ['Croydon South'],
#  ['Matamata'],
#  ['West Melbourne'],
#  ['Blackburn North'],
#  ['Balwyn'],
#  ['Kingsville'],
#  ['Kew'],
#  ['Seddon'],
#  ['Box Hill North'],
#  ['Collingwood'],
#  ['Canete'],
#  ['Eynesbury'],
#  ['Mont Albert North'],
#  ['Footscray'],
#  ['Carlton'],
#  ['Abbotsford'],
#  ['Ringwood North'],
#  ['Croydon'],
#  ['Kilsyth'],
#  ['Wy Yung'],
#  ['Raglan'],
#  ['Fitzroy'],
#  ['North Melbourne'],
#  ['Clifton Hill'],
#  ['Seville'],
#  ['Kew East'],
#  ['West Footscray'],
#  ['Angol'],
#  ['Derrimut'],
#  ['Kensington'],
#  ['Sunshine West'],
#  ['Balwyn North'],
#  ['Donvale'],
#  ['Fitzroy North'],
#  ['Doncaster'],
#  ['Flemington'],
#  ['Carlton North'],
#  ['Doncaster East'],
#  ['Braybrook'],
#  ['Sunshine'],
#  ['Parkville'],
#  ['Alphington'],
#  ['Mount Evelyn'],
#  ['Wandin North'],
#  ['Hamilton'],
#  ['Mooroolbark'],
#  ['Yarra Junction'],
#  ['Princes Hill'],
#  ['Travancore'],
#  ['Woori Yallock'],
#  ['Launching Place'],
#  ['Maidstone'],
#  ['Albion'],
#  ['Ascot Vale'],
#  ['Fairfield'],
#  ['Park Orchards'],
#  ['Croydon Hills'],
#  ['Ardeer'],
#  ['Warranwood'],
#  ['Veinticinco de Mayo'],
#  ['Ivanhoe East'],
#  ['Brunswick East'],
#  ['Maribyrnong'],
#  ['Sunshine North'],
#  ['Ivanhoe'],
#  ['Croydon North'],
#  ['Deer Park'],
#  ['Moonee Ponds'],
#  ['Brunswick'],
#  ['Northcote'],
#  ['Bulleen'],
#  ['Templestowe Lower'],
#  ['Wesburn'],
#  ['Maketu'],
#  ['Ravenhall'],
#  ['Brunswick West'],
#  ['Eaglemont'],
#  ['Avondale Heights'],
#  ['Aberfeldie'],
#  ['Cairnlea'],
#  ['Thornbury'],
#  ['Millgrove'],
#  ['Essendon West'],
#  ['Templestowe'],
#  ['Warburton'],
#  ['Bellfield'],
#  ['Coburg'],
#  ['Preston'],
#  ['Heidelberg'],
#  ['Warrandyte'],
#  ['Lilydale'],
#  ['Essendon'],
#  ['Burnside'],
#  ['Albanvale'],
#  ['St Albans'],
#  ['Hamilton'],
#  ['Heidelberg Heights'],
#  ['Essendon North'],
#  ['Caroline Springs'],
#  ['Viewbank'],
#  ['Pascoe Vale South'],
#  ['Heidelberg West'],
#  ['Rosanna'],
#  ['Chirnside Park'],
#  ['Niddrie'],
#  ['Kealba'],
#  ['Strathmore'],
#  ['Kings Park'],
#  ['Rockbank'],
#  ['Saint Albans'],
#  ['Pascoe Vale'],
#  ['Macleod'],
#  ['Lower Plenty'],
#  ['Eltham'],
#  ['Wonga Park'],
#  ['Keilor East'],
#  ['North Warrandyte'],
#  ['Coburg North'],
#  ['Burnside Heights'],
#  ['Yallambie'],
#  ['Coldstream'],
#  ['Airport West'],
#  ['Keilor Downs'],
#  ['Keilor Park'],
#  ['Delahey'],
#  ['Mulchen'],
#  ['Oak Park'],
#  ['Keilor'],
#  ['Fawkner'],
#  ['Reservoir'],
#  ['Watsonia'],
#  ['Montmorency'],
#  ['Kingsbury'],
#  ['Taylors Hill'],
#  ['Gowanbrae'],
#  ['Melton South'],
#  ['Hadfield'],
#  ['Briar Hill'],
#  ['Greensborough'],
#  ['Tullamarine'],
#  ['Brookfield'],
#  ['Sydenham'],
#  ['Keilor Lodge'],
#  ['Glenroy'],
#  ['Saint Helena'],
#  ['Eltham North'],
#  ['Research'],
#  ['Badger Creek'],
#  ['Watsonia North'],
#  ['Taylors Lakes'],
#  ['Bundoora'],
#  ['Orbost'],
#  ['Hillside'],
#  ['St Helena'],
#  ['Kangaroo Ground'],
#  ['Jacana'],
#  ['Gladstone Park'],
#  ['Plumpton'],
#  ['Tauranga'],
#  ['Maddingley'],
#  ['Melton'],
#  ['Thomastown'],
#  ['Broadmeadows'],
#  ['Melton West'],
#  ['Westmeadows'],
#  ['Kurunjang'],
#  ['Bacchus Marsh'],
#  ['Benito Juarez'],
#  ['Dallas'],
#  ['Attwood'],
#  ['Guatrache'],
#  ['Ngaruawahia'],
#  ['Lalor'],
#  ['Mill Park'],
#  ['Plenty'],
#  ['Diamond Creek'],
#  ['Wattleglen'],
#  ['Campbellfield'],
#  ['Darley'],
#  ['Yarra Glen'],
#  ['Coolaroo'],
#  ['Healesville'],
#  ['Meadow Heights'],
#  ['Buninyong'],
#  ['Ross Creek'],
#  ['Epping'],
#  ['South Morang'],
#  ['El Huecu'],
#  ['Smythesdale'],
#  ['Hurstbridge'],
#  ['Panton Hill'],
#  ['Yarrambat'],
#  ['Greenvale'],
#  ['Diggers Rest'],
#  ['Roxburgh Park'],
#  ['Mount Helen'],
#  ['Lebu'],
#  ['Piguee'],
#  ['Saint Andrews'],
#  ['Mernda'],
#  ['Haddon'],
#  ['Smythes Creek'],
#  ['Mount Clear'],
#  ['Craigieburn'],
#  ['Doreen'],
#  ['Ballan'],
#  ['Millicent'],
#  ['Delacombe'],
#  ['Sebastopol'],
#  ['Casterton'],
#  ['Mount Pleasant'],
#  ['Wollert'],
#  ['Gordon'],
#  ['Sunbury'],
#  ['Redan'],
#  ['Canadian'],
#  ['Golden Point'],
#  ['Alfredton'],
#  ['Ballarat East'],
#  ['Ballarat'],
#  ['Ballarat Central'],
#  ['Mallacoota'],
#  ['Newington'],
#  ['Black Hill'],
#  ['Katikati'],
#  ['Lake Wendouree'],
#  ['Soldiers Hill'],
#  ['Brown Hill'],
#  ['Lake Gardens'],
#  ['Puan'],
#  ['Laprida'],
#  ['Ballarat North'],
#  ['Mickleham'],
#  ['Kinglake'],
#  ...]

# %%
output_xml(gn[:70000], "geo_cities1.xml")
# Out:
# OK, written 70003 lines

# %%
output_xml(gn[70000:], "geo_cities2.xml")
# Out:
# OK, written 67537 lines

# %%
output_xml(df1, "cities1.xml")
# Out:
# OK, written 26572 lines
