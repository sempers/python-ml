# %% [markdown]
# # Predict tags on StackOverflow with linear models

# %% [markdown]
# In this assignment you will learn how to predict tags for posts from [StackOverflow](https://stackoverflow.com). To solve this task you will use multilabel classification approach.
#
# ### Libraries
#
# In this task you will need the following libraries:
# - [Numpy](http://www.numpy.org) — a package for scientific computing.
# - [Pandas](https://pandas.pydata.org) — a library providing high-performance, easy-to-use data structures and data analysis tools for the Python
# - [scikit-learn](http://scikit-learn.org/stable/index.html) — a tool for data mining and data analysis.
# - [NLTK](http://www.nltk.org) — a platform to work with natural language.

# %% [markdown]
# ### Data
#
# The following cell will download all data required for this assignment into the folder `week1/data`.

# %%
try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False

if IN_COLAB:
    ! wget https://raw.githubusercontent.com/hse-aml/natural-language-processing/master/setup_google_colab.py -O setup_google_colab.py
    import setup_google_colab
    setup_google_colab.setup_week1() 
    
import sys
sys.path.append("..")
from common.download_utils import download_week1_resources

download_week1_resources()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=7196138.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2166270.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1041379.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=5091.0), HTML(value='')))

# %% [markdown]
# ### Grading
# We will create a grader instance below and use it to collect your answers. Note that these outputs will be stored locally inside grader and will be uploaded to platform only after running submitting function in the last part of this assignment. If you want to make partial submission, you can run that cell any time you want.

# %%
from grader import Grader

# %%
grader = Grader()

# %% [markdown]
# ### Text preprocessing

# %% [markdown]
# For this and most of the following assignments you will need to use a list of stop words. It can be downloaded from *nltk*:

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rookie\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# In this task you will deal with a dataset of post titles from StackOverflow. You are provided a split to 3 sets: *train*, *validation* and *test*. All corpora (except for *test*) contain titles of the posts and corresponding tags (100 tags are available). The *test* set is provided for Coursera's grading and doesn't contain answers. Upload the corpora using *pandas* and look at the data:

# %%
from ast import literal_eval
import pandas as pd
import numpy as np

# %%
def read_data(filename):
    data = pd.read_csv(filename, sep='\t')
    data['tags'] = data['tags'].apply(literal_eval)
    return data

# %%
train = read_data('data/train.tsv')
validation = read_data('data/validation.tsv')
test = pd.read_csv('data/test.tsv', sep='\t')

# %%
train.head()
# Out:
#                                                title                  tags
# 0                How to draw a stacked dotplot in R?                   [r]
# 1  mysql select all records where a datetime fiel...          [php, mysql]
# 2             How to terminate windows phone 8.1 app                  [c#]
# 3  get current time in a specific country via jquery  [javascript, jquery]
# 4                      Configuring Tomcat to Use SSL                [java]

# %% [markdown]
# As you can see, *title* column contains titles of the posts and *tags* column contains the tags. It could be noticed that a number of tags for a post is not fixed and could be as many as necessary.

# %% [markdown]
# For a more comfortable usage, initialize *X_train*, *X_val*, *X_test*, *y_train*, *y_val*.

# %%
X_train, y_train = train['title'].values, train['tags'].values
X_val, y_val = validation['title'].values, validation['tags'].values
X_test = test['title'].values

# %% [markdown]
# One of the most known difficulties when working with natural data is that it's unstructured. For example, if you use it "as is" and extract tokens just by splitting the titles by whitespaces, you will see that there are many "weird" tokens like *3.5?*, *"Flip*, etc. To prevent the problems, it's usually useful to prepare the data somehow. In this task you'll write a function, which will be also used in the other assignments.
#
# **Task 1 (TextPrepare).** Implement the function *text_prepare* following the instructions. After that, run the function *test_text_prepare* to test it on tiny cases and submit it to Coursera.

# %%
import re

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))

def text_prepare(text):
    """
        text: a string
        
        return: modified initial string
    """
    text = text.lower() # lowercase text
    text = REPLACE_BY_SPACE_RE.sub('', text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = BAD_SYMBOLS_RE.sub('', text) # delete symbols which are in BAD_SYMBOLS_RE from text
    #text = # delete stopwords from text
    for stopword in list(STOPWORDS):
        text = re.sub(r'\b' + stopword + r'\b', '', text)
    text = re.sub(r' +', ' ', text)
    return text.strip()

# %%
def test_text_prepare():
    examples = ["SQL Server - any equivalent of Excel's CHOOSE function?",
                "How to free c++ memory vector<int> * arr?"]
    answers = ["sql server equivalent excels choose function", 
               "free c++ memory vectorint arr"]
    for ex, ans in zip(examples, answers):
        if text_prepare(ex) != ans:
            return "Wrong answer for the case: '%s', the answer passed as '%s'" % (ex, text_prepare(ex))
    return 'Basic tests are passed.'

# %%
print(test_text_prepare())
# Out:
# Basic tests are passed.

# %% [markdown]
# Run your implementation for questions from file *text_prepare_tests.tsv* to earn the points.

# %%
prepared_questions = []
for line in open('data/text_prepare_tests.tsv', encoding='utf-8'):
    line = text_prepare(line.strip())
    prepared_questions.append(line)
text_prepare_results = '\n'.join(prepared_questions)

grader.submit_tag('TextPrepare', text_prepare_results)
# Out:
# Current answer for task TextPrepare is:
#  sqlitephp readonly
# creating multiple textboxes dynamically
# self one prefer javascript
# save php date ...

# %% [markdown]
# Now we can preprocess the titles using function *text_prepare* and  making sure that the headers don't have bad symbols:

# %%
X_train = [text_prepare(x) for x in X_train]
X_val = [text_prepare(x) for x in X_val]
X_test = [text_prepare(x) for x in X_test]

# %%
X_train[:3]
# Out:
# ['draw stacked dotplot r',
#  'mysql select records datetime field less specified value',
#  'terminate windows phone 81 app']

# %% [markdown]
# For each tag and for each word calculate how many times they occur in the train corpus.
#
# **Task 2 (WordsTagsCount).** Find 3 most popular tags and 3 most popular words in the train data and submit the results to earn the points.

# %%
from collections import Counter

# Dictionary of all tags from train corpus with their counts.
tags_counts = {}
# Dictionary of all words from train corpus with their counts.
words_counts = {}


######################################
######### YOUR CODE HERE #############
######################################
tags_counter = Counter()
words_counter = Counter()

for x in X_train:
    words_counter.update(x.split(' '))

for y in y_train:
    tags_counter.update(y)

words_counts = dict(words_counter.most_common())
tags_counts = dict(tags_counter.most_common())

words_most_common, tags_most_common
# Out:
# ([('using', 8274), ('php', 5422), ('java', 5397)],
#  [('javascript', 19078), ('c#', 19077), ('java', 18661)])

# %%
tags_counts
# Out:
# {'javascript': 19078,
#  'c#': 19077,
#  'java': 18661,
#  'php': 13907,
#  'python': 8940,
#  'jquery': 7510,
#  'c++': 6469,
#  'html': 4668,
#  'objective-c': 4338,
#  'asp.net': 3939,
#  '.net': 3872,
#  'ruby-on-rails': 3344,
#  'ios': 3256,
#  'c': 3119,
#  'mysql': 3092,
#  'android': 2818,
#  'ruby': 2326,
#  'arrays': 2277,
#  'json': 2026,
#  'vb.net': 1918,
#  'iphone': 1909,
#  'django': 1835,
#  'css': 1769,
#  'ajax': 1767,
#  'r': 1727,
#  'string': 1573,
#  'winforms': 1468,
#  'swift': 1465,
#  'regex': 1442,
#  'angularjs': 1353,
#  'xml': 1347,
#  'spring': 1346,
#  'wpf': 1289,
#  'sql': 1272,
#  'asp.net-mvc': 1244,
#  'multithreading': 1118,
#  'eclipse': 992,
#  'linq': 964,
#  'xcode': 900,
#  'forms': 872,
#  'html5': 842,
#  'windows': 838,
#  'hibernate': 807,
#  'linux': 793,
#  'codeigniter': 786,
#  'node.js': 771,
#  'swing': 759,
#  'database': 740,
#  'list': 693,
#  'ruby-on-rails-3': 692,
#  'jsp': 680,
#  'image': 672,
#  'entity-framework': 649,
#  'web-services': 633,
#  'spring-mvc': 618,
#  'visual-studio-2010': 588,
#  'sql-server': 585,
#  'file': 582,
#  'sockets': 579,
#  'visual-studio': 574,
#  'date': 560,
#  'validation': 558,
#  'datetime': 557,
#  'laravel': 525,
#  'performance': 512,
#  'class': 509,
#  'facebook': 508,
#  'cocoa-touch': 507,
#  'numpy': 502,
#  'twitter-bootstrap': 501,
#  'servlets': 498,
#  'osx': 490,
#  'function': 487,
#  'pandas': 479,
#  'wordpress': 478,
#  'uitableview': 460,
#  'rest': 456,
#  'qt': 451,
#  'unit-testing': 449,
#  'excel': 443,
#  'apache': 441,
#  'xaml': 438,
#  'csv': 435,
#  'maven': 432,
#  'selenium': 431,
#  'oop': 425,
#  'python-2.7': 421,
#  'generics': 420,
#  'algorithm': 419,
#  'session': 415,
#  'google-maps': 408,
#  'parsing': 403,
#  'opencv': 401,
#  'dom': 400,
#  'wcf': 389,
#  'loops': 389,
#  'python-3.x': 379,
#  'sorting': 375,
#  'mongodb': 350,
#  'pointers': 350}

# %% [markdown]
# We are assuming that *tags_counts* and *words_counts* are dictionaries like `{'some_word_or_tag': frequency}`. After applying the sorting procedure, results will be look like this: `[('most_popular_word_or_tag', frequency), ('less_popular_word_or_tag', frequency), ...]`. The grader gets the results in the following format (two comma-separated strings with line break):
#
#     tag1,tag2,tag3
#     word1,word2,word3
#
# Pay attention that in this assignment you should not submit frequencies or some additional information.

# %%
most_common_tags = sorted(tags_counts.items(), key=lambda x: x[1], reverse=True)[:3]
most_common_words = sorted(words_counts.items(), key=lambda x: x[1], reverse=True)[:3]

grader.submit_tag('WordsTagsCount', '%s\n%s' % (','.join(tag for tag, _ in most_common_tags), 
                                                ','.join(word for word, _ in most_common_words)))
# Out:
# Current answer for task WordsTagsCount is:
#  javascript,c#,java
# using,php,java...

# %% [markdown]
# ### Transforming text to a vector
#
# Machine Learning algorithms work with numeric data and we cannot use the provided text data "as is". There are many ways to transform text data to numeric vectors. In this task you will try to use two of them.
#
# #### Bag of words
#
# One of the well-known approaches is a *bag-of-words* representation. To create this transformation, follow the steps:
# 1. Find *N* most popular words in train corpus and numerate them. Now we have a dictionary of the most popular words.
# 2. For each title in the corpora create a zero vector with the dimension equals to *N*.
# 3. For each text in the corpora iterate over words which are in the dictionary and increase by 1 the corresponding coordinate.
#
# Let's try to do it for a toy example. Imagine that we have *N* = 4 and the list of the most popular words is
#
#     ['hi', 'you', 'me', 'are']
#
# Then we need to numerate them, for example, like this:
#
#     {'hi': 0, 'you': 1, 'me': 2, 'are': 3}
#
# And we have the text, which we want to transform to the vector:
#
#     'hi how are you'
#
# For this text we create a corresponding zero vector
#
#     [0, 0, 0, 0]
#
# And iterate over all words, and if the word is in the dictionary, we increase the value of the corresponding position in the vector:
#
#     'hi':  [1, 0, 0, 0]
#     'how': [1, 0, 0, 0] # word 'how' is not in our dictionary
#     'are': [1, 0, 0, 1]
#     'you': [1, 1, 0, 1]
#
# The resulting vector will be
#
#     [1, 1, 0, 1]
#
# Implement the described encoding in the function *my_bag_of_words* with the size of the dictionary equals to 5000. To find the most common words use train data. You can test your code using the function *test_my_bag_of_words*.

# %%
DICT_SIZE = 5000
INDEX_TO_WORDS = [x[0] for x in sorted(words_counts.items(), key=lambda x: x[1], reverse=True)][:DICT_SIZE]
WORDS_TO_INDEX = {word: INDEX_TO_WORDS.index(word) for word in INDEX_TO_WORDS}

ALL_WORDS = WORDS_TO_INDEX.keys()

def my_bag_of_words(text, words_to_index, dict_size):
    """
        text: a string
        dict_size: size of the dictionary
        
        return a vector which is a bag-of-words representation of 'text'
    """
    result_vector = np.zeros(dict_size)
    ######################################
    ######### YOUR CODE HERE #############
    ######################################
    tokens = text.split(' ')
    for token in tokens:
        if token in words_to_index:
            result_vector[words_to_index[token]] = 1.
    return result_vector

# %%
WORDS_TO_INDEX
# Out:
# {'using': 0,
#  'php': 1,
#  'java': 2,
#  'file': 3,
#  'javascript': 4,
#  'error': 5,
#  'get': 6,
#  'c#': 7,
#  'python': 8,
#  'string': 9,
#  'array': 10,
#  'data': 11,
#  'value': 12,
#  'jquery': 13,
#  'function': 14,
#  'object': 15,
#  'class': 16,
#  'use': 17,
#  'c++': 18,
#  'method': 19,
#  'list': 20,
#  'multiple': 21,
#  'text': 22,
#  'page': 23,
#  'image': 24,
#  'form': 25,
#  'rails': 26,
#  'create': 27,
#  'type': 28,
#  'code': 29,
#  'html': 30,
#  'working': 31,
#  'database': 32,
#  'set': 33,
#  'add': 34,
#  'convert': 35,
#  'json': 36,
#  'variable': 37,
#  'values': 38,
#  'server': 39,
#  'android': 40,
#  'mysql': 41,
#  'aspnet': 42,
#  'way': 43,
#  'application': 44,
#  'change': 45,
#  'c': 46,
#  'button': 47,
#  'find': 48,
#  'without': 49,
#  'one': 50,
#  'django': 51,
#  'windows': 52,
#  'cannot': 53,
#  'table': 54,
#  'call': 55,
#  'files': 56,
#  'check': 57,
#  'ajax': 58,
#  'time': 59,
#  'two': 60,
#  'getting': 61,
#  'name': 62,
#  'ruby': 63,
#  'make': 64,
#  'web': 65,
#  'another': 66,
#  'app': 67,
#  'user': 68,
#  'xml': 69,
#  'input': 70,
#  'element': 71,
#  'custom': 72,
#  'date': 73,
#  'event': 74,
#  'api': 75,
#  'access': 76,
#  'url': 77,
#  'number': 78,
#  'spring': 79,
#  'sql': 80,
#  'view': 81,
#  'mvc': 82,
#  'return': 83,
#  'google': 84,
#  'query': 85,
#  'select': 86,
#  'inside': 87,
#  'exception': 88,
#  'column': 89,
#  'loop': 90,
#  'display': 91,
#  'swift': 92,
#  'work': 93,
#  'new': 94,
#  'remove': 95,
#  'load': 96,
#  'read': 97,
#  'r': 98,
#  'objects': 99,
#  'property': 100,
#  'cant': 101,
#  'line': 102,
#  'pass': 103,
#  'click': 104,
#  'vs': 105,
#  'framework': 106,
#  'script': 107,
#  'update': 108,
#  'creating': 109,
#  'post': 110,
#  'request': 111,
#  'different': 112,
#  'null': 113,
#  'field': 114,
#  'run': 115,
#  'doesnt': 116,
#  '2': 117,
#  'net': 118,
#  'row': 119,
#  'key': 120,
#  'ios': 121,
#  'service': 122,
#  'linq': 123,
#  'div': 124,
#  'project': 125,
#  'open': 126,
#  'best': 127,
#  'format': 128,
#  'wpf': 129,
#  'window': 130,
#  'specific': 131,
#  'dynamically': 132,
#  'variables': 133,
#  'undefined': 134,
#  'controller': 135,
#  'adding': 136,
#  'based': 137,
#  'angularjs': 138,
#  'control': 139,
#  'parameter': 140,
#  'send': 141,
#  'difference': 142,
#  'show': 143,
#  'passing': 144,
#  'insert': 145,
#  'first': 146,
#  'model': 147,
#  '3': 148,
#  'elements': 149,
#  'regex': 150,
#  'vbnet': 151,
#  'within': 152,
#  'library': 153,
#  'codeigniter': 154,
#  'dynamic': 155,
#  'visual': 156,
#  'eclipse': 157,
#  'memory': 158,
#  'path': 159,
#  'possible': 160,
#  'connection': 161,
#  'js': 162,
#  'thread': 163,
#  'via': 164,
#  '+': 165,
#  'running': 166,
#  'default': 167,
#  'id': 168,
#  'program': 169,
#  'found': 170,
#  'size': 171,
#  'save': 172,
#  'issue': 173,
#  'content': 174,
#  'reference': 175,
#  'studio': 176,
#  'attribute': 177,
#  'laravel': 178,
#  'search': 179,
#  'static': 180,
#  'excel': 181,
#  'write': 182,
#  'test': 183,
#  'session': 184,
#  'characters': 185,
#  'character': 186,
#  'output': 187,
#  'current': 188,
#  'problem': 189,
#  'entity': 190,
#  'calling': 191,
#  'parameters': 192,
#  'simple': 193,
#  'empty': 194,
#  'command': 195,
#  'upload': 196,
#  'directory': 197,
#  'reading': 198,
#  'validation': 199,
#  'http': 200,
#  'selected': 201,
#  'unable': 202,
#  'textbox': 203,
#  'client': 204,
#  'map': 205,
#  'item': 206,
#  'int': 207,
#  'browser': 208,
#  'facebook': 209,
#  'images': 210,
#  'link': 211,
#  'setting': 212,
#  'store': 213,
#  'expression': 214,
#  'index': 215,
#  'single': 216,
#  'template': 217,
#  'css': 218,
#  'strings': 219,
#  'statement': 220,
#  'hibernate': 221,
#  'like': 222,
#  'failed': 223,
#  'rows': 224,
#  'loading': 225,
#  'box': 226,
#  'delete': 227,
#  'login': 228,
#  'header': 229,
#  'numbers': 230,
#  'nested': 231,
#  'replace': 232,
#  'color': 233,
#  'returning': 234,
#  'background': 235,
#  '4': 236,
#  'instance': 237,
#  'pdf': 238,
#  'could': 239,
#  'iphone': 240,
#  'parse': 241,
#  '1': 242,
#  'print': 243,
#  'char': 244,
#  'message': 245,
#  'csv': 246,
#  'bootstrap': 247,
#  'module': 248,
#  'tag': 249,
#  'converting': 250,
#  'invalid': 251,
#  'returns': 252,
#  'parent': 253,
#  'disable': 254,
#  'methods': 255,
#  'need': 256,
#  'chrome': 257,
#  'local': 258,
#  'changing': 259,
#  'trying': 260,
#  'email': 261,
#  'connect': 262,
#  'response': 263,
#  'functions': 264,
#  'install': 265,
#  'datetime': 266,
#  'angular': 267,
#  'redirect': 268,
#  'order': 269,
#  'dropdown': 270,
#  'arrays': 271,
#  'generate': 272,
#  'bar': 273,
#  'dictionary': 274,
#  'classes': 275,
#  'pandas': 276,
#  'source': 277,
#  'submit': 278,
#  'process': 279,
#  'folder': 280,
#  'checkbox': 281,
#  'columns': 282,
#  'child': 283,
#  'integer': 284,
#  'sending': 285,
#  'detect': 286,
#  'parsing': 287,
#  'items': 288,
#  'fields': 289,
#  'count': 290,
#  'x': 291,
#  'gridview': 292,
#  'start': 293,
#  'pointer': 294,
#  'console': 295,
#  'constructor': 296,
#  'double': 297,
#  'import': 298,
#  'programmatically': 299,
#  'random': 300,
#  'jsp': 301,
#  'selenium': 302,
#  'instead': 303,
#  'linux': 304,
#  'action': 305,
#  '7': 306,
#  'collection': 307,
#  'version': 308,
#  'datagridview': 309,
#  'sort': 310,
#  'filter': 311,
#  'objectivec': 312,
#  'website': 313,
#  'generic': 314,
#  'last': 315,
#  'build': 316,
#  'result': 317,
#  'binding': 318,
#  'system': 319,
#  'iframe': 320,
#  'split': 321,
#  'cell': 322,
#  'datatable': 323,
#  'arguments': 324,
#  'interface': 325,
#  'properties': 326,
#  'syntax': 327,
#  'download': 328,
#  'back': 329,
#  'nodejs': 330,
#  'scroll': 331,
#  'external': 332,
#  'binary': 333,
#  'onclick': 334,
#  'xcode': 335,
#  '5': 336,
#  'position': 337,
#  'called': 338,
#  'execute': 339,
#  'missing': 340,
#  'socket': 341,
#  'maps': 342,
#  'rest': 343,
#  'implement': 344,
#  'typeerror': 345,
#  'word': 346,
#  'whats': 347,
#  'byte': 348,
#  'extension': 349,
#  'match': 350,
#  'video': 351,
#  'argument': 352,
#  'menu': 353,
#  'given': 354,
#  'wordpress': 355,
#  'refresh': 356,
#  'copy': 357,
#  'retrieve': 358,
#  'regular': 359,
#  'node': 360,
#  'hide': 361,
#  'accessing': 362,
#  'forms': 363,
#  'include': 364,
#  'results': 365,
#  'ui': 366,
#  'showing': 367,
#  'canvas': 368,
#  'runtime': 369,
#  'defined': 370,
#  'arraylist': 371,
#  'handle': 372,
#  'document': 373,
#  'group': 374,
#  'drop': 375,
#  'large': 376,
#  'errors': 377,
#  'types': 378,
#  'mobile': 379,
#  'compare': 380,
#  'properly': 381,
#  'member': 382,
#  'many': 383,
#  'equivalent': 384,
#  'wcf': 385,
#  'exists': 386,
#  'opencv': 387,
#  'screen': 388,
#  'address': 389,
#  'global': 390,
#  'expected': 391,
#  'maven': 392,
#  'ie': 393,
#  'plugin': 394,
#  'events': 395,
#  '8': 396,
#  'password': 397,
#  'height': 398,
#  'vector': 399,
#  'length': 400,
#  'extract': 401,
#  'stored': 402,
#  'certain': 403,
#  'help': 404,
#  '0': 405,
#  'used': 406,
#  'jar': 407,
#  'apache': 408,
#  'writing': 409,
#  'dataframe': 410,
#  'dialog': 411,
#  'automatically': 412,
#  'handling': 413,
#  'works': 414,
#  'servlet': 415,
#  'prevent': 416,
#  'every': 417,
#  'fails': 418,
#  'resource': 419,
#  'names': 420,
#  'created': 421,
#  'style': 422,
#  'location': 423,
#  'html5': 424,
#  'magento': 425,
#  'width': 426,
#  'cast': 427,
#  'wrong': 428,
#  'numpy': 429,
#  'close': 430,
#  'range': 431,
#  'validate': 432,
#  'warning': 433,
#  'frame': 434,
#  'enum': 435,
#  'popup': 436,
#  'pattern': 437,
#  'contains': 438,
#  'displaying': 439,
#  'updating': 440,
#  'must': 441,
#  'listview': 442,
#  'tomcat': 443,
#  'curl': 444,
#  'testing': 445,
#  'operator': 446,
#  'package': 447,
#  'context': 448,
#  'conversion': 449,
#  '2d': 450,
#  'space': 451,
#  'authentication': 452,
#  'qt': 453,
#  'stop': 454,
#  'put': 455,
#  'structure': 456,
#  'exist': 457,
#  'auto': 458,
#  'keys': 459,
#  'token': 460,
#  'existing': 461,
#  'problems': 462,
#  'callback': 463,
#  'db': 464,
#  'long': 465,
#  'saving': 466,
#  'main': 467,
#  'always': 468,
#  'finding': 469,
#  'matplotlib': 470,
#  'grid': 471,
#  'foreach': 472,
#  'end': 473,
#  'block': 474,
#  'sorting': 475,
#  'remote': 476,
#  'determine': 477,
#  'dll': 478,
#  'performance': 479,
#  'buttons': 480,
#  'tags': 481,
#  'label': 482,
#  'sqlite': 483,
#  'tab': 484,
#  'plot': 485,
#  'combobox': 486,
#  'option': 487,
#  'bind': 488,
#  'mac': 489,
#  'stream': 490,
#  'uncaught': 491,
#  'phone': 492,
#  'modal': 493,
#  'join': 494,
#  'unexpected': 495,
#  'decimal': 496,
#  'chart': 497,
#  'example': 498,
#  'attributes': 499,
#  'compile': 500,
#  'radio': 501,
#  'checking': 502,
#  'correctly': 503,
#  'dom': 504,
#  'firefox': 505,
#  'installing': 506,
#  'lines': 507,
#  'tables': 508,
#  'point': 509,
#  'mouse': 510,
#  'support': 511,
#  'base': 512,
#  'right': 513,
#  'basic': 514,
#  'making': 515,
#  'tree': 516,
#  'unique': 517,
#  'users': 518,
#  'unit': 519,
#  'threads': 520,
#  'correct': 521,
#  'already': 522,
#  'wont': 523,
#  'handler': 524,
#  'mean': 525,
#  'good': 526,
#  'struct': 527,
#  'duplicate': 528,
#  'task': 529,
#  'scope': 530,
#  'uitableview': 531,
#  'hash': 532,
#  'even': 533,
#  'float': 534,
#  'pages': 535,
#  'valid': 536,
#  'namespace': 537,
#  'admin': 538,
#  'contents': 539,
#  'graph': 540,
#  'dates': 541,
#  'removing': 542,
#  'objective': 543,
#  'matrix': 544,
#  'sdk': 545,
#  'changes': 546,
#  'side': 547,
#  'lists': 548,
#  'calculate': 549,
#  'site': 550,
#  'const': 551,
#  'full': 552,
#  'keep': 553,
#  'next': 554,
#  'configuration': 555,
#  'encoding': 556,
#  'programming': 557,
#  'storing': 558,
#  'sum': 559,
#  'active': 560,
#  'limit': 561,
#  'log': 562,
#  'animation': 563,
#  'listbox': 564,
#  'case': 565,
#  'override': 566,
#  'printing': 567,
#  'implementation': 568,
#  'top': 569,
#  'allow': 570,
#  'append': 571,
#  'edit': 572,
#  'unicode': 573,
#  'part': 574,
#  'record': 575,
#  'debug': 576,
#  'winforms': 577,
#  'core': 578,
#  'lambda': 579,
#  'loaded': 580,
#  'controls': 581,
#  'mail': 582,
#  'twitter': 583,
#  'utf8': 584,
#  'times': 585,
#  'security': 586,
#  'resize': 587,
#  'pdo': 588,
#  'mongodb': 589,
#  'selection': 590,
#  'fatal': 591,
#  'records': 592,
#  'layout': 593,
#  'bean': 594,
#  'game': 595,
#  'language': 596,
#  'draw': 597,
#  'outside': 598,
#  'play': 599,
#  'cakephp': 600,
#  'jpa': 601,
#  'catch': 602,
#  'force': 603,
#  'constant': 604,
#  'gui': 605,
#  'unknown': 606,
#  'webdriver': 607,
#  'cookie': 608,
#  'assign': 609,
#  'boolean': 610,
#  'inserting': 611,
#  'domain': 612,
#  'mode': 613,
#  'slow': 614,
#  'oracle': 615,
#  'issues': 616,
#  'focus': 617,
#  'ip': 618,
#  'mapping': 619,
#  '20': 620,
#  'named': 621,
#  'multidimensional': 622,
#  'requests': 623,
#  'port': 624,
#  'generated': 625,
#  'uploading': 626,
#  'clicked': 627,
#  'available': 628,
#  'wait': 629,
#  'condition': 630,
#  'state': 631,
#  'populate': 632,
#  'specified': 633,
#  'gem': 634,
#  'switch': 635,
#  'device': 636,
#  'yii': 637,
#  'assembly': 638,
#  'netbeans': 639,
#  'ubuntu': 640,
#  'jdbc': 641,
#  'required': 642,
#  'special': 643,
#  'engine': 644,
#  'executing': 645,
#  'bad': 646,
#  'exceptions': 647,
#  'know': 648,
#  'avoid': 649,
#  'initialize': 650,
#  'async': 651,
#  'network': 652,
#  'javafx': 653,
#  'swing': 654,
#  'soap': 655,
#  'trigger': 656,
#  '404': 657,
#  'question': 658,
#  'checked': 659,
#  'timeout': 660,
#  'export': 661,
#  'timer': 662,
#  '2010': 663,
#  'dont': 664,
#  'want': 665,
#  'webservice': 666,
#  'design': 667,
#  'os': 668,
#  'component': 669,
#  'iterate': 670,
#  'tkinter': 671,
#  'efficient': 672,
#  'native': 673,
#  'zend': 674,
#  'stack': 675,
#  'heroku': 676,
#  'implementing': 677,
#  'textarea': 678,
#  'words': 679,
#  'body': 680,
#  'linked': 681,
#  'move': 682,
#  '6': 683,
#  'compiler': 684,
#  'clicking': 685,
#  'datagrid': 686,
#  'false': 687,
#  'navigation': 688,
#  'views': 689,
#  'fill': 690,
#  'inheritance': 691,
#  'second': 692,
#  'render': 693,
#  'define': 694,
#  'pointers': 695,
#  'procedure': 696,
#  'particular': 697,
#  'clear': 698,
#  'information': 699,
#  'symfony2': 700,
#  'true': 701,
#  'route': 702,
#  'scrolling': 703,
#  'declaration': 704,
#  'symbol': 705,
#  'enable': 706,
#  'behind': 707,
#  'root': 708,
#  'spaces': 709,
#  'fix': 710,
#  'flask': 711,
#  'reflection': 712,
#  'bytes': 713,
#  'status': 714,
#  '10': 715,
#  'push': 716,
#  'algorithm': 717,
#  'integers': 718,
#  'youtube': 719,
#  'rspec': 720,
#  'n': 721,
#  'calls': 722,
#  'apply': 723,
#  'fetch': 724,
#  'month': 725,
#  'options': 726,
#  'services': 727,
#  'calendar': 728,
#  'private': 729,
#  'dependency': 730,
#  'usage': 731,
#  'target': 732,
#  'development': 733,
#  'progress': 734,
#  'left': 735,
#  'cache': 736,
#  'comparing': 737,
#  'environment': 738,
#  'alert': 739,
#  'xpath': 740,
#  'practice': 741,
#  'models': 742,
#  'changed': 743,
#  'maximum': 744,
#  'hex': 745,
#  'ssl': 746,
#  'merge': 747,
#  'internet': 748,
#  'headers': 749,
#  'matching': 750,
#  'statements': 751,
#  'notification': 752,
#  'shared': 753,
#  'tests': 754,
#  'previous': 755,
#  'apps': 756,
#  'datepicker': 757,
#  'separate': 758,
#  'panel': 759,
#  'standard': 760,
#  'font': 761,
#  'installed': 762,
#  'processing': 763,
#  'directive': 764,
#  'comma': 765,
#  'symfony': 766,
#  'driver': 767,
#  'boost': 768,
#  'https': 769,
#  'libraries': 770,
#  'would': 771,
#  'resolve': 772,
#  'better': 773,
#  'report': 774,
#  'ggplot2': 775,
#  'container': 776,
#  'opengl': 777,
#  'abstract': 778,
#  'title': 779,
#  'htaccess': 780,
#  'configure': 781,
#  'icon': 782,
#  'see': 783,
#  'partial': 784,
#  'alternative': 785,
#  'queries': 786,
#  'hashmap': 787,
#  'autocomplete': 788,
#  'returned': 789,
#  'debugging': 790,
#  'links': 791,
#  'throws': 792,
#  'messages': 793,
#  'hidden': 794,
#  'logging': 795,
#  'asp': 796,
#  'selecting': 797,
#  'junit': 798,
#  'react': 799,
#  'checkboxes': 800,
#  'declare': 801,
#  'generating': 802,
#  'keyboard': 803,
#  'proxy': 804,
#  'something': 805,
#  'try': 806,
#  'jtable': 807,
#  'whether': 808,
#  'max': 809,
#  'quotes': 810,
#  'visible': 811,
#  'echo': 812,
#  'causes': 813,
#  'resources': 814,
#  'coordinates': 815,
#  'operation': 816,
#  'extjs': 817,
#  'denied': 818,
#  'devise': 819,
#  'virtual': 820,
#  'contain': 821,
#  'escape': 822,
#  'formatting': 823,
#  'shell': 824,
#  'public': 825,
#  'drawing': 826,
#  'take': 827,
#  'product': 828,
#  'machine': 829,
#  'delegate': 830,
#  'webpage': 831,
#  'entities': 832,
#  'queue': 833,
#  'strange': 834,
#  'containing': 835,
#  'cells': 836,
#  'dataset': 837,
#  'twice': 838,
#  'dropdownlist': 839,
#  'svg': 840,
#  'connecting': 841,
#  'serialize': 842,
#  'per': 843,
#  'ms': 844,
#  'execution': 845,
#  'rendering': 846,
#  'intellij': 847,
#  'setup': 848,
#  'conditional': 849,
#  'applications': 850,
#  'gives': 851,
#  'relationship': 852,
#  'xaml': 853,
#  'jsf': 854,
#  'level': 855,
#  'inline': 856,
#  'opening': 857,
#  'nodes': 858,
#  'razor': 859,
#  'jqgrid': 860,
#  'drag': 861,
#  'definition': 862,
#  'relative': 863,
#  'initialization': 864,
#  'safe': 865,
#  'cc++': 866,
#  'reload': 867,
#  'importing': 868,
#  'building': 869,
#  'blank': 870,
#  'expressions': 871,
#  'day': 872,
#  'uiview': 873,
#  'batch': 874,
#  'modify': 875,
#  'timestamp': 876,
#  'capture': 877,
#  'allowed': 878,
#  'internal': 879,
#  'added': 880,
#  'retrieving': 881,
#  'serialization': 882,
#  'widget': 883,
#  'compiling': 884,
#  'sqlalchemy': 885,
#  'still': 886,
#  'boot': 887,
#  'seconds': 888,
#  'highcharts': 889,
#  'gcc': 890,
#  'foreign': 891,
#  'numeric': 892,
#  'starting': 893,
#  'phonegap': 894,
#  'cookies': 895,
#  'jackson': 896,
#  'injection': 897,
#  'points': 898,
#  'annotation': 899,
#  'embedded': 900,
#  'etc': 901,
#  'fast': 902,
#  'firing': 903,
#  'selector': 904,
#  'host': 905,
#  'href': 906,
#  'nsstring': 907,
#  'webbrowser': 908,
#  'doctrine': 909,
#  'trouble': 910,
#  'section': 911,
#  'passed': 912,
#  'asynchronous': 913,
#  'cursor': 914,
#  'able': 915,
#  'jframe': 916,
#  'protocol': 917,
#  'recursive': 918,
#  'overriding': 919,
#  'specify': 920,
#  'sequence': 921,
#  'touch': 922,
#  'config': 923,
#  'labels': 924,
#  'deploy': 925,
#  'fixed': 926,
#  'jaxb': 927,
#  'postgresql': 928,
#  'giving': 929,
#  'hover': 930,
#  'urls': 931,
#  'ascii': 932,
#  'assignment': 933,
#  'deleting': 934,
#  'axis': 935,
#  'nil': 936,
#  'tabs': 937,
#  'gwt': 938,
#  'transaction': 939,
#  'go': 940,
#  'webview': 941,
#  'explorer': 942,
#  'sharepoint': 943,
#  'anchor': 944,
#  'restful': 945,
#  'replacing': 946,
#  'osx': 947,
#  'days': 948,
#  'base64': 949,
#  'toggle': 950,
#  'closing': 951,
#  'proper': 952,
#  'vb': 953,
#  'faster': 954,
#  '500': 955,
#  'digits': 956,
#  'exit': 957,
#  'fastest': 958,
#  'v3': 959,
#  'enter': 960,
#  'casting': 961,
#  'pagination': 962,
#  'moving': 963,
#  'nhibernate': 964,
#  'activerecord': 965,
#  'permission': 966,
#  'settings': 967,
#  'templates': 968,
#  'ignore': 969,
#  'reset': 970,
#  'serial': 971,
#  'caching': 972,
#  'real': 973,
#  'effect': 974,
#  'including': 975,
#  'loops': 976,
#  'tcp': 977,
#  'year': 978,
#  'declared': 979,
#  'incorrect': 980,
#  'else': 981,
#  'across': 982,
#  'uitableviewcell': 983,
#  'sent': 984,
#  'comparison': 985,
#  'complex': 986,
#  'programatically': 987,
#  'complete': 988,
#  'multi': 989,
#  'activity': 990,
#  'singleton': 991,
#  'stl': 992,
#  'speed': 993,
#  'mysqli': 994,
#  'equal': 995,
#  's3': 996,
#  'place': 997,
#  'inner': 998,
#  'txt': 999,
#  ...}

# %%
def test_my_bag_of_words():
    words_to_index = {'hi': 0, 'you': 1, 'me': 2, 'are': 3}
    examples = ['hi how are you']
    answers = [[1, 1, 0, 1]]
    for ex, ans in zip(examples, answers):
        if (my_bag_of_words(ex, words_to_index, 4) != ans).any():
            return "Wrong answer for the case: '%s', returned %s" % (ex, my_bag_of_words(ex, words_to_index, 4))
    return 'Basic tests are passed.'

# %%
print(test_my_bag_of_words())
# Out:
# Basic tests are passed.

# %% [markdown]
# Now apply the implemented function to all samples (this might take up to a minute):

# %%
from scipy import sparse as sp_sparse

# %%
X_train_mybag = sp_sparse.vstack([sp_sparse.csr_matrix(my_bag_of_words(text, WORDS_TO_INDEX, DICT_SIZE)) for text in X_train])
X_val_mybag = sp_sparse.vstack([sp_sparse.csr_matrix(my_bag_of_words(text, WORDS_TO_INDEX, DICT_SIZE)) for text in X_val])
X_test_mybag = sp_sparse.vstack([sp_sparse.csr_matrix(my_bag_of_words(text, WORDS_TO_INDEX, DICT_SIZE)) for text in X_test])
print('X_train shape ', X_train_mybag.shape)
print('X_val shape ', X_val_mybag.shape)
print('X_test shape ', X_test_mybag.shape)
# Out:
# X_train shape  (100000, 5000)
# X_val shape  (30000, 5000)
# X_test shape  (20000, 5000)

# %% [markdown]
# As you might notice, we transform the data to sparse representation, to store the useful information efficiently. There are many [types](https://docs.scipy.org/doc/scipy/reference/sparse.html) of such representations, however sklearn algorithms can work only with [csr](https://docs.scipy.org/doc/scipy/reference/generated/scipy.sparse.csr_matrix.html#scipy.sparse.csr_matrix) matrix, so we will use this one.

# %% [markdown]
# **Task 3 (BagOfWords).** For the 11th row in *X_train_mybag* find how many non-zero elements it has. In this task the answer (variable *non_zero_elements_count*) should be an integer number, e.g. 20.

# %%
import numpy as np

row = X_train_mybag[10].toarray()[0]
non_zero_elements_count = np.count_nonzero(row)####### YOUR CODE HERE #######

print(non_zero_elements_count)

grader.submit_tag('BagOfWords', str(non_zero_elements_count))
# Out:
# 7
# Current answer for task BagOfWords is:
#  7...

# %% [markdown]
# #### TF-IDF
#
# The second approach extends the bag-of-words framework by taking into account total frequencies of words in the corpora. It helps to penalize too frequent words and provide better features space.
#
# Implement function *tfidf_features* using class [TfidfVectorizer](http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html) from *scikit-learn*. Use *train* corpus to train a vectorizer. Don't forget to take a look into the arguments that you can pass to it. We suggest that you filter out too rare words (occur less than in 5 titles) and too frequent words (occur more than in 90% of the titles). Also, use bigrams along with unigrams in your vocabulary.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
def tfidf_features(X_train, X_val, X_test):
    """
        X_train, X_val, X_test — samples        
        return TF-IDF vectorized representation of each sample and vocabulary
    """
    # Create TF-IDF vectorizer with a proper parameters choice
    # Fit the vectorizer on the train set
    # Transform the train, test, and val sets and return the result   
    
    vectorizer = TfidfVectorizer(None, min_df=4, max_df=0.9, ngram_range=(1,2), token_pattern=r'(\S+)') ####### YOUR CODE HERE #######
    vectorizer.fit(train.title.values)
    X_train = vectorizer.transform(X_train)
    X_val = vectorizer.transform(X_val)
    X_test = vectorizer.transform(X_test)
    ######################################
    ######### YOUR CODE HERE #############
    ######################################
    
    return X_train, X_val, X_test, vectorizer.vocabulary_

# %% [markdown]
# Once you have done text preprocessing, always have a look at the results. Be very careful at this step, because the performance of future models will drastically depend on it.
#
# In this case, check whether you have c++ or c# in your vocabulary, as they are obviously important tokens in our tags prediction task:

# %%
X_train_tfidf, X_val_tfidf, X_test_tfidf, tfidf_vocab = tfidf_features(X_train, X_val, X_test)
tfidf_reversed_vocab = {i:word for word,i in tfidf_vocab.items()}

tfidf_reversed_vocab
# Out:
# {14042: 'how',
#  29639: 'to',
#  10061: 'draw',
#  1440: 'a',
#  27392: 'stacked',
#  14852: 'in',
#  24206: 'r?',
#  14071: 'how to',
#  29868: 'to draw',
#  10062: 'draw a',
#  2123: 'a stacked',
#  15421: 'in r?',
#  19846: 'mysql',
#  26026: 'select',
#  2839: 'all',
#  24532: 'records',
#  32937: 'where',
#  8903: 'datetime',
#  11497: 'field',
#  16414: 'is',
#  17885: 'less',
#  28666: 'than',
#  27180: 'specified',
#  32030: 'value',
#  19881: 'mysql select',
#  26030: 'select all',
#  2889: 'all records',
#  32938: 'where a',
#  1611: 'a datetime',
#  8907: 'datetime field',
#  11510: 'field is',
#  16510: 'is less',
#  17887: 'less than',
#  28669: 'than a',
#  2112: 'a specified',
#  28498: 'terminate',
#  33172: 'windows',
#  22777: 'phone',
#  1305: '8.1',
#  4027: 'app',
#  30397: 'to terminate',
#  33202: 'windows phone',
#  22780: 'phone 8.1',
#  1306: '8.1 app',
#  13132: 'get',
#  8472: 'current',
#  29519: 'time',
#  27129: 'specific',
#  8243: 'country',
#  32290: 'via',
#  17253: 'jquery',
#  13163: 'get current',
#  8491: 'current time',
#  29539: 'time in',
#  14865: 'in a',
#  2111: 'a specific',
#  32307: 'via jquery',
#  7675: 'configuring',
#  30536: 'tomcat',
#  31473: 'use',
#  27373: 'ssl',
#  30452: 'to use',
#  4808: 'awesome',
#  20059: 'nested',
#  26455: 'set',
#  23118: 'plugin',
#  547: '-',
#  2504: 'add',
#  20110: 'new',
#  6823: 'children',
#  28747: 'the',
#  30664: 'tree',
#  4600: 'at',
#  32200: 'various',
#  17906: 'levels',
#  23119: 'plugin -',
#  659: '- how',
#  29664: 'to add',
#  2549: 'add new',
#  6827: 'children to',
#  30404: 'to the',
#  8274: 'create',
#  18740: 'map',
#  12579: 'from',
#  17412: 'json',
#  25116: 'response',
#  25509: 'ruby',
#  21318: 'on',
#  24217: 'rails',
#  1186: '3?',
#  29806: 'to create',
#  18747: 'map from',
#  12730: 'from json',
#  17443: 'json response',
#  25124: 'response in',
#  15459: 'in ruby',
#  25527: 'ruby on',
#  21499: 'on rails',
#  24229: 'rails 3?',
#  25497: 'rspec',
#  28508: 'test',
#  14576: 'if',
#  19100: 'method',
#  6177: 'called',
#  25500: 'rspec test',
#  28522: 'test if',
#  19131: 'method is',
#  16438: 'is called',
#  27277: 'springboot',
#  17945: 'lifecycle',
#  11002: 'exception',
#  14816: 'import',
#  8613: 'data',
#  10975: 'excel',
#  8704: 'database',
#  31631: 'using',
#  22797: 'php',
#  29999: 'to import',
#  14820: 'import data',
#  8643: 'data from',
#  12680: 'from excel',
#  10990: 'excel to',
#  30126: 'to mysql',
#  19857: 'mysql database',
#  8739: 'database using',
#  31831: 'using php',
#  20892: 'obtaining',
#  20755: 'object',
#  12015: 'for',
#  22396: 'parameterized',
#  30861: 'type',
#  33727: 'without',
#  7803: 'constructing',
#  6881: 'class',
#  20893: 'obtaining the',
#  29074: 'the object',
#  20782: 'object for',
#  12023: 'for a',
#  1933: 'a parameterized',
#  22397: 'parameterized type',
#  28822: 'the class',
#  6912: 'class in',
#  16388: 'ipad',
#  20334: 'not',
#  26112: 'selecting',
#  28557: 'text',
#  15984: 'inside',
#  15877: 'input',
#  28400: 'tap',
#  26114: 'selecting all',
#  2900: 'all text',
#  28585: 'text inside',
#  15985: 'inside a',
#  2172: 'a text',
#  28584: 'text input',
#  15902: 'input on',
#  17353: "jquery's",
#  138: '$',
#  12906: 'function',
#  3210: 'and',
#  3013: 'an',
#  20835: 'object?',
#  14059: 'how is',
#  1709: 'a function',
#  12910: 'function and',
#  3228: 'and an',
#  3156: 'an object?',
#  10298: 'eclipse',
#  5962: 'c++',
#  19219: 'mingw',
#  6230: 'can',
#  23623: 'program',
#  10302: 'eclipse c++',
#  579: '- can',
#  6249: 'can not',
#  17029: 'javascript',
#  14246: 'i',
#  6116: 'call',
#  21609: 'one',
#  23805: 'prototype',
#  3855: 'another',
#  19162: 'method?',
#  15202: 'in javascript',
#  17085: 'javascript how',
#  14046: 'how can',
#  6244: 'can i',
#  14263: 'i call',
#  6143: 'call one',
#  23807: 'prototype method',
#  19128: 'method in',
#  14889: 'in another',
#  16217: 'intersection',
#  20922: 'of',
#  18133: 'list',
#  26525: 'sets',
#  16218: 'intersection of',
#  21109: 'of list',
#  18162: 'list of',
#  20214: 'no',
#  18486: 'longer',
#  2308: 'able',
#  13934: 'hide',
#  17597: 'keyboard',
#  10165: 'during',
#  16376: 'ios7',
#  20231: 'no longer',
#  2309: 'able to',
#  29980: 'to hide',
#  15178: 'in ios7',
#  11482: 'fetch',
#  17557: 'key',
#  28129: 'swift?',
#  29928: 'to fetch',
#  11487: 'fetch the',
#  29003: 'the key',
#  17568: 'key from',
#  17428: 'json in',
#  15524: 'in swift?',
#  6543: 'change',
#  23036: 'pivot',
#  13799: 'header',
#  28458: 'template',
#  1296: '8',
#  29752: 'to change',
#  28467: 'template in',
#  15630: 'in windows',
#  22779: 'phone 8',
#  7744: 'connectionstring',
#  10570: 'encryption',
#  17888: 'let',
#  30960: 'ui',
#  24667: 'refresh',
#  18470: 'long',
#  25586: 'running',
#  21838: 'operation',
#  30058: 'to let',
#  29237: 'the ui',
#  10166: 'during a',
#  1837: 'a long',
#  18477: 'long running',
#  5184: 'better',
#  32562: 'way',
#  11067: 'execute',
#  11552: 'file',
#  23915: 'python',
#  7754: 'console',
#  22126: 'output',
#  32797: 'when',
#  25551: 'run',
#  24049: 'python?',
#  5188: 'better way',
#  32569: 'way to',
#  29911: 'to execute',
#  25521: 'ruby file',
#  11629: 'file using',
#  31849: 'using python',
#  23933: 'python and',
#  3423: 'and how',
#  29963: 'to get',
#  7764: 'console output',
#  22148: 'output when',
#  11595: 'file is',
#  16553: 'is run',
#  25561: 'run from',
#  12785: 'from python?',
#  18648: 'make',
#  1038: '2',
#  29503: 'thumbnails',
#  21582: 'once',
#  7218: 'codeigniter',
#  4616: 'at once',
#  21584: 'once in',
#  14982: 'in codeigniter',
#  16810: 'java',
#  6659: 'character',
#  32467: 'vs',
#  32762: 'what',
#  2314: 'about',
#  18994: 'memory',
#  31470: 'usage?',
#  32763: 'what about',
#  5388: 'bootstrap',
#  19294: 'modal',
#  7108: 'close',
#  10614: 'enter',
#  23424: 'press',
#  5398: 'bootstrap modal',
#  21396: 'on enter',
#  10615: 'enter key',
#  17577: 'key press',
#  18085: 'linq',
#  24097: 'query',
#  33237: 'with',
#  13584: 'group',
#  5703: 'by',
#  25224: 'retrieving',
#  22718: 'percentage',
#  18101: 'linq query',
#  24126: 'query with',
#  33405: 'with group',
#  13587: 'group by',
#  17671: 'label',
#  16611: 'issue',
#  21803: 'openerp',
#  16612: 'issue -',
#  17538: 'keep',
#  20856: 'objects',
#  32345: 'view',
#  25765: 'scaling',
#  32384: 'view?',
#  456: '(or',
#  30047: 'to keep',
#  20866: 'objects in',
#  15604: 'in view',
#  4603: 'at all',
#  29526: 'time by',
#  28924: 'the field',
#  11514: 'field of',
#  4679: 'attributeerror:',
#  270: "'nonetype'",
#  13707: 'has',
#  4656: 'attribute',
#  291: "'split'",
#  4681: "attributeerror: 'nonetype'",
#  271: "'nonetype' object",
#  20787: 'object has',
#  13723: 'has no',
#  20217: 'no attribute',
#  4077: 'append',
#  29688: 'to append',
#  4085: 'append to',
#  24907: 'replace',
#  21591: 'onclick',
#  17329: 'jquery replace',
#  21597: 'onclick in',
#  24571: 'redirect',
#  23661: 'programme',
#  27003: 'some',
#  30254: 'to redirect',
#  24582: 'redirect output',
#  22142: 'output of',
#  21192: 'of ruby',
#  30346: 'to some',
#  212: "'access-control-allow-origin'",
#  23413: 'present',
#  25006: 'requested',
#  25079: 'resource',
#  10717: 'error',
#  20215: "no 'access-control-allow-origin'",
#  213: "'access-control-allow-origin' header",
#  13807: 'header is',
#  16543: 'is present',
#  23416: 'present on',
#  21540: 'on the',
#  29145: 'the requested',
#  25007: 'requested resource',
#  8332: 'creating',
#  5845: 'c#',
#  6307: 'cannot',
#  14813: 'implicitly',
#  8016: 'convert',
#  296: "'string'",
#  8342: 'creating json',
#  33177: 'windows 8',
#  1299: '8 c#',
#  5934: 'c# using',
#  6327: 'cannot implicitly',
#  14814: 'implicitly convert',
#  8082: 'convert type',
#  30865: "type 'string'",
#  297: "'string' to",
#  9725: 'django',
#  19353: 'modelform',
#  9750: 'django modelform',
#  9797: 'do',
#  26670: 'show/hide',
#  9679: 'div',
#  26881: 'slide',
#  504: '(without',
#  17355: 'jquery)',
#  29860: 'to do',
#  26671: 'show/hide div',
#  9708: 'div with',
#  26883: 'slide in',
#  4800: 'avoid',
#  5596: 'busy',
#  29707: 'to avoid',
#  15194: 'in java',
#  17718: 'laravel',
#  1230: '4:',
#  25312: 'returns',
#  141: '$.ajax',
#  23295: 'post',
#  17721: 'laravel 4:',
#  25324: 'returns no',
#  20221: 'no data',
#  8687: 'data with',
#  13657: 'handle',
#  2758: 'ajax',
#  29974: 'to handle',
#  15219: 'in jquery',
#  17263: 'jquery ajax',
#  34145: 'year',
#  24178: 'r',
#  12936: 'function in',
#  15418: 'in r',
#  25232: 'retrofit',
#  4373: 'as',
#  26812: 'singleton',
#  32987: 'while',
#  13608: 'gson',
#  4374: 'as a',
#  2097: 'a singleton',
#  33026: 'while using',
#  31728: 'using gson',
#  841: '.cpp',
#  19771: 'my',
#  19181: 'mfc',
#  4062: 'app?',
#  14052: 'how do',
#  9804: 'do i',
#  14463: 'i use',
#  15304: 'in my',
#  8162: 'copying',
#  32601: 'web',
#  24617: 'reference',
#  23682: 'project',
#  8163: 'copying a',
#  2267: 'a web',
#  32625: 'web reference',
#  24633: 'reference to',
#  29653: 'to a',
#  1901: 'a new',
#  20138: 'new project',
#  30575: 'top',
#  11893: 'five',
#  24123: 'query to',
#  30314: 'to select',
#  26072: 'select top',
#  17149: 'javascript:',
#  15936: 'insert',
#  27690: 'string',
#  15733: 'index',
#  17151: 'javascript: how',
#  14344: 'i insert',
#  15937: 'insert a',
#  2136: 'a string',
#  27701: 'string at',
#  4602: 'at a',
#  27151: 'specific index',
#  3961: 'apache',
#  22241: 'page',
#  12413: 'format',
#  33895: 'worksheet',
#  6582: 'change page',
#  12421: 'format for',
#  12120: 'for excel',
#  10994: 'excel worksheet',
#  29629: 'tkinter',
#  23676: 'progress',
#  4902: 'bar',
#  24019: 'python tkinter',
#  23677: 'progress bar',
#  4911: 'bar not',
#  20511: 'not running',
#  27609: 'store',
#  14692: 'image',
#  22621: 'path',
#  30365: 'to store',
#  27621: 'store image',
#  14729: 'image path',
#  22629: 'path in',
#  15305: 'in mysql',
#  31665: 'using c#',
#  17169: 'jdbc',
#  7715: 'connection',
#  10793: 'error:',
#  4568: 'associated',
#  18698: 'managed',
#  17171: 'jdbc connection',
#  10807: 'error: not',
#  4569: 'associated with',
#  33243: 'with a',
#  1848: 'a managed',
#  19579: 'multiple',
#  28322: 'tables',
#  19312: 'model',
#  34167: 'yii2',
#  31510: 'use multiple',
#  19674: 'multiple tables',
#  28325: 'tables in',
#  15335: 'in one',
#  21648: 'one model',
#  19329: 'model in',
#  15658: 'in yii2',
#  7957: 'controller',
#  19961: 'names',
#  4469: 'asp.net',
#  19760: 'mvc4',
#  13139: 'get all',
#  19965: 'names in',
#  14905: 'in asp.net',
#  4491: 'asp.net mvc4',
#  6426: 'casting',
#  16111: 'integer',
#  4267: 'array',
#  16113: 'integer array',
#  4313: 'array to',
#  30153: 'to object',
#  20762: 'object array',
#  4286: 'array in',
#  13319: 'getting',
#  31390: 'uploading',
#  13333: 'getting error',
#  10753: 'error in',
#  31393: 'uploading file',
#  11590: 'file in',
#  15364: 'in php',
#  19163: 'methods',
#  19168: 'methods in',
#  23504: 'printing',
#  11948: 'floats',
#  20681: 'number',
#  34250: 'zeros',
#  27158: 'specific number',
#  20693: 'number of',
#  26738: 'simple',
#  6051: 'c/c++',
#  20096: 'network',
#  14483: 'i/o',
#  17920: 'library',
#  16085: 'instead',
#  25606: 'running ruby',
#  16086: 'instead of',
#  5289: 'bitmap',
#  6047: 'c,',
#  5239: 'binary',
#  21847: 'operations',
#  14949: 'in c,',
#  9062: 'default',
#  18615: 'mail',
#  33862: 'working',
#  20559: 'not working',
#  10636: 'entity',
#  12524: 'framework',
#  9670: 'distinct',
#  10639: 'entity framework',
#  12543: 'framework model',
#  11302: 'extjs',
#  6776: 'checked',
#  20285: 'nodes',
#  27956: 'submit?',
#  13151: 'get checked',
#  18216: 'lists',
#  18103: 'linq select',
#  20076: 'nested lists',
#  26639: 'show',
#  10427: 'element,',
#  22521: 'pass',
#  32094: 'values',
#  14100: 'html',
#  10392: 'element',
#  447: '(not',
#  17356: 'jquery)?',
#  30333: 'to show',
#  26645: 'show and',
#  3421: 'and hide',
#  3072: 'an element,',
#  22556: 'pass values',
#  32104: 'values from',
#  12726: 'from javascript',
#  17128: 'javascript to',
#  29985: 'to html',
#  14125: 'html element',
#  10417: 'element using',
#  31752: 'using javascript',
#  17032: 'javascript (not',
#  15795: 'information',
#  9390: 'dictionary',
#  14329: 'i get',
#  13195: 'get information',
#  15796: 'information from',
#  9395: 'dictionary in',
#  169: '&',
#  933: '.text',
#  9602: 'display',
#  8315: 'created',
#  21788: 'opencv',
#  3733: 'android',
#  9615: 'display image',
#  8317: 'created by',
#  21794: 'opencv on',
#  21329: 'on android',
#  16082: 'instantiating',
#  19970: 'namespace',
#  6892: 'class by',
#  5772: 'by string',
#  27730: 'string in',
#  15012: 'in current',
#  33914: 'wpf',
#  25827: 'screen',
#  25064: 'resolution',
#  33916: 'wpf and',
#  25832: 'screen resolution',
#  7864: 'content',
#  27491: 'static',
#  28276: 'table',
#  6480: 'cell',
#  9645: 'displayed',
#  16350: 'ios',
#  1313: '9',
#  7876: 'content of',
#  21214: 'of static',
#  28311: 'table view',
#  32352: 'view cell',
#  20400: 'not displayed',
#  16358: 'ios 9',
#  5166: 'best',
#  32776: 'what is',
#  16572: 'is the',
#  28789: 'the best',
#  4843: 'backbone',
#  19349: 'model.save()',
#  26202: 'sending',
#  23880: 'put',
#  21170: 'of post',
#  24602: 'redirects',
#  13378: 'given',
#  5597: 'but',
#  26419: 'session',
#  24603: 'redirects to',
#  28952: 'the given',
#  29183: 'the session',
#  26430: 'session from',
#  12775: 'from php',
#  19725: 'mvc',
#  1191: '4',
#  24360: 'razor:',
#  19240: 'missing',
#  7274: 'collections',
#  12353: 'form',
#  19731: 'mvc 4',
#  32851: 'when i',
#  31474: 'use a',
#  1698: 'a form',
#  12384: 'form post',
#  23141: 'poi',
#  8841: 'date',
#  3970: 'apache poi',
#  27889: 'style',
#  10219: 'dynamically',
#  18059: 'linkbutton',
#  2669: 'affecting',
#  22094: 'others?',
#  6592: 'change the',
#  29207: 'the style',
#  27896: 'style of',
#  21150: 'of one',
#  10231: 'dynamically created',
#  6719: 'check',
#  23146: 'point',
#  5158: 'below',
#  17985: 'line',
#  21898: 'or',
#  20566: 'not?',
#  14273: 'i check',
#  6730: 'check if',
#  14578: 'if a',
#  1962: 'a point',
#  23148: 'point is',
#  1810: 'a line',
#  18010: 'line or',
#  21979: 'or not?',
#  7066: 'client',
#  24975: 'request',
#  11408: 'fails',
#  29569: 'timeout',
#  11416: 'fails with',
#  33344: 'with default',
#  26780: 'simultaneously',
#  2430: 'acquire',
#  31285: 'update',
#  13519: 'graph',
#  18875: 'matplotlib',
#  8618: 'data and',
#  3690: 'and update',
#  13523: 'graph using',
#  16227: 'into',
#  27627: 'store value',
#  32058: 'value into',
#  16287: 'into string',
#  27697: 'string array',
#  8820: 'datatable',
#  15868: 'inner',
#  17213: 'join',
#  10173: 'dynamic',
#  7352: 'columns',
#  5876: 'c# datatable',
#  15872: 'inner join',
#  17222: 'join with',
#  33358: 'with dynamic',
#  10181: 'dynamic columns',
#  8181: 'correct',
#  2501: 'adapter',
#  22648: 'pattern',
#  20839: 'objective',
#  5810: 'c',
#  28851: 'the correct',
#  21233: 'of the',
#  22651: 'pattern in',
#  15332: 'in objective',
#  20840: 'objective c',
#  25709: 'save',
#  11969: 'folder',
#  30304: 'to save',
#  25711: 'save an',
#  3114: 'an image',
#  14741: 'image to',
#  29683: 'to another',
#  3874: 'another folder',
#  11984: 'folder using',
#  31637: 'using ajax',
#  2762: 'ajax and',
#  3463: 'and jquery',
#  26627: 'should',
#  32906: 'when should',
#  26632: 'should i',
#  31495: 'use function',
#  15412: 'in python?',
#  23127: 'plugin:',
#  14669: 'ignore',
#  25477: 'rows',
#  27057: 'sorting',
#  29995: 'to ignore',
#  27167: 'specific rows',
#  9941: 'dom',
#  3786: 'angular',
#  9515: 'directive',
#  9943: 'dom element',
#  10404: 'element in',
#  14883: 'in angular',
#  3795: 'angular directive',
#  24549: 'rectangles',
#  20172: 'next',
#  10257: 'each',
#  22079: 'other',
#  20179: 'next to',
#  29876: 'to each',
#  10266: 'each other',
#  22086: 'other in',
#  22400: 'parameters',
#  31414: 'url',
#  34240: 'zend',
#  13324: 'getting all',
#  22405: 'parameters from',
#  12848: 'from url',
#  31422: 'url in',
#  15661: 'in zend',
#  15805: 'inheritance',
#  2345: 'access',
#  23531: 'problem',
#  15869: 'inner class',
#  32091: 'valueerror:',
#  9862: 'does',
#  18837: 'match',
#  29528: 'time data',
#  9882: 'does not',
#  20467: 'not match',
#  22568: 'passing',
#  26979: 'sockets',
#  22570: 'passing an',
#  3046: 'an array',
#  4304: 'array of',
#  21096: 'of json',
#  17434: 'json objects',
#  26981: 'sockets in',
#  6804: 'child',
#  9245: 'deserializing',
#  34061: 'xml',
#  6812: 'child nodes',
#  32836: 'when deserializing',
#  9248: 'deserializing xml',
#  34100: 'xml to',
#  32269: 'version:',
#  4107: 'application',
#  11063: 'executable',
#  7853: 'contains',
#  31245: 'unsupported',
#  10785: 'error when',
#  32922: 'when uploading',
#  4315: 'array using',
#  1419: '[errno',
#  31162: 'unique',
#  7372: 'combination',
#  7373: 'combination of',
#  5252: 'bind',
#  10093: 'drop',
#  10004: 'down',
#  11855: 'first',
#  8962: 'ddl',
#  10096: 'drop down',
#  10009: 'down list',
#  18168: 'list using',
#  31763: 'using jquery',
#  21353: 'on change',
#  6580: 'change of',
#  21047: 'of first',
#  1158: '3.1',
#  10567: 'encrypted',
#  13049: 'gem',
#  6991: 'clause',
#  24225: 'rails 3.1',
#  28862: 'the database',
#  26456: 'set a',
#  28583: 'text in',
#  22957: 'php,',
#  19895: 'mysql,',
#  13459: 'google',
#  18781: 'maps',
#  3979: 'api',
#  13062: 'generate',
#  6875: 'city',
#  27457: 'state',
#  19954: 'name?',
#  22960: 'php, mysql,',
#  3411: 'and google',
#  13477: 'google maps',
#  18784: 'maps api',
#  3651: 'and state',
#  1315: ':',
#  18767: 'mappedby',
#  31193: 'unknown',
#  28404: 'target',
#  23747: 'property',
#  24619: 'reference an',
#  3186: 'an unknown',
#  4102: 'applet',
#  18574: 'mac',
#  22067: 'os',
#  30300: 'to run',
#  25552: 'run a',
#  1769: 'a java',
#  16828: 'java applet',
#  21463: 'on mac',
#  18577: 'mac os',
#  17797: 'latitude',
#  18490: 'longitude',
#  13162: 'get country',
#  17799: 'latitude longitude',
#  19487: 'mouseout',
#  18206: 'listener',
#  33816: 'wordpress',
#  33870: 'working in',
#  15639: 'in wordpress',
#  11747: 'find',
#  25444: 'row',
#  24160: 'quickly',
#  25471: 'row with',
#  33626: 'with specified',
#  16392: 'iphone',
#  7415: 'command',
#  28496: 'terminal',
#  33879: 'working,',
#  30503: 'to?',
#  7420: 'command from',
#  20560: 'not working,',
#  14073: 'how to?',
#  33047: 'why',
#  25234: 'return',
#  18886: 'matrix',
#  28682: 'that',
#  20033: 'need',
#  29300: 'then',
#  33114: 'will',
#  4635: 'attach',
#  8769: 'dataframe?',
#  33056: 'why does',
#  25237: 'return a',
#  1857: 'a matrix',
#  28705: 'that i',
#  14373: 'i need',
#  20041: 'need to',
#  3675: 'and then',
#  29309: 'then the',
#  33118: 'will not',
#  1602: 'a dataframe?',
#  23648: 'programmatically',
#  15960: 'insert rows',
#  8599: 'd3',
#  17374: 'js',
#  29508: 'tick',
#  27111: 'spacing',
#  4815: 'axis',
#  13313: 'gets',
#  19086: 'messed',
#  31263: 'up',
#  19432: 'month',
#  5431: 'boundary',
#  17375: 'js -',
#  21543: 'on time',
#  19087: 'messed up',
#  31268: 'up by',
#  5750: 'by month',
#  13740: 'hash',
#  8275: 'create a',
#  1738: 'a hash',
#  13745: 'hash or',
#  20788: 'object in',
#  26510: 'set to',
#  31555: 'user',
#  11886: 'fit',
#  6559: 'change default',
#  9772: 'django user',
#  31588: 'user model',
#  19341: 'model to',
#  29939: 'to fit',
#  1384: '=',
#  26289: 'serializing',
#  17471: 'json?',
#  32904: 'when serializing',
#  4765: 'automatically',
#  16016: 'install',
#  11837: 'firefox',
#  33877: 'working with',
#  4726: 'auto',
#  17810: 'layout',
#  13: '"add',
#  16165: 'interactive',
#  16171: 'interface',
#  5564: 'builder',
#  4732: 'auto layout',
#  15171: 'in interface',
#  16173: 'interface builder',
#  17637: 'kill',
#  23562: 'process',
#  28214: 'system',
#  26600: 'shell',
#  17638: 'kill a',
#  1528: 'a child',
#  6817: 'child process',
#  23574: 'process running',
#  25587: 'running a',
#  2158: 'a system',
#  26601: 'shell command',
#  26537: 'setting',
#  29609: 'timezone',
#  6262: "can't",
#  24495: 'recent',
#  26538: 'setting a',
#  1952: 'a php',
#  580: "- can't",
#  6297: "can't update",
#  31319: 'update to',
#  11338: 'facebook',
#  13857: 'help',
#  9363: 'dialog',
#  11339: 'facebook -',
#  762: '- show',
#  26640: 'show a',
#  17146: 'javascript/jquery',
#  10879: 'event',
#  18256: 'load',
#  5521: 'browsers',
#  10896: 'event listener',
#  18209: 'listener on',
#  21429: 'on image',
#  14720: 'image load',
#  12028: 'for all',
#  2844: 'all browsers',
#  821: '->',
#  7781: 'constant',
#  11227: 'expression',
#  25026: 'required"',
#  6402: 'case',
#  7783: 'constant expression',
#  10103: 'dropdown',
#  4944: 'based',
#  10649: 'entries',
#  4948: 'based on',
#  21375: 'on database',
#  33787: "won't",
#  33834: 'work',
#  18340: 'local',
#  18583: 'machine',
#  33796: "won't work",
#  33843: 'work on',
#  21460: 'on local',
#  18347: 'local machine',
#  23910: 'pyqt?',
#  29853: 'to display',
#  9609: 'display data',
#  12753: 'from mysql',
#  8724: 'database in',
#  15535: 'in table',
#  28309: 'table using',
#  2582: 'addeventlistener',
#  16527: 'is not',
#  26167: 'send',
#  29393: 'thread',
#  26174: 'send data',
#  ...}

# %%
######### YOUR CODE HERE #############
'c#' in tfidf_vocab
# Out:
# True

# %% [markdown]
# If you can't find it, we need to understand how did it happen that we lost them? It happened during the built-in tokenization of TfidfVectorizer. Luckily, we can influence on this process. Get back to the function above and use '(\S+)' regexp as a *token_pattern* in the constructor of the vectorizer.

# %% [markdown]
# Now, use this transormation for the data and check again.

# %%
######### YOUR CODE HERE #############

# %% [markdown]
# ### MultiLabel classifier
#
# As we have noticed before, in this task each example can have multiple tags. To deal with such kind of prediction, we need to transform labels in a binary form and the prediction will be a mask of 0s and 1s. For this purpose it is convenient to use [MultiLabelBinarizer](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MultiLabelBinarizer.html) from *sklearn*.

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# %%
mlb = MultiLabelBinarizer(classes=sorted(tags_counts.keys()))
y_train = mlb.fit_transform(y_train)
y_val = mlb.fit_transform(y_val)

# %% [markdown]
# Implement the function *train_classifier* for training a classifier. In this task we suggest to use One-vs-Rest approach, which is implemented in [OneVsRestClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multiclass.OneVsRestClassifier.html) class. In this approach *k* classifiers (= number of tags) are trained. As a basic classifier, use [LogisticRegression](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html). It is one of the simplest methods, but often it performs good enough in text classification tasks. It might take some time, because a number of classifiers to train is large.

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression, RidgeClassifier

# %%
# Out:
# (100000, 100000)

# %%
def train_classifier(X_train, y_train):
    """
      X_train, y_train — training data
      
      return: trained classifier
    """
    
    # Create and fit LogisticRegression wraped into OneVsRestClassifier.
    classifier = OneVsRestClassifier(LogisticRegression()).fit(X_train, y_train)
    ######################################
    ######### YOUR CODE HERE #############
    ######################################
    return classifier
# Out:
# C:\bin\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# OneVsRestClassifier(estimator=LogisticRegression(C=1.0, class_weight=None,
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=100,
#                                                  multi_class='warn',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=None,
#                                                  solver='warn', tol=0.0001,
#                                                  verbose=0, warm_start=False),
#                     n_jobs=None)

# %% [markdown]
# Train the classifiers for different data transformations: *bag-of-words* and *tf-idf*.

# %%
classifier_mybag = train_classifier(X_train_mybag, y_train)
classifier_tfidf = train_classifier(X_train_tfidf, y_train)
# Out:
# C:\bin\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\bin\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %% [markdown]
# Now you can create predictions for the data. You will need two types of predictions: labels and scores.

# %%
y_val_predicted_labels_mybag = classifier_mybag.predict(X_val_mybag)
y_val_predicted_scores_mybag = classifier_mybag.decision_function(X_val_mybag)

y_val_predicted_labels_tfidf = classifier_tfidf.predict(X_val_tfidf)
y_val_predicted_scores_tfidf = classifier_tfidf.decision_function(X_val_tfidf)

# %% [markdown]
# Now take a look at how classifier, which uses TF-IDF, works for a few examples:

# %%
y_val_pred_inversed = mlb.inverse_transform(y_val_predicted_labels_tfidf)
y_val_inversed = mlb.inverse_transform(y_val)
for i in range(3):
    print('Title:\t{}\nTrue labels:\t{}\nPredicted labels:\t{}\n\n'.format(
        X_val[i],
        ','.join(y_val_inversed[i]),
        ','.join(y_val_pred_inversed[i])
    ))
# Out:
# Title:	odbc_exec always fail
# True labels:	php,sql
# Predicted labels:
#
#
# Title:	access base classes variable within child class
# True labels:	javascript
# Predicted labels:
#
#
# Title:	contenttype applicationjson required rails
# True labels:	ruby,ruby-on-rails
# Predicted labels:	ruby-on-rails

# %% [markdown]
# Now, we would need to compare the results of different predictions, e.g. to see whether TF-IDF transformation helps or to try different regularization techniques in logistic regression. For all these experiments, we need to setup evaluation procedure.

# %% [markdown]
# ### Evaluation
#
# To evaluate the results we will use several classification metrics:
#  - [Accuracy](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html)
#  - [F1-score](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html)
#  - [Area under ROC-curve](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html)
#  - [Area under precision-recall curve](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.average_precision_score.html#sklearn.metrics.average_precision_score)
#
# Make sure you are familiar with all of them. How would you expect the things work for the multi-label scenario? Read about micro/macro/weighted averaging following the sklearn links provided above.

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score 
from sklearn.metrics import average_precision_score
from sklearn.metrics import recall_score

# %% [markdown]
# Implement the function *print_evaluation_scores* which calculates and prints to stdout:
#  - *accuracy*
#  - *F1-score macro/micro/weighted*
#  - *Precision macro/micro/weighted*

# %%
def print_evaluation_scores(y_val, predicted):
    
    ######################################
    ######### YOUR CODE HERE #############
    ######################################
    print("accuracy score: %s", accuracy_score(y_val, predicted))
    print("f1 score (macro): %s", f1_score(y_val, predicted, average='macro'))
    print("f1 score (micro): %s", f1_score(y_val, predicted, average='micro'))
    print("f1 score (weighted): %s", f1_score(y_val, predicted, average='weighted'))
    print("ap score (macro): %s", average_precision_score(y_val, predicted, average='macro'))
    print("ap score (micro): %s", average_precision_score(y_val, predicted, average='micro'))
    print("ap score (weighted): %s", average_precision_score(y_val, predicted, average='weighted'))

# %%
print('Bag-of-words')
print_evaluation_scores(y_val, y_val_predicted_labels_mybag)
print('Tfidf')
print_evaluation_scores(y_val, y_val_predicted_labels_tfidf)
# Out:
# Bag-of-words
# accuracy score: %s 0.3564
# f1 score (macro): %s 0.5018073220303733
# f1 score (micro): %s 0.6678280826204883
# f1 score (weighted): %s 0.645512630085386
# ap score (macro): %s 0.3422775648594118
# ap score (micro): %s 0.4776724267088293
# ap score (weighted): %s 0.5073398241878465
# Tfidf
# accuracy score: %s 0.3216
# f1 score (macro): %s 0.4352462159976301
# f1 score (micro): %s 0.6243699247787121
# f1 score (weighted): %s 0.595595444780477
# ap score (macro): %s 0.2919494255235838
# ap score (micro): %s 0.4374882440810693
# ap score (weighted): %s 0.466854463413737

# %% [markdown]
# You might also want to plot some generalization of the [ROC curve](http://scikit-learn.org/stable/modules/model_evaluation.html#receiver-operating-characteristic-roc) for the case of multi-label classification. Provided function *roc_auc* can make it for you. The input parameters of this function are:
#  - true labels
#  - decision functions scores
#  - number of classes

# %%
from metrics import roc_auc
# %matplotlib inline

# %%
n_classes = len(tags_counts)
roc_auc(y_val, y_val_predicted_scores_mybag, n_classes)

# %%
n_classes = len(tags_counts)
roc_auc(y_val, y_val_predicted_scores_tfidf, n_classes)

# %% [markdown]
# **Task 4 (MultilabelClassification).** Once we have the evaluation set up, we suggest that you experiment a bit with training your classifiers. We will use *F1-score weighted* as an evaluation metric. Our recommendation:
# - compare the quality of the bag-of-words and TF-IDF approaches and chose one of them.
# - for the chosen one, try *L1* and *L2*-regularization techniques in Logistic Regression with different coefficients (e.g. C equal to 0.1, 1, 10, 100).
#
# You also could try other improvements of the preprocessing / model, if you want.

# %%
#1. получаем фичи
X_train_tfidf, X_val_tfidf, X_test_tfidf, tfidf_vocab = tfidf_features(X_train, X_val, X_test)
classifier = OneVsRestClassifier(LogisticRegression(penalty='l2', C=10)).fit(X_train_tfidf, y_train)

y_val_predicted_labels = classifier.predict(X_val_tfidf)
y_val_predicted_scores = classifier.decision_function(X_val_tfidf)

print_evaluation_scores(y_val, y_val_predicted_labels)
n_classes = len(tags_counts)
roc_auc(y_val, y_val_predicted_scores_tfidf, n_classes)
# Out:
# C:\bin\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# accuracy score: %s 0.3364
# f1 score (macro): %s 0.4721253110746917
# f1 score (micro): %s 0.6447766823472713
# f1 score (weighted): %s 0.622366346388829
# ap score (macro): %s 0.31004874329108245
# ap score (micro): %s 0.44736474340641985
# ap score (weighted): %s 0.4777154855566256

# %% [markdown]
# When you are happy with the quality, create predictions for *test* set, which you will submit to Coursera.

# %%
test_predictions = classifier.predict(X_test_tfidf)
test_pred_inversed = mlb.inverse_transform(test_predictions)

test_predictions_for_submission = '\n'.join('%i\t%s' % (i, ','.join(row)) for i, row in enumerate(test_pred_inversed))
grader.submit_tag('MultilabelClassification', test_predictions_for_submission)
# Out:
# Current answer for task MultilabelClassification is:
#  0	mysql,php
# 1	javascript,jquery
# 2	python
# 3	javascript,jquery
# 4	android
# 5	php,xml
# 6	json
# 7	java,swing...

# %% [markdown]
# ### Analysis of the most important features

# %% [markdown]
# Finally, it is usually a good idea to look at the features (words or n-grams) that are used with the largest weigths in your logistic regression model.

# %% [markdown]
# Implement the function *print_words_for_tag* to find them. Get back to sklearn documentation on [OneVsRestClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multiclass.OneVsRestClassifier.html) and [LogisticRegression](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html) if needed.

# %%
def print_words_for_tag(classifier, tag, tags_classes, index_to_words, all_words):
    """
        classifier: trained classifier
        tag: particular tag
        tags_classes: a list of classes names from MultiLabelBinarizer
        index_to_words: index_to_words transformation
        all_words: all words in the dictionary
        
        return nothing, just print top 5 positive and top 5 negative words for current tag
    """
    print('Tag:\t{}'.format(tag))
    
    # Extract an estimator from the classifier for the given tag.
    # Extract feature coefficients from the estimator. 
    
    ######################################
    ######### YOUR CODE HERE #############
    ######################################
    
    top_positive_words = # top-5 words sorted by the coefficiens.
    top_negative_words = # bottom-5 words  sorted by the coefficients.
    print('Top positive words:\t{}'.format(', '.join(top_positive_words)))
    print('Top negative words:\t{}\n'.format(', '.join(top_negative_words)))

# %%
print_words_for_tag(classifier_tfidf, 'c', mlb.classes, tfidf_reversed_vocab, ALL_WORDS)
print_words_for_tag(classifier_tfidf, 'c++', mlb.classes, tfidf_reversed_vocab, ALL_WORDS)
print_words_for_tag(classifier_tfidf, 'linux', mlb.classes, tfidf_reversed_vocab, ALL_WORDS)

# %% [markdown]
# ### Authorization & Submission
# To submit assignment parts to Cousera platform, please, enter your e-mail and token into variables below. You can generate token on this programming assignment page. <b>Note:</b> Token expires 30 minutes after generation.

# %%
grader.status()
# Out:
# You want to submit these parts:
# Task TextPrepare:
#  sqlitephp readonly
# creating multiple textboxes dynamically
# self one prefer javascript
# save php date ...
# Task WordsTagsCount:
#  javascript,c#,java
# using,php,java...
# Task BagOfWords:
#  7...
# Task MultilabelClassification:
#  0	mysql,php
# 1	javascript,jquery
# 2	python
# 3	javascript,jquery
# 4	android
# 5	php,xml
# 6	json
# 7	java,swing...

# %%
STUDENT_EMAIL = "groddenator@gmail.com"
STUDENT_TOKEN = "kR7TdC1XeADTmxdK"
grader.status()
# Out:
# You want to submit these parts:
# Task TextPrepare:
#  sqlitephp readonly
# creating multiple textboxes dynamically
# self one prefer javascript
# save php date ...
# Task WordsTagsCount:
#  javascript,c#,java
# using,php,java...
# Task BagOfWords:
#  7...
# Task MultilabelClassification:
#  0	mysql,php
# 1	javascript,jquery
# 2	python
# 3	javascript,jquery
# 4	android
# 5	php,xml
# 6	json
# 7	java,swing...

# %% [markdown]
# If you want to submit these answers, run cell below

# %%
grader.submit(STUDENT_EMAIL, STUDENT_TOKEN)
# Out:
# Submitted to Coursera platform. See results on assignment page!
