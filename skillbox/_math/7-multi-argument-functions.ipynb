# %%
from sympy import *
from sympy.plotting import plot
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = Symbol('x')

# %% [markdown]
# # Задание 1.
# ## 1.
# ### Получите значение MSE меньшее 0.75.

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-2, -1, 0, 1, 2, 3, 3.5, 4, 4.5, 5])
    points_Y = np.array([3, 1, -0.5, 1.2, 2.5, 0.8, -2, -3.5, -3, -5])
    plt.xlim(-10, 10)
    plt.ylim(-5, 5)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

# %%
f1 = 2 * x * sin(2 * x + 5) + 5 * sin(2 * x + 5) + 2
f1
# Out:
# 2*x*sin(2*x + 5) + 5*sin(2*x + 5) + 2

# %%
k, b = symbols('k, b')
#Выберем точкy -1, подставляем вместо x kx+b
#mse = expand((1 - f1.subs(x, -k))**2)
#print("MSE:", mse)
#ddk = diff(mse, k)
#ddb = diff(mse, b)
#print("dMSE/dk:", ddk)
#print("dMSE/db:", ddb)
#solve(ddk, k)
#solve(ddb, b)
#^Ничего это выше не дает, sympy не может в такое

#print(diff(f1))
#solve(diff(f1))
#производную тоже не считает

fn = expand(f1.subs(x, 0.5*x-2.35))-1.5
print(fn)
print_points_ands_function1(fn)
# Out:
# 1.0*x*sin(x + 0.3) + 0.3*sin(x + 0.3) + 0.5
# MSE = 0.5772939653262281

# %% [markdown]
# ## 2.
# ### Получите значение MSE меньшее 0.1.

# %%
def print_points_ands_function2(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([0, 1, 2, 3, 3.5, 4, 4.5, 5, 6, 6.5, 7, 8, 9])
    points_Y = np.array([0.5, 1.2, 0.7, 1.2, 1.1, 0.7, 0.65, 0.9, 0.95, 0.3, 0.8, 0.5, 0.0])
    plt.xlim(-1, 20)
    plt.ylim(-2, 2)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0] + 1, plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

# %%
f2 = sin(sqrt(3) *sqrt(x)) - 1
f2
# Out:
#    /  ___   ___\
# sin\\/ 3 *\/ x / - 1

# %%
x = Symbol("x", real=True)
f2 = sin(sqrt(3)*sqrt(x)) - 1

mse = expand((1.2 - f2.subs(x, k+b))**2)
print("MSE: ", mse)
print("dMSE/dk: ",diff(mse, k))
print("dMSE/db: ", diff(mse, b))
print("dMSE/dk =0 : ", solve(diff(mse, k)))


fn = f2.subs(x, 0.3*x -0.3 + 0.822467033424113)+1.2
print("fn: ", fn)
print_points_ands_function2(fn)

#print_points_ands_function2(f2)
#Последний коэффициент подгонкой
# Out:
# MSE:  sin(sqrt(3)*sqrt(b + k))**2 - 4.4*sin(sqrt(3)*sqrt(b + k)) + 4.84
# dMSE/dk:  sqrt(3)*sin(sqrt(3)*sqrt(b + k))*cos(sqrt(3)*sqrt(b + k))/sqrt(b + k) - 2.2*sqrt(3)*cos(sqrt(3)*sqrt(b + k))/sqrt(b + k)
# dMSE/db:  sqrt(3)*sin(sqrt(3)*sqrt(b + k))*cos(sqrt(3)*sqrt(b + k))/sqrt(b + k) - 2.2*sqrt(3)*cos(sqrt(3)*sqrt(b + k))/sqrt(b + k)
# dMSE/dk =0 :  [{b: 0.822467033424113 - k}, {b: -k + 1.33333333333333*(0.785398163397448 - 0.712708471535306*I)**2}, {b: -k + 1.33333333333333*(0.785398163397448 + 0.712708471535306*I)**2}]
# fn:  sin(sqrt(3)*sqrt(0.3*x + 0.522467033424113)) + 0.2
# MSE = 0.08471665970574326

# %% [markdown]
# # Задание 2.
#
# Постройте графики функций 2 переменных. Найдите их нули и затем постройте графики их нулей, если они не представляют собой выражения вида {x: ...}. <br>
# а) $f(x,y)=xy^2$.
# б) $f(x,y)=y^2sin(\pi x)$.
# в)$f(x,y)=x sin(x) sin(y)$.

# %%
# %matplotlib inline
from sympy.plotting import plot3d

x, y = symbols("x, y")
f = x*y**2

#Ноль в точке (0;0;0)

plot3d(f, (x, -5, 5), (y, -5, 5))

# %%
f1 = y**2*sin(pi*x)
print(solve(f1))

plot3d(f1, (x, -5, 5), (y, -5, 5))
# Out:
# [{x: 0}, {x: 1}, {y: 0}]

# %%
f2 = x*sin(x)*sin(y)
print(solve(f2))
plot3d(f2, (x, -5, 5), (y, -5, 5))
# Out:
# [{x: 0}, {x: pi}, {y: 0}, {y: pi}]

# %% [markdown]
# # Задание 3.
#
#
# ## а)
#
# Дана функция:
# $$f(x_1,x_2,x_3,x_4)=a_4x_4+a_3x_3+a_2x_2+a_1x_1+a_0$$
# Данная функция отвечает на вопрос: “является ли текст спамом или нет?”. Если является, функция возвращает 1, если нет – 0. Переменная $x_1$ равна количеству раз, которое в тексте встретилось в одной из своих форм слово “покупать”. Переменная $x_2$ равна 1, если в тексте есть слово “скидка” и 0 в противном случае. Переменная $x_3$ равна 1, если в тексте есть слово “акция” и 0 в противном случае. $x_4$ равна длине текста в словах.
#
# ### 1. Запишите функцию в виде:
# ``` название функции: область определения → область значений ```
#
# **Ответ:**
# области определения параметров $x_1, x_4$ - целые неотрицаительные числа, $x_2, x_3$ - {0, 1}
# область значений функции f - {0,1}

# %% [markdown]
# ### 2. Какую размерность будет иметь задаваемая этой функцией гиперплоскость?
#
# **Ответ:** 4

# %% [markdown]
# ## б)
#
# Дана функция:
# $$f(x_1,x_2,x_3)=a_3x_3+a_2x_2+a_1x_1+a_0$$
# Данная функция отвечает на вопрос: “с какой вероятностью клиент сделает вклад?”. Переменная $x_1$ равна количеству раз, которое клиент делал вклады ранее. Переменная $x_2$ равна сумме всех этих вкладов. Переменная $x_3$ равна 1, если у клиента есть вклад в данный момент, и 0 в противном случае.
#
# ### 1. Запишите функцию в виде:
# ``` название функции: область определения → область значений ```
#
# **Ответ:**
# области определения параметров $x_1$ - целые неотрицательные числа, $x_2$ - целые неотрицательные числа (если в копейках считаем), или вещественные неотрицательные, $x_3$ - {0, 1}
# область значений функции f - вещественное число из [0,1]

# %% [markdown]
# ### 2. Какую размерность будет иметь задаваемая этой функцией гиперплоскость?
#
# **Ответ:** 3

# %% [markdown]
# ## в)
#
# Дана функция:
# $$f(x_1,x_2,x_3,x_4)=a_4x_4+a_3x_3+a_2x_2+a_1x_1+a_0$$
#
# Данная функция отвечает на вопрос: “болен ли пациент гриппом?”. Переменная $x_1$ равна 1, если пациент привит от гриппа, и 0 в противном случае. Переменная $x_2$ равна температуре пациента. Переменная $x_3$ равна 1, если у пациента есть кашель, и 0 в противном случае. $x_4$ равна 1, если у пациента есть насморк, и 0 в противном случае.
#
# ### 1. Запишите функцию в виде:
# ``` название функции: область определения → область значений ```
#
# **Ответ:**
# области определения параметров $x_1, x_3, x_4$ - {0, 1}, $x_2$ - вещественные неотрицательные числа
# область значений функции f - {0, 1} или вещественная вероятность из [0, 1]

# %% [markdown]
# ### 2. Какую размерность будет иметь задаваемая этой функцией гиперплоскость?
#
# **Ответ:** если ответ дискретный, то говорить о гиперплоскости бессмысленно, если же вещественный, то 4.
