# %% [markdown]
# # Экзамен по курсу "Аналитика данных на Python"

# %% [markdown]
# Этот тест проверит Ваши навыки работы с таблицами данных с помощью библиотек pandas и numpy. Задания делятся на простые (⭐️), средние (⭐️⭐️) и сложные (⭐️⭐️⭐️). Решение простых заданий, как правило, требует одной-двух операций с таблицами, тогда как для более сложных может потребоваться несколько последовательных преобразований данных.

# %% [markdown]
# ##  Предыстория

# %% [markdown]
# Сегодня Ваш первый день работы в крупном интернет-магазине, который продаёт товары с доставкой по всему миру. Ваша первая задача – проанализировать базу данных покупок, совершённых в магазине за последние несколько лет. База содержит информацию об отдельных транзакциях, про каждую из которых известны номер инвойса (InvoiceNo), дата инвойса(InvoiceDate), код товара (StockCode), описание товара(Description), количество товара в транзакции (Quantity), стоимость единицы товара (UnitPrice), код покупателя (CustomerID), страна покупателя (Country).
#
# База выгружена для Вас в формате CSV: файл [```online-retail.csv```](https://drive.google.com/file/d/1O1oJtpEu-u6s6xTu7seQfnNcQjYCt0GF/view?usp=sharing)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## ⭐️ Вопрос 1
#
# Загрузите данные из файла online-retail.csv в переменную типа pandas DataFrame
#
# Подсказка: Используйте функцию из библиотеки pandas
#
# Какой символ-разделитель используется в этом файле?
#
# * Запятая ","
# * Двоеточие ":"
# * Точка с запятой ";"
# * Символ табуляции "tab"

# %% [markdown]
# #### Решение

# %%
df = pd.read_csv("online_retail.csv", sep=";")
df.head()

#В качестве разделителя идет символ ';'
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4  2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# ## ⭐️ Вопрос 2
#
# Сколько строк в полученной таблице (не считая заголовков столбцов)?

# %% [markdown]
# #### Решение

# %%
len(df)
# Out:
# 541911

# %% [markdown]
# ## ⭐️ Вопрос 3
#
# Сколько столбцов в полученной таблице (не считая индекса)?

# %% [markdown]
# #### Решение

# %%
len(df.columns)
# Out:
# 8

# %% [markdown]
# ## ⭐️ Вопрос 4
#
# Как называется столбец с самым коротким названием?

# %% [markdown]
# #### Решение

# %%
df.columns[np.argmin(list(map(len, df.columns)))]
# Out:
# 'Country'

# %% [markdown]
# ## ⭐️ Вопрос 5
#
# В скольких столбцах встречаются пропущенные значения? (ответ - целое число)

# %% [markdown]
# #### Решение

# %%
len([col for col in df.columns if df[col].hasnans])
# Out:
# 2

# %% [markdown]
# ## ⭐️ Вопрос 6
#
# Сколько пропущенных значений в столбце CustomerID? (ответ - целое число)

# %% [markdown]
# #### Решение

# %%
df["CustomerID"].isnull().sum(axis=0)
# Out:
# 135080

# %% [markdown]
# ## ⭐️⭐️ Вопрос 7
#
# Посмотрим, данные за какой исторический период у нас есть.
#
# Данные за какой самый ранний и за какой самый поздний годы содержатся в датасете? В ответе укажите два целых числа через запятую.

# %% [markdown]
# #### Решение

# %%
from datetime import *
datetime.strptime(np.min(df["InvoiceDate"]), "%Y-%m-%d %H:%M:%S").year, datetime.strptime(np.max(df["InvoiceDate"]), "%Y-%m-%d %H:%M:%S").year
# Out:
# (2010, 2011)

# %% [markdown]
# ## ⭐️ Вопрос 8
#
# Каковы минимальная и максимальная цена товаров (UnitPrice)? Перечислите через запятую. Цена в этом задании может принимать отрицательные значения.

# %% [markdown]
# #### Решение

# %%
np.min(df["UnitPrice"]),
np.max(df["UnitPrice"])
# Out:
# (-11062.06, 38970.0)

# %% [markdown]
# ## ⭐️ Вопрос 9
#
# В таблице оказались товары с отрицательными ценами! Это явно какая-то ошибка. Какое описание (Description) у таких транзакций? Перечислите все варианты через запятую, отсортировав строки по алфавиту.

# %% [markdown]
# #### Решение

# %%
l = list(df[df["UnitPrice"]<0]["Description"].unique())
l.sort()
print(l)

df[df["UnitPrice"]<0]
# Out:
# ['Adjust bad debt']
#        InvoiceNo StockCode      Description  Quantity          InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1  2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1  2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %% [markdown]
# ## ⭐️ Вопрос 10
#
# Поищем ещё возможные проблемы с данными. Как насчёт товаров с нулевыми ценами?
#
# Сколько в таблице транзакций с нулевой ценой? А с пропусками на месте цены?
#
# Перечислите два целых числа через запятую.

# %% [markdown]
# #### Решение

# %%
len(df[df["UnitPrice"] == 0]), df["UnitPrice"].isnull().sum(axis=0)
# Out:
# (2515, 0)

# %% [markdown]
# ## ⭐️⭐️ Вопрос 11
#
# Для дальнейшего анализа поведения покупателей нам понадобится набор данных, в которых у каждой транзакции корректно указана цена, количество единиц товара (Quantity) и id покупателя (CustomerID). Удалите из таблицы все строки, в которых цена не превосходит 0 или пропущена, или количество единиц товара не превосходит 0 или пропущено, или в которых пропущен id покупателя.
#
# Сколько строк осталось?

# %% [markdown]
# #### Решение

# %%
df2 = df[(df["UnitPrice"].notnull()) & (df["UnitPrice"] > 0) & \
         (df["CustomerID"].notnull()) & (df["Quantity"].notnull()) & (df["Quantity"]>0)]
len(df2)
# Out:
# 397886

# %% [markdown]
# ## Внимание!
#
# ### Везде далее мы работаем с очищенной таблицей, полученной в Вопросе 11.

# %% [markdown]
# ## ⭐️⭐️ Вопрос 12
#
# В таблице для каждой транзакции указаны цена за единицу товара (UnitPrice) и количество единиц товара (Quantity). Вычислите для каждой транзакции её **полную стоимость** и сохраните в новом столбце Price, который добавьте в таблицу.
#
# Каковы минимальная и максимальная полная стоимость транзакций? Перечислите через запятую, округлив до целых чисел.

# %% [markdown]
# #### Решение

# %%
df2["Price"] = df2["UnitPrice"] * df2["Quantity"]
df2.head()

min(df2["Price"]), max(df2["Price"])
# Out:
# <ipython-input-7-a8169a5ba010>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Price"] = df2["UnitPrice"] * df2["Quantity"]
# (0.001, 168469.6)

# %% [markdown]
# ## ⭐️⭐️ Вопрос 13
#
# В нашей базе данных каждая покупка представлена одной или несколькими транзакциями. Покупка однозначно определяется своим номером инвойса (InvoiceNo). Транзакции, относящиеся к одной покупке, имеют один и тот же InvoiceNo.
#
# Стоимость всей покупки равна сумме полных стоимостей транзакций, входящих в неё. Найдите стоимости трёх самых дорогих покупок. Перечислите через запятую в порядке убывания, округлив до целых чисел.

# %% [markdown]
# #### Решение

# %%
list(map(int, df2[["InvoiceNo", "Price"]].groupby("InvoiceNo").agg("sum").sort_values("Price", ascending=False)["Price"][:3]))
# Out:
# [168469, 77183, 38970]

# %% [markdown]
# ## ⭐️⭐️ Вопрос 14
#
# Какой товар составил наибольшую выручку? В ответе укажите описание товара (дословно строку из соответствующего поля в столбце Description).

# %% [markdown]
# #### Решение

# %%
row = df2[["Description", "Price"]].groupby(["Description"]).agg("sum").sort_values("Price", ascending=False)[:1]
row
# Out:
#                                 Price
# Description
# PAPER CRAFT , LITTLE BIRDIE  168469.6

# %% [markdown]
# ## ⭐️⭐️ Вопрос 15
#
# Создайте новую таблицу purchases, в которой каждая строка будет соответствовать отдельной покупке, со столбцами
# InvoiceNo, InvoiceDate, Price, CustomerID, Country.
#
# Поскольку дата InvoiceDate может быть отличаться для разных транзакций внутри одной покупки, при группировке возьмите самую раннюю из дат. Также отсортируйте её по датам по возрастанию.
#
# Сколько получилось строк?

# %% [markdown]
# #### Решение

# %%
purchases = pd.DataFrame(df2[["InvoiceNo", "InvoiceDate", "CustomerID", "Country",  "Price"]]\
.groupby(["InvoiceNo", "CustomerID", "Country"]).agg({"InvoiceDate" : lambda x: np.min(x), "Price": "sum"}))

print(len(purchases))
# Out:
# 18533

# %% [markdown]
# ## ⭐️⭐️ Вопрос 16
#
# Исследуем, растут или убывают покупки наших клиентов после их первой покупки на сайте.
# Найдите среднюю цену первых покупок клиентов: для каждого клиента возьмите его первую покупку и усредните эти значения. Найдите среднюю цену покупок в целом. Округлите эти числа до целых и перечислите в этом порядке через запятую.

# %% [markdown]
# #### Решение

# %%
#Переведем индексные колонки обратно в обыкновенные
purchases.reset_index(level=0, inplace=True)
purchases.reset_index(level=0, inplace=True)
purchases.reset_index(level=0, inplace=True)
purchases.columns
# Out:
# Index(['Country', 'CustomerID', 'InvoiceNo', 'InvoiceDate', 'Price'], dtype='object')

# %%
first_purchases = []
for customerId in list(purchases["CustomerID"].unique()):
    first_purchases.append(purchases[purchases["CustomerID"] == customerId].sort_values("InvoiceDate")["Price"].values[0])

first_purchases_mean = np.mean(first_purchases)

all_purchases_mean = purchases["Price"].mean()

first_purchases_mean, all_purchases_mean
# Out:
# (425.6565244352236, 480.8420495332635)

# %% [markdown]
# ## ⭐️⭐️⭐️ Вопрос 17
#
# В какой день недели было наибольшее число покупок? В ответе укажите русское название дня недели, начинающееся с заглавной буквы.
#
#
# Подсказка:
# * Преобразуйте тип данных в столбце InvoiceDate таблицы purchases из строк в datetime.
# * Для каждой покупки вычислите день недели, в который она была совершена. Сохраните в новый столбец.
# * Сгруппируйте таблицу по дням недели.

# %% [markdown]
# #### Решение

# %%
from datetime import datetime 
WEEKDAYS = ["Понедельник", "Вторник", "Среда", "Четверг", "Пятница", "Суббота", "Воскресенье"]

purchases["InvoiceDateDt"] = purchases["InvoiceDate"].apply(lambda x : datetime.strptime(x, "%Y-%m-%d %H:%M:%S"))
purchases["InvoiceDateWeekDay"] = purchases["InvoiceDateDt"].apply(lambda x: WEEKDAYS[x.weekday()])

purchases_by_weekdays = purchases.groupby(["InvoiceDateWeekDay"]).agg({"InvoiceNo": "count"}).sort_values("InvoiceNo", ascending=False)
purchases_by_weekdays.head()
# Out:
#                     InvoiceNo
# InvoiceDateWeekDay
# Четверг                  4032
# Среда                    3455
# Вторник                  3184
# Понедельник              2863
# Пятница                  2830

# %% [markdown]
# ## ⭐️⭐️⭐️ Вопрос 18
#
# В какой год и месяц выручка была максимальной?
#
# Подсказка:
# * Преобразуйте тип данных в столбце InvoiceDate таблицы purchases из строк в datetime.
# * Для каждой покупки вычислите год и месяц, в которые она была совершена. Сохраните в новые столбцы.
# * Сгруппируйте таблицу по новым столбцам
#
# В ответе укажите два целых числа через запятую: год, месяц

# %% [markdown]
# #### Решение

# %%
purchases["Year"] = purchases["InvoiceDateDt"].apply(lambda x: x.year)
purchases["Month"] = purchases["InvoiceDateDt"].apply(lambda x: x.month)

purchases_by_yearmonths = purchases.groupby(["Year", "Month"]).agg({"Price": "sum"}).sort_values("Price", ascending=False)
list(purchases_by_yearmonths[:1].index)[0]
# Out:
# (2011, 11)

# %% [markdown]
# ## ⭐️⭐️⭐️ Вопрос 19
#
# Магазин продаёт товары покупателям из разных стран (Country). В какой стране был наибольший процентный рост месячных продаж, если сравнить март 2011 и сентябрь 2011? Сколько процентов составил этот рост? В расчёт брать только страны, в которых были ненулевые продажи в обоих этих месяцах. В ответе укажите через запятую название страны и целое число (процентный рост, округлённый до целого числа).

# %% [markdown]
# #### Решение

# %%
purchases_compare = purchases[(purchases["Year"] == 2011) & ((purchases["Month"] == 3) | (purchases["Month"] == 9))][["Country", "Month", "Price"]]
#группируем первый раз по месяцам
purchases_grouped = purchases_compare.groupby(["Country", "Month"]).agg({"Price": "sum"})
#группируем второй раз по процентному соотношению
row = purchases_grouped.groupby("Country").agg({"Price": lambda x: (np.max(x)/np.min(x) - 1.0)*100}).sort_values("Price", ascending=False)[:1]

row.index[0], row.values[0][0]
# Out:
# ('Norway', 585.914123811556)

# %% [markdown]
# ## ⭐️⭐️⭐️ Вопрос 20
#
# Большинство клиентов все свои покупки делают из одной и той же страны. Выясним, однако, насколько велика доля путешественников среди клиентов.
# Сколько клиентов сделали покупки по крайней мере из двух разных стран? (ответ - целое число)

# %% [markdown]
# #### Решение

# %%
grouped = purchases.groupby(["CustomerID"]).agg({"Country": lambda x: len(set(x))})
len(grouped[grouped["Country"] > 1])
# Out:
# 8

# %% [markdown]
# ## ⭐️⭐️⭐️ Вопрос 21
#
# Мы запускаем в Италии рекомендательную систему "С этим товаром часто покупают...", и для этого хотим узнать, какие различные товары чаще всего встречаются в одной покупке из этой страны. Определите, какая пара различных товаров чаще всего встречается в различных покупках с ```Country=='Italy'```, и в скольких покупках это происходит. Одинаковые товары или нет, проверяйте по равенству поля Description.
#
# (ответ: название (Description) первого товара, название (Description) второго товара, целое число)

# %% [markdown]
# #### Решение

# %%
from itertools import combinations
from collections import Counter

filtered = df2[df2["Country"] == "Italy"]
#Создаем из дескрипшнов одной покупки множество
grouped = filtered[["InvoiceNo", "Description"]].groupby("InvoiceNo").agg({"Description": lambda x: set(x)})
sets = list(grouped["Description"].values)

#Выведем комбинации из двух пар для всех покупок
combi = [list(combinations(s, 2)) for s in sets]
combi
# Out:
# [[('6 CHOCOLATE LOVE HEART T-LIGHTS', 'SILVER GLITTER FLOWER VOTIVE HOLDER'),
#   ('6 CHOCOLATE LOVE HEART T-LIGHTS', 'BLUE FLOCK GLASS CANDLEHOLDER'),
#   ('6 CHOCOLATE LOVE HEART T-LIGHTS', 'ROSE SCENT CANDLE IN JEWELLED BOX'),
#   ('6 CHOCOLATE LOVE HEART T-LIGHTS', 'GOLD MUG BONE CHINA TREE OF LIFE'),
#   ('6 CHOCOLATE LOVE HEART T-LIGHTS', 'SET OF 6 T-LIGHTS SANTA'),
#   ('6 CHOCOLATE LOVE HEART T-LIGHTS', 'GARDENIA 3 WICK MORRIS BOXED CANDLE'),
#   ('6 CHOCOLATE LOVE HEART T-LIGHTS', 'SET/3 VANILLA SCENTED CANDLE IN BOX'),
#   ('6 CHOCOLATE LOVE HEART T-LIGHTS', 'CHOCOLATE 1 WICK MORRIS BOX CANDLE'),
#   ('6 CHOCOLATE LOVE HEART T-LIGHTS', 'GREEN REGENCY TEACUP AND SAUCER'),
#   ('6 CHOCOLATE LOVE HEART T-LIGHTS', '3 GARDENIA MORRIS BOXED CANDLES'),
#   ('6 CHOCOLATE LOVE HEART T-LIGHTS', 'POSTAGE'),
#   ('6 CHOCOLATE LOVE HEART T-LIGHTS', 'CHARLIE+LOLA RED HOT WATER BOTTLE'),
#   ('6 CHOCOLATE LOVE HEART T-LIGHTS', 'GRAND CHOCOLATECANDLE'),
#   ('6 CHOCOLATE LOVE HEART T-LIGHTS', 'PINK BAROQUE FLOCK CANDLE HOLDER'),
#   ('6 CHOCOLATE LOVE HEART T-LIGHTS', 'CHOCOLATE 3 WICK MORRIS BOX CANDLE'),
#   ('6 CHOCOLATE LOVE HEART T-LIGHTS', 'SCANDINAVIAN 3 HEARTS NAPKIN RING'),
#   ('6 CHOCOLATE LOVE HEART T-LIGHTS', 'PORCELAIN T-LIGHT HOLDERS ASSORTED'),
#   ('6 CHOCOLATE LOVE HEART T-LIGHTS', 'T-LIGHT GLASS FLUTED ANTIQUE'),
#   ('6 CHOCOLATE LOVE HEART T-LIGHTS', 'SET OF 6 T-LIGHTS SNOWMEN'),
#   ('6 CHOCOLATE LOVE HEART T-LIGHTS', 'SCENTED VELVET LOUNGE CANDLE'),
#   ('6 CHOCOLATE LOVE HEART T-LIGHTS', '3 ROSE MORRIS BOXED CANDLES'),
#   ('6 CHOCOLATE LOVE HEART T-LIGHTS', 'ROSE 3 WICK MORRIS BOX CANDLE'),
#   ('6 CHOCOLATE LOVE HEART T-LIGHTS', 'ROSE SCENT CANDLE JEWELLED DRAWER'),
#   ('SILVER GLITTER FLOWER VOTIVE HOLDER', 'BLUE FLOCK GLASS CANDLEHOLDER'),
#   ('SILVER GLITTER FLOWER VOTIVE HOLDER', 'ROSE SCENT CANDLE IN JEWELLED BOX'),
#   ('SILVER GLITTER FLOWER VOTIVE HOLDER', 'GOLD MUG BONE CHINA TREE OF LIFE'),
#   ('SILVER GLITTER FLOWER VOTIVE HOLDER', 'SET OF 6 T-LIGHTS SANTA'),
#   ('SILVER GLITTER FLOWER VOTIVE HOLDER',
#    'GARDENIA 3 WICK MORRIS BOXED CANDLE'),
#   ('SILVER GLITTER FLOWER VOTIVE HOLDER',
#    'SET/3 VANILLA SCENTED CANDLE IN BOX'),
#   ('SILVER GLITTER FLOWER VOTIVE HOLDER',
#    'CHOCOLATE 1 WICK MORRIS BOX CANDLE'),
#   ('SILVER GLITTER FLOWER VOTIVE HOLDER', 'GREEN REGENCY TEACUP AND SAUCER'),
#   ('SILVER GLITTER FLOWER VOTIVE HOLDER', '3 GARDENIA MORRIS BOXED CANDLES'),
#   ('SILVER GLITTER FLOWER VOTIVE HOLDER', 'POSTAGE'),
#   ('SILVER GLITTER FLOWER VOTIVE HOLDER', 'CHARLIE+LOLA RED HOT WATER BOTTLE'),
#   ('SILVER GLITTER FLOWER VOTIVE HOLDER', 'GRAND CHOCOLATECANDLE'),
#   ('SILVER GLITTER FLOWER VOTIVE HOLDER', 'PINK BAROQUE FLOCK CANDLE HOLDER'),
#   ('SILVER GLITTER FLOWER VOTIVE HOLDER',
#    'CHOCOLATE 3 WICK MORRIS BOX CANDLE'),
#   ('SILVER GLITTER FLOWER VOTIVE HOLDER', 'SCANDINAVIAN 3 HEARTS NAPKIN RING'),
#   ('SILVER GLITTER FLOWER VOTIVE HOLDER',
#    'PORCELAIN T-LIGHT HOLDERS ASSORTED'),
#   ('SILVER GLITTER FLOWER VOTIVE HOLDER', 'T-LIGHT GLASS FLUTED ANTIQUE'),
#   ('SILVER GLITTER FLOWER VOTIVE HOLDER', 'SET OF 6 T-LIGHTS SNOWMEN'),
#   ('SILVER GLITTER FLOWER VOTIVE HOLDER', 'SCENTED VELVET LOUNGE CANDLE'),
#   ('SILVER GLITTER FLOWER VOTIVE HOLDER', '3 ROSE MORRIS BOXED CANDLES'),
#   ('SILVER GLITTER FLOWER VOTIVE HOLDER', 'ROSE 3 WICK MORRIS BOX CANDLE'),
#   ('SILVER GLITTER FLOWER VOTIVE HOLDER', 'ROSE SCENT CANDLE JEWELLED DRAWER'),
#   ('BLUE FLOCK GLASS CANDLEHOLDER', 'ROSE SCENT CANDLE IN JEWELLED BOX'),
#   ('BLUE FLOCK GLASS CANDLEHOLDER', 'GOLD MUG BONE CHINA TREE OF LIFE'),
#   ('BLUE FLOCK GLASS CANDLEHOLDER', 'SET OF 6 T-LIGHTS SANTA'),
#   ('BLUE FLOCK GLASS CANDLEHOLDER', 'GARDENIA 3 WICK MORRIS BOXED CANDLE'),
#   ('BLUE FLOCK GLASS CANDLEHOLDER', 'SET/3 VANILLA SCENTED CANDLE IN BOX'),
#   ('BLUE FLOCK GLASS CANDLEHOLDER', 'CHOCOLATE 1 WICK MORRIS BOX CANDLE'),
#   ('BLUE FLOCK GLASS CANDLEHOLDER', 'GREEN REGENCY TEACUP AND SAUCER'),
#   ('BLUE FLOCK GLASS CANDLEHOLDER', '3 GARDENIA MORRIS BOXED CANDLES'),
#   ('BLUE FLOCK GLASS CANDLEHOLDER', 'POSTAGE'),
#   ('BLUE FLOCK GLASS CANDLEHOLDER', 'CHARLIE+LOLA RED HOT WATER BOTTLE'),
#   ('BLUE FLOCK GLASS CANDLEHOLDER', 'GRAND CHOCOLATECANDLE'),
#   ('BLUE FLOCK GLASS CANDLEHOLDER', 'PINK BAROQUE FLOCK CANDLE HOLDER'),
#   ('BLUE FLOCK GLASS CANDLEHOLDER', 'CHOCOLATE 3 WICK MORRIS BOX CANDLE'),
#   ('BLUE FLOCK GLASS CANDLEHOLDER', 'SCANDINAVIAN 3 HEARTS NAPKIN RING'),
#   ('BLUE FLOCK GLASS CANDLEHOLDER', 'PORCELAIN T-LIGHT HOLDERS ASSORTED'),
#   ('BLUE FLOCK GLASS CANDLEHOLDER', 'T-LIGHT GLASS FLUTED ANTIQUE'),
#   ('BLUE FLOCK GLASS CANDLEHOLDER', 'SET OF 6 T-LIGHTS SNOWMEN'),
#   ('BLUE FLOCK GLASS CANDLEHOLDER', 'SCENTED VELVET LOUNGE CANDLE'),
#   ('BLUE FLOCK GLASS CANDLEHOLDER', '3 ROSE MORRIS BOXED CANDLES'),
#   ('BLUE FLOCK GLASS CANDLEHOLDER', 'ROSE 3 WICK MORRIS BOX CANDLE'),
#   ('BLUE FLOCK GLASS CANDLEHOLDER', 'ROSE SCENT CANDLE JEWELLED DRAWER'),
#   ('ROSE SCENT CANDLE IN JEWELLED BOX', 'GOLD MUG BONE CHINA TREE OF LIFE'),
#   ('ROSE SCENT CANDLE IN JEWELLED BOX', 'SET OF 6 T-LIGHTS SANTA'),
#   ('ROSE SCENT CANDLE IN JEWELLED BOX', 'GARDENIA 3 WICK MORRIS BOXED CANDLE'),
#   ('ROSE SCENT CANDLE IN JEWELLED BOX', 'SET/3 VANILLA SCENTED CANDLE IN BOX'),
#   ('ROSE SCENT CANDLE IN JEWELLED BOX', 'CHOCOLATE 1 WICK MORRIS BOX CANDLE'),
#   ('ROSE SCENT CANDLE IN JEWELLED BOX', 'GREEN REGENCY TEACUP AND SAUCER'),
#   ('ROSE SCENT CANDLE IN JEWELLED BOX', '3 GARDENIA MORRIS BOXED CANDLES'),
#   ('ROSE SCENT CANDLE IN JEWELLED BOX', 'POSTAGE'),
#   ('ROSE SCENT CANDLE IN JEWELLED BOX', 'CHARLIE+LOLA RED HOT WATER BOTTLE'),
#   ('ROSE SCENT CANDLE IN JEWELLED BOX', 'GRAND CHOCOLATECANDLE'),
#   ('ROSE SCENT CANDLE IN JEWELLED BOX', 'PINK BAROQUE FLOCK CANDLE HOLDER'),
#   ('ROSE SCENT CANDLE IN JEWELLED BOX', 'CHOCOLATE 3 WICK MORRIS BOX CANDLE'),
#   ('ROSE SCENT CANDLE IN JEWELLED BOX', 'SCANDINAVIAN 3 HEARTS NAPKIN RING'),
#   ('ROSE SCENT CANDLE IN JEWELLED BOX', 'PORCELAIN T-LIGHT HOLDERS ASSORTED'),
#   ('ROSE SCENT CANDLE IN JEWELLED BOX', 'T-LIGHT GLASS FLUTED ANTIQUE'),
#   ('ROSE SCENT CANDLE IN JEWELLED BOX', 'SET OF 6 T-LIGHTS SNOWMEN'),
#   ('ROSE SCENT CANDLE IN JEWELLED BOX', 'SCENTED VELVET LOUNGE CANDLE'),
#   ('ROSE SCENT CANDLE IN JEWELLED BOX', '3 ROSE MORRIS BOXED CANDLES'),
#   ('ROSE SCENT CANDLE IN JEWELLED BOX', 'ROSE 3 WICK MORRIS BOX CANDLE'),
#   ('ROSE SCENT CANDLE IN JEWELLED BOX', 'ROSE SCENT CANDLE JEWELLED DRAWER'),
#   ('GOLD MUG BONE CHINA TREE OF LIFE', 'SET OF 6 T-LIGHTS SANTA'),
#   ('GOLD MUG BONE CHINA TREE OF LIFE', 'GARDENIA 3 WICK MORRIS BOXED CANDLE'),
#   ('GOLD MUG BONE CHINA TREE OF LIFE', 'SET/3 VANILLA SCENTED CANDLE IN BOX'),
#   ('GOLD MUG BONE CHINA TREE OF LIFE', 'CHOCOLATE 1 WICK MORRIS BOX CANDLE'),
#   ('GOLD MUG BONE CHINA TREE OF LIFE', 'GREEN REGENCY TEACUP AND SAUCER'),
#   ('GOLD MUG BONE CHINA TREE OF LIFE', '3 GARDENIA MORRIS BOXED CANDLES'),
#   ('GOLD MUG BONE CHINA TREE OF LIFE', 'POSTAGE'),
#   ('GOLD MUG BONE CHINA TREE OF LIFE', 'CHARLIE+LOLA RED HOT WATER BOTTLE'),
#   ('GOLD MUG BONE CHINA TREE OF LIFE', 'GRAND CHOCOLATECANDLE'),
#   ('GOLD MUG BONE CHINA TREE OF LIFE', 'PINK BAROQUE FLOCK CANDLE HOLDER'),
#   ('GOLD MUG BONE CHINA TREE OF LIFE', 'CHOCOLATE 3 WICK MORRIS BOX CANDLE'),
#   ('GOLD MUG BONE CHINA TREE OF LIFE', 'SCANDINAVIAN 3 HEARTS NAPKIN RING'),
#   ('GOLD MUG BONE CHINA TREE OF LIFE', 'PORCELAIN T-LIGHT HOLDERS ASSORTED'),
#   ('GOLD MUG BONE CHINA TREE OF LIFE', 'T-LIGHT GLASS FLUTED ANTIQUE'),
#   ('GOLD MUG BONE CHINA TREE OF LIFE', 'SET OF 6 T-LIGHTS SNOWMEN'),
#   ('GOLD MUG BONE CHINA TREE OF LIFE', 'SCENTED VELVET LOUNGE CANDLE'),
#   ('GOLD MUG BONE CHINA TREE OF LIFE', '3 ROSE MORRIS BOXED CANDLES'),
#   ('GOLD MUG BONE CHINA TREE OF LIFE', 'ROSE 3 WICK MORRIS BOX CANDLE'),
#   ('GOLD MUG BONE CHINA TREE OF LIFE', 'ROSE SCENT CANDLE JEWELLED DRAWER'),
#   ('SET OF 6 T-LIGHTS SANTA', 'GARDENIA 3 WICK MORRIS BOXED CANDLE'),
#   ('SET OF 6 T-LIGHTS SANTA', 'SET/3 VANILLA SCENTED CANDLE IN BOX'),
#   ('SET OF 6 T-LIGHTS SANTA', 'CHOCOLATE 1 WICK MORRIS BOX CANDLE'),
#   ('SET OF 6 T-LIGHTS SANTA', 'GREEN REGENCY TEACUP AND SAUCER'),
#   ('SET OF 6 T-LIGHTS SANTA', '3 GARDENIA MORRIS BOXED CANDLES'),
#   ('SET OF 6 T-LIGHTS SANTA', 'POSTAGE'),
#   ('SET OF 6 T-LIGHTS SANTA', 'CHARLIE+LOLA RED HOT WATER BOTTLE'),
#   ('SET OF 6 T-LIGHTS SANTA', 'GRAND CHOCOLATECANDLE'),
#   ('SET OF 6 T-LIGHTS SANTA', 'PINK BAROQUE FLOCK CANDLE HOLDER'),
#   ('SET OF 6 T-LIGHTS SANTA', 'CHOCOLATE 3 WICK MORRIS BOX CANDLE'),
#   ('SET OF 6 T-LIGHTS SANTA', 'SCANDINAVIAN 3 HEARTS NAPKIN RING'),
#   ('SET OF 6 T-LIGHTS SANTA', 'PORCELAIN T-LIGHT HOLDERS ASSORTED'),
#   ('SET OF 6 T-LIGHTS SANTA', 'T-LIGHT GLASS FLUTED ANTIQUE'),
#   ('SET OF 6 T-LIGHTS SANTA', 'SET OF 6 T-LIGHTS SNOWMEN'),
#   ('SET OF 6 T-LIGHTS SANTA', 'SCENTED VELVET LOUNGE CANDLE'),
#   ('SET OF 6 T-LIGHTS SANTA', '3 ROSE MORRIS BOXED CANDLES'),
#   ('SET OF 6 T-LIGHTS SANTA', 'ROSE 3 WICK MORRIS BOX CANDLE'),
#   ('SET OF 6 T-LIGHTS SANTA', 'ROSE SCENT CANDLE JEWELLED DRAWER'),
#   ('GARDENIA 3 WICK MORRIS BOXED CANDLE',
#    'SET/3 VANILLA SCENTED CANDLE IN BOX'),
#   ('GARDENIA 3 WICK MORRIS BOXED CANDLE',
#    'CHOCOLATE 1 WICK MORRIS BOX CANDLE'),
#   ('GARDENIA 3 WICK MORRIS BOXED CANDLE', 'GREEN REGENCY TEACUP AND SAUCER'),
#   ('GARDENIA 3 WICK MORRIS BOXED CANDLE', '3 GARDENIA MORRIS BOXED CANDLES'),
#   ('GARDENIA 3 WICK MORRIS BOXED CANDLE', 'POSTAGE'),
#   ('GARDENIA 3 WICK MORRIS BOXED CANDLE', 'CHARLIE+LOLA RED HOT WATER BOTTLE'),
#   ('GARDENIA 3 WICK MORRIS BOXED CANDLE', 'GRAND CHOCOLATECANDLE'),
#   ('GARDENIA 3 WICK MORRIS BOXED CANDLE', 'PINK BAROQUE FLOCK CANDLE HOLDER'),
#   ('GARDENIA 3 WICK MORRIS BOXED CANDLE',
#    'CHOCOLATE 3 WICK MORRIS BOX CANDLE'),
#   ('GARDENIA 3 WICK MORRIS BOXED CANDLE', 'SCANDINAVIAN 3 HEARTS NAPKIN RING'),
#   ('GARDENIA 3 WICK MORRIS BOXED CANDLE',
#    'PORCELAIN T-LIGHT HOLDERS ASSORTED'),
#   ('GARDENIA 3 WICK MORRIS BOXED CANDLE', 'T-LIGHT GLASS FLUTED ANTIQUE'),
#   ('GARDENIA 3 WICK MORRIS BOXED CANDLE', 'SET OF 6 T-LIGHTS SNOWMEN'),
#   ('GARDENIA 3 WICK MORRIS BOXED CANDLE', 'SCENTED VELVET LOUNGE CANDLE'),
#   ('GARDENIA 3 WICK MORRIS BOXED CANDLE', '3 ROSE MORRIS BOXED CANDLES'),
#   ('GARDENIA 3 WICK MORRIS BOXED CANDLE', 'ROSE 3 WICK MORRIS BOX CANDLE'),
#   ('GARDENIA 3 WICK MORRIS BOXED CANDLE', 'ROSE SCENT CANDLE JEWELLED DRAWER'),
#   ('SET/3 VANILLA SCENTED CANDLE IN BOX',
#    'CHOCOLATE 1 WICK MORRIS BOX CANDLE'),
#   ('SET/3 VANILLA SCENTED CANDLE IN BOX', 'GREEN REGENCY TEACUP AND SAUCER'),
#   ('SET/3 VANILLA SCENTED CANDLE IN BOX', '3 GARDENIA MORRIS BOXED CANDLES'),
#   ('SET/3 VANILLA SCENTED CANDLE IN BOX', 'POSTAGE'),
#   ('SET/3 VANILLA SCENTED CANDLE IN BOX', 'CHARLIE+LOLA RED HOT WATER BOTTLE'),
#   ('SET/3 VANILLA SCENTED CANDLE IN BOX', 'GRAND CHOCOLATECANDLE'),
#   ('SET/3 VANILLA SCENTED CANDLE IN BOX', 'PINK BAROQUE FLOCK CANDLE HOLDER'),
#   ('SET/3 VANILLA SCENTED CANDLE IN BOX',
#    'CHOCOLATE 3 WICK MORRIS BOX CANDLE'),
#   ('SET/3 VANILLA SCENTED CANDLE IN BOX', 'SCANDINAVIAN 3 HEARTS NAPKIN RING'),
#   ('SET/3 VANILLA SCENTED CANDLE IN BOX',
#    'PORCELAIN T-LIGHT HOLDERS ASSORTED'),
#   ('SET/3 VANILLA SCENTED CANDLE IN BOX', 'T-LIGHT GLASS FLUTED ANTIQUE'),
#   ('SET/3 VANILLA SCENTED CANDLE IN BOX', 'SET OF 6 T-LIGHTS SNOWMEN'),
#   ('SET/3 VANILLA SCENTED CANDLE IN BOX', 'SCENTED VELVET LOUNGE CANDLE'),
#   ('SET/3 VANILLA SCENTED CANDLE IN BOX', '3 ROSE MORRIS BOXED CANDLES'),
#   ('SET/3 VANILLA SCENTED CANDLE IN BOX', 'ROSE 3 WICK MORRIS BOX CANDLE'),
#   ('SET/3 VANILLA SCENTED CANDLE IN BOX', 'ROSE SCENT CANDLE JEWELLED DRAWER'),
#   ('CHOCOLATE 1 WICK MORRIS BOX CANDLE', 'GREEN REGENCY TEACUP AND SAUCER'),
#   ('CHOCOLATE 1 WICK MORRIS BOX CANDLE', '3 GARDENIA MORRIS BOXED CANDLES'),
#   ('CHOCOLATE 1 WICK MORRIS BOX CANDLE', 'POSTAGE'),
#   ('CHOCOLATE 1 WICK MORRIS BOX CANDLE', 'CHARLIE+LOLA RED HOT WATER BOTTLE'),
#   ('CHOCOLATE 1 WICK MORRIS BOX CANDLE', 'GRAND CHOCOLATECANDLE'),
#   ('CHOCOLATE 1 WICK MORRIS BOX CANDLE', 'PINK BAROQUE FLOCK CANDLE HOLDER'),
#   ('CHOCOLATE 1 WICK MORRIS BOX CANDLE', 'CHOCOLATE 3 WICK MORRIS BOX CANDLE'),
#   ('CHOCOLATE 1 WICK MORRIS BOX CANDLE', 'SCANDINAVIAN 3 HEARTS NAPKIN RING'),
#   ('CHOCOLATE 1 WICK MORRIS BOX CANDLE', 'PORCELAIN T-LIGHT HOLDERS ASSORTED'),
#   ('CHOCOLATE 1 WICK MORRIS BOX CANDLE', 'T-LIGHT GLASS FLUTED ANTIQUE'),
#   ('CHOCOLATE 1 WICK MORRIS BOX CANDLE', 'SET OF 6 T-LIGHTS SNOWMEN'),
#   ('CHOCOLATE 1 WICK MORRIS BOX CANDLE', 'SCENTED VELVET LOUNGE CANDLE'),
#   ('CHOCOLATE 1 WICK MORRIS BOX CANDLE', '3 ROSE MORRIS BOXED CANDLES'),
#   ('CHOCOLATE 1 WICK MORRIS BOX CANDLE', 'ROSE 3 WICK MORRIS BOX CANDLE'),
#   ('CHOCOLATE 1 WICK MORRIS BOX CANDLE', 'ROSE SCENT CANDLE JEWELLED DRAWER'),
#   ('GREEN REGENCY TEACUP AND SAUCER', '3 GARDENIA MORRIS BOXED CANDLES'),
#   ('GREEN REGENCY TEACUP AND SAUCER', 'POSTAGE'),
#   ('GREEN REGENCY TEACUP AND SAUCER', 'CHARLIE+LOLA RED HOT WATER BOTTLE'),
#   ('GREEN REGENCY TEACUP AND SAUCER', 'GRAND CHOCOLATECANDLE'),
#   ('GREEN REGENCY TEACUP AND SAUCER', 'PINK BAROQUE FLOCK CANDLE HOLDER'),
#   ('GREEN REGENCY TEACUP AND SAUCER', 'CHOCOLATE 3 WICK MORRIS BOX CANDLE'),
#   ('GREEN REGENCY TEACUP AND SAUCER', 'SCANDINAVIAN 3 HEARTS NAPKIN RING'),
#   ('GREEN REGENCY TEACUP AND SAUCER', 'PORCELAIN T-LIGHT HOLDERS ASSORTED'),
#   ('GREEN REGENCY TEACUP AND SAUCER', 'T-LIGHT GLASS FLUTED ANTIQUE'),
#   ('GREEN REGENCY TEACUP AND SAUCER', 'SET OF 6 T-LIGHTS SNOWMEN'),
#   ('GREEN REGENCY TEACUP AND SAUCER', 'SCENTED VELVET LOUNGE CANDLE'),
#   ('GREEN REGENCY TEACUP AND SAUCER', '3 ROSE MORRIS BOXED CANDLES'),
#   ('GREEN REGENCY TEACUP AND SAUCER', 'ROSE 3 WICK MORRIS BOX CANDLE'),
#   ('GREEN REGENCY TEACUP AND SAUCER', 'ROSE SCENT CANDLE JEWELLED DRAWER'),
#   ('3 GARDENIA MORRIS BOXED CANDLES', 'POSTAGE'),
#   ('3 GARDENIA MORRIS BOXED CANDLES', 'CHARLIE+LOLA RED HOT WATER BOTTLE'),
#   ('3 GARDENIA MORRIS BOXED CANDLES', 'GRAND CHOCOLATECANDLE'),
#   ('3 GARDENIA MORRIS BOXED CANDLES', 'PINK BAROQUE FLOCK CANDLE HOLDER'),
#   ('3 GARDENIA MORRIS BOXED CANDLES', 'CHOCOLATE 3 WICK MORRIS BOX CANDLE'),
#   ('3 GARDENIA MORRIS BOXED CANDLES', 'SCANDINAVIAN 3 HEARTS NAPKIN RING'),
#   ('3 GARDENIA MORRIS BOXED CANDLES', 'PORCELAIN T-LIGHT HOLDERS ASSORTED'),
#   ('3 GARDENIA MORRIS BOXED CANDLES', 'T-LIGHT GLASS FLUTED ANTIQUE'),
#   ('3 GARDENIA MORRIS BOXED CANDLES', 'SET OF 6 T-LIGHTS SNOWMEN'),
#   ('3 GARDENIA MORRIS BOXED CANDLES', 'SCENTED VELVET LOUNGE CANDLE'),
#   ('3 GARDENIA MORRIS BOXED CANDLES', '3 ROSE MORRIS BOXED CANDLES'),
#   ('3 GARDENIA MORRIS BOXED CANDLES', 'ROSE 3 WICK MORRIS BOX CANDLE'),
#   ('3 GARDENIA MORRIS BOXED CANDLES', 'ROSE SCENT CANDLE JEWELLED DRAWER'),
#   ('POSTAGE', 'CHARLIE+LOLA RED HOT WATER BOTTLE'),
#   ('POSTAGE', 'GRAND CHOCOLATECANDLE'),
#   ('POSTAGE', 'PINK BAROQUE FLOCK CANDLE HOLDER'),
#   ('POSTAGE', 'CHOCOLATE 3 WICK MORRIS BOX CANDLE'),
#   ('POSTAGE', 'SCANDINAVIAN 3 HEARTS NAPKIN RING'),
#   ('POSTAGE', 'PORCELAIN T-LIGHT HOLDERS ASSORTED'),
#   ('POSTAGE', 'T-LIGHT GLASS FLUTED ANTIQUE'),
#   ('POSTAGE', 'SET OF 6 T-LIGHTS SNOWMEN'),
#   ('POSTAGE', 'SCENTED VELVET LOUNGE CANDLE'),
#   ('POSTAGE', '3 ROSE MORRIS BOXED CANDLES'),
#   ('POSTAGE', 'ROSE 3 WICK MORRIS BOX CANDLE'),
#   ('POSTAGE', 'ROSE SCENT CANDLE JEWELLED DRAWER'),
#   ('CHARLIE+LOLA RED HOT WATER BOTTLE', 'GRAND CHOCOLATECANDLE'),
#   ('CHARLIE+LOLA RED HOT WATER BOTTLE', 'PINK BAROQUE FLOCK CANDLE HOLDER'),
#   ('CHARLIE+LOLA RED HOT WATER BOTTLE', 'CHOCOLATE 3 WICK MORRIS BOX CANDLE'),
#   ('CHARLIE+LOLA RED HOT WATER BOTTLE', 'SCANDINAVIAN 3 HEARTS NAPKIN RING'),
#   ('CHARLIE+LOLA RED HOT WATER BOTTLE', 'PORCELAIN T-LIGHT HOLDERS ASSORTED'),
#   ('CHARLIE+LOLA RED HOT WATER BOTTLE', 'T-LIGHT GLASS FLUTED ANTIQUE'),
#   ('CHARLIE+LOLA RED HOT WATER BOTTLE', 'SET OF 6 T-LIGHTS SNOWMEN'),
#   ('CHARLIE+LOLA RED HOT WATER BOTTLE', 'SCENTED VELVET LOUNGE CANDLE'),
#   ('CHARLIE+LOLA RED HOT WATER BOTTLE', '3 ROSE MORRIS BOXED CANDLES'),
#   ('CHARLIE+LOLA RED HOT WATER BOTTLE', 'ROSE 3 WICK MORRIS BOX CANDLE'),
#   ('CHARLIE+LOLA RED HOT WATER BOTTLE', 'ROSE SCENT CANDLE JEWELLED DRAWER'),
#   ('GRAND CHOCOLATECANDLE', 'PINK BAROQUE FLOCK CANDLE HOLDER'),
#   ('GRAND CHOCOLATECANDLE', 'CHOCOLATE 3 WICK MORRIS BOX CANDLE'),
#   ('GRAND CHOCOLATECANDLE', 'SCANDINAVIAN 3 HEARTS NAPKIN RING'),
#   ('GRAND CHOCOLATECANDLE', 'PORCELAIN T-LIGHT HOLDERS ASSORTED'),
#   ('GRAND CHOCOLATECANDLE', 'T-LIGHT GLASS FLUTED ANTIQUE'),
#   ('GRAND CHOCOLATECANDLE', 'SET OF 6 T-LIGHTS SNOWMEN'),
#   ('GRAND CHOCOLATECANDLE', 'SCENTED VELVET LOUNGE CANDLE'),
#   ('GRAND CHOCOLATECANDLE', '3 ROSE MORRIS BOXED CANDLES'),
#   ('GRAND CHOCOLATECANDLE', 'ROSE 3 WICK MORRIS BOX CANDLE'),
#   ('GRAND CHOCOLATECANDLE', 'ROSE SCENT CANDLE JEWELLED DRAWER'),
#   ('PINK BAROQUE FLOCK CANDLE HOLDER', 'CHOCOLATE 3 WICK MORRIS BOX CANDLE'),
#   ('PINK BAROQUE FLOCK CANDLE HOLDER', 'SCANDINAVIAN 3 HEARTS NAPKIN RING'),
#   ('PINK BAROQUE FLOCK CANDLE HOLDER', 'PORCELAIN T-LIGHT HOLDERS ASSORTED'),
#   ('PINK BAROQUE FLOCK CANDLE HOLDER', 'T-LIGHT GLASS FLUTED ANTIQUE'),
#   ('PINK BAROQUE FLOCK CANDLE HOLDER', 'SET OF 6 T-LIGHTS SNOWMEN'),
#   ('PINK BAROQUE FLOCK CANDLE HOLDER', 'SCENTED VELVET LOUNGE CANDLE'),
#   ('PINK BAROQUE FLOCK CANDLE HOLDER', '3 ROSE MORRIS BOXED CANDLES'),
#   ('PINK BAROQUE FLOCK CANDLE HOLDER', 'ROSE 3 WICK MORRIS BOX CANDLE'),
#   ('PINK BAROQUE FLOCK CANDLE HOLDER', 'ROSE SCENT CANDLE JEWELLED DRAWER'),
#   ('CHOCOLATE 3 WICK MORRIS BOX CANDLE', 'SCANDINAVIAN 3 HEARTS NAPKIN RING'),
#   ('CHOCOLATE 3 WICK MORRIS BOX CANDLE', 'PORCELAIN T-LIGHT HOLDERS ASSORTED'),
#   ('CHOCOLATE 3 WICK MORRIS BOX CANDLE', 'T-LIGHT GLASS FLUTED ANTIQUE'),
#   ('CHOCOLATE 3 WICK MORRIS BOX CANDLE', 'SET OF 6 T-LIGHTS SNOWMEN'),
#   ('CHOCOLATE 3 WICK MORRIS BOX CANDLE', 'SCENTED VELVET LOUNGE CANDLE'),
#   ('CHOCOLATE 3 WICK MORRIS BOX CANDLE', '3 ROSE MORRIS BOXED CANDLES'),
#   ('CHOCOLATE 3 WICK MORRIS BOX CANDLE', 'ROSE 3 WICK MORRIS BOX CANDLE'),
#   ('CHOCOLATE 3 WICK MORRIS BOX CANDLE', 'ROSE SCENT CANDLE JEWELLED DRAWER'),
#   ('SCANDINAVIAN 3 HEARTS NAPKIN RING', 'PORCELAIN T-LIGHT HOLDERS ASSORTED'),
#   ('SCANDINAVIAN 3 HEARTS NAPKIN RING', 
),
#   ('SET OF 3 CAKE TINS PANTRY DESIGN', 'HOMEMADE JAM SCENTED CANDLES'),
#   ('SET OF 3 CAKE TINS PANTRY DESIGN', 'POSTAGE'),
#   ('SET OF 3 CAKE TINS PANTRY DESIGN', 'PACK OF 60 PINK PAISLEY CAKE CASES'),
#   ('SET OF 3 CAKE TINS PANTRY DESIGN', 'CAKE PLATE LOVEBIRD PINK'),
#   ('SET OF 3 CAKE TINS PANTRY DESIGN', 'CAKE STAND LOVEBIRD 2 TIER PINK'),
#   ('SET OF 3 CAKE TINS PANTRY DESIGN', 'REGENCY CAKESTAND 3 TIER'),
#   ('SET OF 3 CAKE TINS PANTRY DESIGN', 'CAKE STAND 3 TIER MAGIC GARDEN'),
#   ('SET OF 3 CAKE TINS PANTRY DESIGN', 'ASSORTED COLOURS SILK FAN'),
#   ('SET OF 3 CAKE TINS PANTRY DESIGN', 'FAIRY CAKE FLANNEL ASSORTED COLOUR'),
#   ('SET OF 3 CAKE TINS PANTRY DESIGN', 'GREEN REGENCY TEACUP AND SAUCER'),
#   ('SET OF 3 CAKE TINS PANTRY DESIGN', 'CUPCAKE LACE PAPER SET 6'),
#   ('SET OF 3 CAKE TINS PANTRY DESIGN', 'CAKE STAND WHITE TWO TIER LACE'),
#   ('PACK OF 60 MUSHROOM CAKE CASES', 'HOMEMADE JAM SCENTED CANDLES'),
#   ('PACK OF 60 MUSHROOM CAKE CASES', 'POSTAGE'),
#   ('PACK OF 60 MUSHROOM CAKE CASES', 'PACK OF 60 PINK PAISLEY CAKE CASES'),
#   ('PACK OF 60 MUSHROOM CAKE CASES', 'CAKE PLATE LOVEBIRD PINK'),
#   ('PACK OF 60 MUSHROOM CAKE CASES', 'CAKE STAND LOVEBIRD 2 TIER PINK'),
#   ('PACK OF 60 MUSHROOM CAKE CASES', 'REGENCY CAKESTAND 3 TIER'),
#   ('PACK OF 60 MUSHROOM CAKE CASES', 'CAKE STAND 3 TIER MAGIC GARDEN'),
#   ('PACK OF 60 MUSHROOM CAKE CASES', 'ASSORTED COLOURS SILK FAN'),
#   ('PACK OF 60 MUSHROOM CAKE CASES', 'FAIRY CAKE FLANNEL ASSORTED COLOUR'),
#   ('PACK OF 60 MUSHROOM CAKE CASES', 'GREEN REGENCY TEACUP AND SAUCER'),
#   ('PACK OF 60 MUSHROOM CAKE CASES', 'CUPCAKE LACE PAPER SET 6'),
#   ('PACK OF 60 MUSHROOM CAKE CASES', 'CAKE STAND WHITE TWO TIER LACE'),
#   ('HOMEMADE JAM SCENTED CANDLES', 'POSTAGE'),
#   ('HOMEMADE JAM SCENTED CANDLES', 'PACK OF 60 PINK PAISLEY CAKE CASES'),
#   ('HOMEMADE JAM SCENTED CANDLES', 'CAKE PLATE LOVEBIRD PINK'),
#   ('HOMEMADE JAM SCENTED CANDLES', 'CAKE STAND LOVEBIRD 2 TIER PINK'),
#   ('HOMEMADE JAM SCENTED CANDLES', 'REGENCY CAKESTAND 3 TIER'),
#   ('HOMEMADE JAM SCENTED CANDLES', 'CAKE STAND 3 TIER MAGIC GARDEN'),
#   ('HOMEMADE JAM SCENTED CANDLES', 'ASSORTED COLOURS SILK FAN'),
#   ('HOMEMADE JAM SCENTED CANDLES', 'FAIRY CAKE FLANNEL ASSORTED COLOUR'),
#   ('HOMEMADE JAM SCENTED CANDLES', 'GREEN REGENCY TEACUP AND SAUCER'),
#   ('HOMEMADE JAM SCENTED CANDLES', 'CUPCAKE LACE PAPER SET 6'),
#   ('HOMEMADE JAM SCENTED CANDLES', 'CAKE STAND WHITE TWO TIER LACE'),
#   ('POSTAGE', 'PACK OF 60 PINK PAISLEY CAKE CASES'),
#   ('POSTAGE', 'CAKE PLATE LOVEBIRD PINK'),
#   ('POSTAGE', 'CAKE STAND LOVEBIRD 2 TIER PINK'),
#   ('POSTAGE', 'REGENCY CAKESTAND 3 TIER'),
#   ('POSTAGE', 'CAKE STAND 3 TIER MAGIC GARDEN'),
#   ('POSTAGE', 'ASSORTED COLOURS SILK FAN'),
#   ('POSTAGE', 'FAIRY CAKE FLANNEL ASSORTED COLOUR'),
#   ('POSTAGE', 'GREEN REGENCY TEACUP AND SAUCER'),
#   ('POSTAGE', 'CUPCAKE LACE PAPER SET 6'),
#   ('POSTAGE', 'CAKE STAND WHITE TWO TIER LACE'),
#   ('PACK OF 60 PINK PAISLEY CAKE CASES', 'CAKE PLATE LOVEBIRD PINK'),
#   ('PACK OF 60 PINK PAISLEY CAKE CASES', 'CAKE STAND LOVEBIRD 2 TIER PINK'),
#   ('PACK OF 60 PINK PAISLEY CAKE CASES', 'REGENCY CAKESTAND 3 TIER'),
#   ('PACK OF 60 PINK PAISLEY CAKE CASES', 'CAKE STAND 3 TIER MAGIC GARDEN'),
#   ('PACK OF 60 PINK PAISLEY CAKE CASES', 'ASSORTED COLOURS SILK FAN'),
#   ('PACK OF 60 PINK PAISLEY CAKE CASES', 'FAIRY CAKE FLANNEL ASSORTED COLOUR'),
#   ('PACK OF 60 PINK PAISLEY CAKE CASES', 'GREEN REGENCY TEACUP AND SAUCER'),
#   ('PACK OF 60 PINK PAISLEY CAKE CASES', 'CUPCAKE LACE PAPER SET 6'),
#   ('PACK OF 60 PINK PAISLEY CAKE CASES', 'CAKE STAND WHITE TWO TIER LACE'),
#   ('CAKE PLATE LOVEBIRD PINK', 'CAKE STAND LOVEBIRD 2 TIER PINK'),
#   ('CAKE PLATE LOVEBIRD PINK', 'REGENCY CAKESTAND 3 TIER'),
#   ('CAKE PLATE LOVEBIRD PINK', 'CAKE STAND 3 TIER MAGIC GARDEN'),
#   ('CAKE PLATE LOVEBIRD PINK', 'ASSORTED COLOURS SILK FAN'),
#   ('CAKE PLATE LOVEBIRD PINK', 'FAIRY CAKE FLANNEL ASSORTED COLOUR'),
#   ('CAKE PLATE LOVEBIRD PINK', 'GREEN REGENCY TEACUP AND SAUCER'),
#   ('CAKE PLATE LOVEBIRD PINK', 'CUPCAKE LACE PAPER SET 6'),
#   ('CAKE PLATE LOVEBIRD PINK', 'CAKE STAND WHITE TWO TIER LACE'),
#   ('CAKE STAND LOVEBIRD 2 TIER PINK', 'REGENCY CAKESTAND 3 TIER'),
#   ('CAKE STAND LOVEBIRD 2 TIER PINK', 'CAKE STAND 3 TIER MAGIC GARDEN'),
#   ('CAKE STAND LOVEBIRD 2 TIER PINK', 'ASSORTED COLOURS SILK FAN'),
#   ('CAKE STAND LOVEBIRD 2 TIER PINK', 'FAIRY CAKE FLANNEL ASSORTED COLOUR'),
#   ('CAKE STAND LOVEBIRD 2 TIER PINK', 'GREEN REGENCY TEACUP AND SAUCER'),
#   ('CAKE STAND LOVEBIRD 2 TIER PINK', 'CUPCAKE LACE PAPER SET 6'),
#   ('CAKE STAND LOVEBIRD 2 TIER PINK', 'CAKE STAND WHITE TWO TIER LACE'),
#   ('REGENCY CAKESTAND 3 TIER', 'CAKE STAND 3 TIER MAGIC GARDEN'),
#   ('REGENCY CAKESTAND 3 TIER', 'ASSORTED COLOURS SILK FAN'),
#   ('REGENCY CAKESTAND 3 TIER', 'FAIRY CAKE FLANNEL ASSORTED COLOUR'),
#   ('REGENCY CAKESTAND 3 TIER', 'GREEN REGENCY TEACUP AND SAUCER'),
#   ('REGENCY CAKESTAND 3 TIER', 'CUPCAKE LACE PAPER SET 6'),
#   ('REGENCY CAKESTAND 3 TIER', 'CAKE STAND WHITE TWO TIER LACE'),
#   ('CAKE STAND 3 TIER MAGIC GARDEN', 'ASSORTED COLOURS SILK FAN'),
#   ('CAKE STAND 3 TIER MAGIC GARDEN', 'FAIRY CAKE FLANNEL ASSORTED COLOUR'),
#   ('CAKE STAND 3 TIER MAGIC GARDEN', 'GREEN REGENCY TEACUP AND SAUCER'),
#   ('CAKE STAND 3 TIER MAGIC GARDEN', 'CUPCAKE LACE PAPER SET 6'),
#   ('CAKE STAND 3 TIER MAGIC GARDEN', 'CAKE STAND WHITE TWO TIER LACE'),
#   ('ASSORTED COLOURS SILK FAN', 'FAIRY CAKE FLANNEL ASSORTED COLOUR'),
#   ('ASSORTED COLOURS SILK FAN', 'GREEN REGENCY TEACUP AND SAUCER'),
#   
),
#   ('EMERGENCY FIRST AID TIN', 'CHILDS GARDEN FORK BLUE'),
#   ('EMERGENCY FIRST AID TIN', 'CHILDS GARDEN TROWEL BLUE'),
#   ('EMERGENCY FIRST AID TIN', 'WATERING CAN BLUE ELEPHANT'),
#   ('EMERGENCY FIRST AID TIN', 'WATERING CAN GREEN DINOSAUR'),
#   ('EMERGENCY FIRST AID TIN', 'VICTORIAN SEWING KIT'),
#   ('EMERGENCY FIRST AID TIN', 'CLOTHES PEGS RETROSPOT PACK 24'),
#   ('EMERGENCY FIRST AID TIN', 'DINOSAUR LUNCH BOX WITH CUTLERY'),
#   ('EMERGENCY FIRST AID TIN', 'CHILDS GARDEN RAKE BLUE'),
#   ('EMERGENCY FIRST AID TIN', 'JUNGLE POPSICLES ICE LOLLY HOLDERS'),
#   ('EMERGENCY FIRST AID TIN', 'DECORATIVE CATS BATHROOM BOTTLE'),
#   ('EMERGENCY FIRST AID TIN', 'DOORMAT RESPECTABLE HOUSE'),
#   ('EMERGENCY FIRST AID TIN', 'GROW YOUR OWN PLANT IN A CAN'),
#   ('EMERGENCY FIRST AID TIN', 'IVORY KNITTED MUG COSY'),
#   ('EMERGENCY FIRST AID TIN', 'CHILDS GARDEN SPADE BLUE'),
#   ('EMERGENCY FIRST AID TIN', 'POLKADOT RAIN HAT'),
#   ('EMERGENCY FIRST AID TIN', 'FELTCRAFT DOLL ROSIE'),
#   ('EMERGENCY FIRST AID TIN', 'ILLUSTRATED CAT BOWL'),
#   ('EMERGENCY FIRST AID TIN', 'TEA BAG PLATE RED RETROSPOT'),
#   ('EMERGENCY FIRST AID TIN', 'CIRCUS PARADE LUNCH BOX'),
#   ('EMERGENCY FIRST AID TIN', 'CHILDRENS GARDEN GLOVES PINK'),
#   ('EMERGENCY FIRST AID TIN', 'CHILDS GARDEN SPADE PINK'),
#   ('EMERGENCY FIRST AID TIN', 'CHILDS GARDEN RAKE PINK'),
#   ('EMERGENCY FIRST AID TIN', 'DECORATIVE FLORE BATHROOM BOTTLE'),
#   ('EMERGENCY FIRST AID TIN', 'GREY HEART HOT WATER BOTTLE'),
#   ('EMERGENCY FIRST AID TIN', 'RETROSPOT HEART HOT WATER BOTTLE'),
#   ('EMERGENCY FIRST AID TIN', 'DOORMAT AIRMAIL'),
#   ('EMERGENCY FIRST AID TIN', 'RED RETROSPOT MUG'),
#   ('EMERGENCY FIRST AID TIN', 'SET OF 3 HEART COOKIE CUTTERS'),
#   ('EMERGENCY FIRST AID TIN', 'PLASTERS IN TIN CIRCUS PARADE'),
#   ('EMERGENCY FIRST AID TIN', 'STRAWBERRY LUNCH BOX WITH CUTLERY'),
#   ('EMERGENCY FIRST AID TIN', 'SET OF 3 BUTTERFLY COOKIE CUTTERS'),
#   ('EMERGENCY FIRST AID TIN', 'CARAVAN SQUARE TISSUE BOX'),
#   ('EMERGENCY FIRST AID TIN', 'MINI LADLE LOVE HEART PINK'),
#   ('EMERGENCY FIRST AID TIN', 'BOUDOIR SQUARE TISSUE BOX'),
#   ('EMERGENCY FIRST AID TIN', 'POSTAGE'),
#   ('EMERGENCY FIRST AID TIN', 'OFFICE MUG WARMER BLACK+SILVER'),
#   ('EMERGENCY FIRST AID TIN', 'PHARMACIE FIRST AID TIN'),
#   ('EMERGENCY FIRST AID TIN', 'CHILDS GARDEN TROWEL PINK'),
#   ('EMERGENCY FIRST AID TIN', 'TV DINNER TRAY DOLLY GIRL'),
#   ('EMERGENCY FIRST AID TIN', 'LUNCH BAG RED RETROSPOT'),
#   ('EMERGENCY FIRST AID TIN', 'PLASTERS IN TIN WOODLAND ANIMALS'),
#   ('EMERGENCY FIRST AID TIN', 'SCOTTIE DOG HOT WATER BOTTLE'),
#   ('EMERGENCY FIRST AID TIN', 'MINI LADLE LOVE HEART RED'),
#   ('EMERGENCY FIRST AID TIN', 'SPACEBOY LUNCH BOX'),
#   ('EMERGENCY FIRST AID TIN', 'COFFEE MUG DOG + BALL DESIGN'),
#   ('EMERGENCY FIRST AID TIN', 'CHILDS GARDE
 'RED HANGING HEART T-LIGHT HOLDER'),
#   ('MINT KITCHEN SCALES', 'WHITE HANGING HEART T-LIGHT HOLDER'),
#   ('DOORMAT UNION FLAG', 'RED HANGING HEART T-LIGHT HOLDER'),
#   ('DOORMAT UNION FLAG', 'WHITE HANGING HEART T-LIGHT HOLDER'),
#   ('RED HANGING HEART T-LIGHT HOLDER', 'WHITE HANGING HEART T-LIGHT HOLDER')],
#  [('TOY TIDY SPACEBOY', 'TOY TIDY PINK POLKADOT')]]

# %%
#Комбинации (A,B) и (B,A) надо посчитать эквивалентными, поэтому реализуем свой каунтер
counter = {}
for row in combi:
    for pair in row:
        a, b = pair
        if (a,b) in counter:
            counter[(a,b)] += 1
        elif (b,a) in counter:
            counter[(b,a)] += 1
        else:
            counter[(a,b)] = 1
#Сортируем по встречаемости
counter = {k:v for (k,v) in sorted(counter.items(), key=lambda item: -item[1])}
print(counter)
# Out:
# {('TOY TIDY SPACEBOY', 'TOY TIDY PINK POLKADOT'): 6, ('PLASTERS IN TIN CIRCUS PARADE', 'PLASTERS IN TIN WOODLAND ANIMALS'): 5, ('POSTAGE', 'REGENCY CAKESTAND 3 TIER'): 4, ('PLASTERS IN TIN CIRCUS PARADE', 'POSTAGE'): 4, ('POSTAGE', 'RECYCLING BAG RETROSPOT'): 4, ('TOY TIDY SPACEBOY', 'RECYCLING BAG RETROSPOT'): 4, ('LUNCH BAG WOODLAND', 'LUNCH BAG CARS BLUE'): 4, ('TOY TIDY PINK POLKADOT', 'RECYCLING BAG RETROSPOT'): 4, ('TOY TIDY SPACEBOY', 'CHILDRENS APRON APPLES DESIGN'): 4, ('TOY TIDY PINK POLKADOT', 'CHILDRENS APRON APPLES DESIGN'): 4, ('CHILDRENS APRON APPLES DESIGN', 'SET OF 20 KIDS COOKIE CUTTERS'): 4, ('PLASTERS IN TIN CIRCUS PARADE', 'SET OF 20 KIDS COOKIE CUTTERS'): 4, ('SET OF 3 CAKE TINS PANTRY DESIGN', 'DOORMAT UNION FLAG'): 4, ('SET OF 3 CAKE TINS PANTRY DESIGN', 'DOORMAT WELCOME TO OUR HOME'): 4, ('DOORMAT UNION FLAG', 'DOORMAT WELCOME TO OUR HOME'): 4, ('DOORMAT UNION FLAG', 'DOORMAT AIRMAIL'): 4, ('DOORMAT WELCOME TO OUR HOME', 'DOORMAT AIRMAIL'): 4, ('ROUND SNACK BOXES SET OF4 WOODLAND', 'JUMBO STORAGE BAG SUKI'): 4, ('GINGERBREAD MAN COOKIE CUTTER', 'SET OF 20 KIDS COOKIE CUTTERS'): 4, ('GINGERBREAD MAN COOKIE CUTTER', 'RETROSPOT TEA SET CERAMIC 11 PC'): 4, ('SET OF 20 KIDS COOKIE CUTTERS', 'RETROSPOT TEA SET CERAMIC 11 PC'): 4, ('SET OF 3 CAKE TINS PANTRY DESIGN', 'MINT KITCHEN SCALES'): 4, ('SET OF 3 CAKE TINS PANTRY DESIGN', 'RETROSPOT LARGE MILK JUG'): 4, ('VINTAGE CREAM DOG FOOD CONTAINER', 'SET OF TEA COFFEE SUGAR TINS PANTRY'): 4, ('SET OF 3 CAKE TINS PANTRY DESIGN', 'BREAD BIN DINER STYLE IVORY'): 4, ('SET OF 3 CAKE TINS PANTRY DESIGN', 'JAM MAKING SET WITH JARS'): 4, ('BREAD BIN DINER STYLE IVORY', 'DOORMAT UNION FLAG'): 4, ('BREAD BIN DINER STYLE IVORY', 'JAM MAKING SET WITH JARS'): 4, ('SET OF 3 CAKE TINS PANTRY DESIGN', 