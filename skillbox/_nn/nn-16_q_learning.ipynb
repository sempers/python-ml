# %%
pip install gym
# Out:
# Requirement already satisfied: gym in /usr/local/lib/python3.6/dist-packages (0.17.3)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym) (1.18.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym) (1.4.1)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from gym) (1.5.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym) (1.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym) (0.16.0)

# %%
import random

import gym

alpha = 0.1
gamma = 0.6
epsilon = 0.1

def take_optimal_action(q_table, state, action_space):
    max_q_value_action = None
    max_q_value = 0
    if q_table[state]:
        for action, action_q_value in q_table[state].items():
            if action_q_value >= max_q_value:
                max_q_value = action_q_value
                max_q_value_action = action
    return max_q_value_action if max_q_value_action else action_space.sample()

def update(q_table, env, state):
    if random.uniform(0, 1) < epsilon:
        action = env.action_space.sample()
    else:
        action = take_optimal_action(q_table, state, env.action_space)

    next_state, reward, _, _ = env.step(action)
    old_q_value = q_table[state][action]

    # Check if next_state has q values already
    if not q_table[next_state]:
        q_table[next_state] = {action: 0 for action in range(env.action_space.n)}

    # Maximum q_value for the actions in next state
    next_max = max(q_table[next_state].values())
    # Calculate the new q_value
    new_q_value = (1 - alpha) * old_q_value + alpha * (reward + gamma * next_max)
    # Finally, update the q_value
    q_table[state][action] = new_q_value

    return next_state, reward

#Функция для обучения агента
def train_agent(q_table, env, num_episodes):
    for i in range(num_episodes):
        state = env.reset()
        if not q_table[state]:
            q_table[state] = {action: 0 for action in range(env.action_space.n)}

        epochs = 0
        num_penalties, reward, total_reward = 0, 0, 0
        while reward != 20:
            state, reward = update(q_table, env, state)
            total_reward += reward

            if reward == -10:
                num_penalties += 1

            epochs += 1
        print("\nTraining episode {}".format(i + 1))
        print("Time steps: {}, Penalties: {}, Reward: {}".format(epochs,
                                                                 num_penalties,
                                                                 total_reward))

    print("Training finished.\n")
    return q_table


from collections import defaultdict

NUM_EPISODES = 10000

env = gym.make("Taxi-v3")
q_table = defaultdict(int, {})
q_table = train_agent(q_table, env, NUM_EPISODES)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Training episode 8335
# Time steps: 1931, Penalties: 632, Reward: -7598
#
# Training episode 8336
# Time steps: 696, Penalties: 237, Reward: -2808
#
# Training episode 8337
# Time steps: 1631, Penalties: 557, Reward: -6623
#
# Training episode 8338
# Time steps: 868, Penalties: 257, Reward: -3160
#
# Training episode 8339
# Time steps: 406, Penalties: 134, Reward: -1591
#
# Training episode 8340
# Time steps: 61, Penalties: 19, Reward: -211
#
# Training episode 8341
# Time steps: 72, Penalties: 23, Reward: -258
#
# Training episode 8342
# Time steps: 55, Penalties: 14, Reward: -160
#
# Training episode 8343
# Time steps: 562, Penalties: 176, Reward: -2125
#
# Training episode 8344
# Time steps: 1065, Penalties: 319, Reward: -3915
#
# Training episode 8345
# Time steps: 136, Penalties: 28, Reward: -367
#
# Training episode 8346
# Time steps: 699, Penalties: 225, Reward: -2703
#
# Training episode 8347
# Time steps: 419, Penalties: 122, Reward: -1496
#
# Training episode 8348
# Time steps: 3491, Penalties: 1137, Reward: -13703
#
# Training episode 8349
# Time steps: 283, Penalties: 73, Reward: -919
#
# Training episode 8350
# Time steps: 276, Penalties: 84, Reward: -1011
#
# Training episode 8351
# Time steps: 4964, Penalties: 1646, Reward: -19757
#
# Training episode 8352
# Time steps: 90, Penalties: 32, Reward: -357
#
# Training episode 8353
# Time steps: 379, Penalties: 112, Reward: -1366
#
# Training episode 8354
# Time steps: 2376, Penalties: 792, Reward: -9483
#
# Training episode 8355
# Time steps: 632, Penalties: 187, Reward: -2294
#
# Training episode 8356
# Time steps: 807, Penalties: 271, Reward: -3225
#
# Training episode 8357
# Time steps: 1409, Penalties: 451, Reward: -5447
#
# Training episode 8358
# Time steps: 1077, Penalties: 352, Reward: -4224
#
# Training episode 8359
# Time steps: 692, Penalties: 223, Reward: -2678
#
# Training episode 8360
# Time steps: 226, Penalties: 59, Reward: -736
#
# Training episode 8361
# Time steps: 4627, Penalties: 1496, Reward: -18070
#
# Training episode 8362
# Time steps: 3821, Penalties: 1274, Reward: -15266
#
# Training episode 8363
# Time steps: 82, Penalties: 24, Reward: -277
#
# Training episode 8364
# Time steps: 486, Penalties: 166, Reward: -1959
#
# Training episode 8365
# Time steps: 1215, Penalties: 369, Reward: -4515
#
# Training episode 8366
# Time steps: 52, Penalties: 13, Reward: -148
#
# Training episode 8367
# Time steps: 495, Penalties: 151, Reward: -1833
#
# Training episode 8368
# Time steps: 2222, Penalties: 721, Reward: -8690
#
# Training episode 8369
# Time steps: 4807, Penalties: 1540, Reward: -18646
#
# Training episode 8370
# Time steps: 291, Penalties: 103, Reward: -1197
#
# Training episode 8371
# Time steps: 301, Penalties: 86, Reward: -1054
#
# Training episode 8372
# Time steps: 1378, Penalties: 468, Reward: -5569
#
# Training episode 8373
# Time steps: 53, Penalties: 17, Reward: -185
#
# Training episode 8374
# Time steps: 1384, Penalties: 419, Reward: -5134
#
# Training episode 8375
# Time steps: 199, Penalties: 73, Reward: -835
#
# Training episode 8376
# Time steps: 1033, Penalties: 340, Reward: -4072
#
# Training episode 8377
# Time steps: 2290, Penalties: 758, Reward: -9091
#
# Training episode 8378
# Time steps: 1609, Penalties: 517, Reward: -6241
#
# Training episode 8379
# Time steps: 1197, Penalties: 398, Reward: -4758
#
# Training episode 8380
# Time steps: 277, Penalties: 96, Reward: -1120
#
# Training episode 8381
# Time steps: 874, Penalties: 281, Reward: -3382
#
# Training episode 8382
# Time steps: 1079, Penalties: 321, Reward: -3947
#
# Training episode 8383
# Time steps: 697, Penalties: 216, Reward: -2620
#
# Training episode 8384
# Time steps: 234, Penalties: 69, Reward: -834
#
# Training episode 8385
# Time steps: 379, Penalties: 118, Reward: -1420
#
# Training episode 8386
# Time steps: 91, Penalties: 24, Reward: -286
#
# Training episode 8387
# Time steps: 310, Penalties: 102, Reward: -1207
#
# Training episode 8388
# Time steps: 1162, Penalties: 379, Reward: -4552
#
# Training episode 8389
# Time steps: 335, Penalties: 92, Reward: -1142
#
# Training episode 8390
# Time steps: 1013, Penalties: 343, Reward: -4079
#
# Training episode 8391
# Time steps: 96, Penalties: 22, Reward: -273
#
# Training episode 8392
# Time steps: 2205, Penalties: 678, Reward: -8286
#
# Training episode 8393
# Time steps: 38, Penalties: 5, Reward: -62
#
# Training episode 8394
# Time steps: 666, Penalties: 199, Reward: -2436
#
# Training episode 8395
# Time steps: 2258, Penalties: 744, Reward: -8933
#
# Training episode 8396
# Time steps: 295, Penalties: 96, Reward: -1138
#
# Training episode 8397
# Time steps: 14, Penalties: 1, Reward: -2
#
# Training episode 8398
# Time steps: 453, Penalties: 155, Reward: -1827
#
# Training episode 8399
# Time steps: 100, Penalties: 24, Reward: -295
#
# Training episode 8400
# Time steps: 251, Penalties: 87, Reward: -1013
#
# Training episode 8401
# Time steps: 897, Penalties: 294, Reward: -3522
#
# Training episode 8402
# Time steps: 914, Penalties: 289, Reward: -3494
#
# Training episode 8403
# Time steps: 543, Penalties: 166, Reward: -2016
#
# Training episode 8404
# Time steps: 285, Penalties: 86, Reward: -1038
#
# Training episode 8405
# Time steps: 306, Penalties: 96, Reward: -1149
#
# Training episode 8406
# Time steps: 656, Penalties: 204, Reward: -2471
#
# Training episode 8407
# Time steps: 58, Penalties: 11, Reward: -136
#
# Training episode 8408
# Time steps: 427, Penalties: 120, Reward: -1486
#
# Training episode 8409
# Time steps: 1624, Penalties: 519, Reward: -6274
#
# Training episode 8410
# Time steps: 593, Penalties: 178, Reward: -2174
#
# Training episode 8411
# Time steps: 753, Penalties: 215, Reward: -2667
#
# Training episode 8412
# Time steps: 1331, Penalties: 410, Reward: -5000
#
# Training episode 8413
# Time steps: 995, Penalties: 331, Reward: -3953
#
# Training episode 8414
# Time steps: 391, Penalties: 112, Reward: -1378
#
# Training episode 8415
# Time steps: 1262, Penalties: 418, Reward: -5003
#
# Training episode 8416
# Time steps: 830, Penalties: 262, Reward: -3167
#
# Training episode 8417
# Time steps: 797, Penalties: 278, Reward: -3278
#
# Training episode 8418
# Time steps: 633, Penalties: 222, Reward: -2610
#
# Training episode 8419
# Time steps: 2909, Penalties: 977, Reward: -11681
#
# Training episode 8420
# Time steps: 1063, Penalties: 324, Reward: -3958
#
# Training episode 8421
# Time steps: 210, Penalties: 59, Reward: -720
#
# Training episode 8422
# Time steps: 4170, Penalties: 1353, Reward: -16326
#
# Training episode 8423
# Time steps: 116, Penalties: 29, Reward: -356
#
# Training episode 8424
# Time steps: 305, Penalties: 110, Reward: -1274
#
# Training episode 8425
# Time steps: 72, Penalties: 21, Reward: -240
#
# Training episode 8426
# Time steps: 1480, Penalties: 464, Reward: -5635
#
# Training episode 8427
# Time steps: 1003, Penalties: 325, Reward: -3907
#
# Training episode 8428
# Time steps: 465, Penalties: 150, Reward: -1794
#
# Training episode 8429
# Time steps: 675, Penalties: 213, Reward: -2571
#
# Training episode 8430
# Time steps: 93, Penalties: 30, Reward: -342
#
# Training episode 8431
# Time steps: 331, Penalties: 102, Reward: -1228
#
# Training episode 8432
# Time steps: 2575, Penalties: 852, Reward: -10222
#
# Training episode 8433
# Time steps: 746, Penalties: 248, Reward: -2957
#
# Training episode 8434
# Time steps: 68, Penalties: 20, Reward: -227
#
# Training episode 8435
# Time steps: 2497, Penalties: 796, Reward: -9640
#
# Training episode 8436
# Time steps: 198, Penalties: 69, Reward: -798
#
# Training episode 8437
# Time steps: 461, Penalties: 129, Reward: -1601
#
# Training episode 8438
# Time steps: 354, Penalties: 106, Reward: -1287
#
# Training episode 8439
# Time steps: 32, Penalties: 7, Reward: -74
#
# Training episode 8440
# Time steps: 4479, Penalties: 1482, Reward: -17796
#
# Training episode 8441
# Time steps: 534, Penalties: 186, Reward: -2187
#
# Training episode 8442
# Time steps: 1160, Penalties: 382, Reward: -4577
#
# Training episode 8443
# Time steps: 510, Penalties: 176, Reward: -2073
#
# Training episode 8444
# Time steps: 344, Penalties: 80, Reward: -1043
#
# Training episode 8445
# Time steps: 729, Penalties: 263, Reward: -3075
#
# Training episode 8446
# Time steps: 3413, Penalties: 1115, Reward: -13427
#
# Training episode 8447
# Time steps: 413, Penalties: 136, Reward: -1616
#
# Training episode 8448
# Time steps: 157, Penalties: 55, Reward: -631
#
# Training episode 8449
# Time steps: 27, Penalties: 1, Reward: -15
#
# Training episode 8450
# Time steps: 30, Penalties: 5, Reward: -54
#
# Training episode 8451
# Time steps: 1139, Penalties: 394, Reward: -4664
#
# Training episode 8452
# Time steps: 891, Penalties: 282, Reward: -3408
#
# Training episode 8453
# Time steps: 47, Penalties: 12, Reward: -134
#
# Training episode 8454
# Time steps: 408, Penalties: 139, Reward: -1638
#
# Training episode 8455
# Time steps: 259, Penalties: 72, Reward: -886
#
# Training episode 8456
# Time steps: 172, Penalties: 46, Reward: -565
#
# Training episode 8457
# Time steps: 2597, Penalties: 846, Reward: -10190
#
# Training episode 8458
# Time steps: 52, Penalties: 17, Reward: -184
#
# Training episode 8459
# Time steps: 310, Penalties: 111, Reward: -1288
#
# Training episode 8460
# Time steps: 684, Penalties: 227, Reward: -2706
#
# Training episode 8461
# Time steps: 134, Penalties: 41, Reward: -482
#
# Training episode 8462
# Time steps: 443, Penalties: 137, Reward: -1655
#
# Training episode 8463
# Time steps: 743, Penalties: 229, Reward: -2783
#
# Training episode 8464
# Time steps: 926, Penalties: 272, Reward: -3353
#
# Training episode 8465
# Time steps: 534, Penalties: 169, Reward: -2034
#
# Training episode 8466
# Time steps: 48, Penalties: 14, Reward: -153
#
# Training episode 8467
# Time steps: 9, Penalties: 1, Reward: 3
#
# Training episode 8468
# Time steps: 1748, Penalties: 565, Reward: -6812
#
# Training episode 8469
# Time steps: 1984, Penalties: 629, Reward: -7624
#
# Training episode 8470
# Time steps: 2190, Penalties: 688, Reward: -8361
#
# Training episode 8471
# Time steps: 864, Penalties: 282, Reward: -3381
#
# Training episode 8472
# Time steps: 661, Penalties: 182, Reward: -2278
#
# Training episode 8473
# Time steps: 51, Penalties: 14, Reward: -156
#
# Training episode 8474
# Time steps: 425, Penalties: 116, Reward: -1448
#
# Training episode 8475
# Time steps: 1734, Penalties: 568, Reward: -6825
#
# Training episode 8476
# Time steps: 796, Penalties: 245, Reward: -2980
#
# Training episode 8477
# Time steps: 273, Penalties: 76, Reward: -936
#
# Training episode 8478
# Time steps: 1238, Penalties: 391, Reward: -4736
#
# Training episode 8479
# Time steps: 132, Penalties: 42, Reward: -489
#
# Training episode 8480
# Time steps: 122, Penalties: 39, Reward: -452
#
# Training episode 8481
# Time steps: 1141, Penalties: 380, Reward: -4540
#
# Training episode 8482
# Time steps: 717, Penalties: 216, Reward: -2640
#
# Training episode 8483
# Time steps: 1457, Penalties: 464, Reward: -5612
#
# Training episode 8484
# Time steps: 341, Penalties: 102, Reward: -1238
#
# Training episode 8485
# Time steps: 1153, Penalties: 374, Reward: -4498
#
# Training episode 8486
# Time steps: 356, Penalties: 102, Reward: -1253
#
# Training episode 8487
# Time steps: 2394, Penalties: 774, Reward: -9339
#
# Training episode 8488
# Time steps: 195, Penalties: 60, Reward: -714
#
# Training episode 8489
# Time steps: 837, Penalties: 261, Reward: -3165
#
# Training episode 8490
# Time steps: 138, Penalties: 42, Reward: -495
#
# Training episode 8491
# Time steps: 844, Penalties: 265, Reward: -3208
#
# Training episode 8492
# Time steps: 120, Penalties: 32, Reward: -387
#
# Training episode 8493
# Time steps: 1094, Penalties: 372, Reward: -4421
#
# Training episode 8494
# Time steps: 911, Penalties: 294, Reward: -3536
#
# Training episode 8495
# Time steps: 1689, Penalties: 556, Reward: -6672
#
# Training episode 8496
# Time steps: 264, Penalties: 63, Reward: -810
#
# Training episode 8497
# Time steps: 2447, Penalties: 796, Reward: -9590
#
# Training episode 8498
# Time steps: 245, Penalties: 75, Reward: -899
#
# Training episode 8499
# Time steps: 1928, Penalties: 620, Reward: -7487
#
# Training episode 8500
# Time steps: 2707, Penalties: 887, Reward: -10669
#
# Training episode 8501
# Time steps: 835, Penalties: 226, Reward: -2848
#
# Training episode 8502
# Time steps: 662, Penalties: 204, Reward: -2477
#
# Training episode 8503
# Time steps: 361, Penalties: 129, Reward: -1501
#
# Training episode 8504
# Time steps: 257, Penalties: 68, Reward: -848
#
# Training episode 8505
# Time steps: 127, Penalties: 37, Reward: -439
#
# Training episode 8506
# Time steps: 186, Penalties: 54, Reward: -651
#
# Training episode 8507
# Time steps: 37, Penalties: 14, Reward: -142
#
# Training episode 8508
# Time steps: 706, Penalties: 221, Reward: -2674
#
# Training episode 8509
# Time steps: 2204, Penalties: 691, Reward: -8402
#
# Training episode 8510
# Time steps: 2009, Penalties: 640, Reward: -7748
#
# Training episode 8511
# Time steps: 103, Penalties: 23, Reward: -289
#
# Training episode 8512
# Time steps: 265, Penalties: 94, Reward: -1090
#
# Training episode 8513
# Time steps: 1548, Penalties: 498, Reward: -6009
#
# Training episode 8514
# Time steps: 1153, Penalties: 400, Reward: -4732
#
# Training episode 8515
# Time steps: 337, Penalties: 99, Reward: -1207
#
# Training episode 8516
# Time steps: 19, Penalties: 3, Reward: -25
#
# Training episode 8517
# Time steps: 657, Penalties: 207, Reward: -2499
#
# Training episode 8518
# Time steps: 35, Penalties: 8, Reward: -86
#
# Training episode 8519
# Time steps: 14, Penalties: 1, Reward: -2
#
# Training episode 8520
# Time steps: 2154, Penalties: 703, Reward: -8460
#
# Training episode 8521
# Time steps: 687, Penalties: 218, Reward: -2628
#
# Training episode 8522
# Time steps: 640, Penalties: 212, Reward: -2527
#
# Training episode 8523
# Time steps: 318, Penalties: 99, Reward: -1188
#
# Training episode 8524
# Time steps: 178, Penalties: 58, Reward: -679
#
# Training episode 8525
# Time steps: 922, Penalties: 301, Reward: -3610
#
# Training episode 8526
# Time steps: 1965, Penalties: 648, Reward: -7776
#
# Training episode 8527
# Time steps: 206, Penalties: 58, Reward: -707
#
# Training episode 8528
# Time steps: 481, Penalties: 171, Reward: -1999
#
# Training episode 8529
# Time steps: 454, Penalties: 162, Reward: -1891
#
# Training episode 8530
# Time steps: 192, Penalties: 57, Reward: -684
#
# Training episode 8531
# Time steps: 1744, Penalties: 576, Reward: -6907
#
# Training episode 8532
# Time steps: 698, Penalties: 198, Reward: -2459
#
# Training episode 8533
# Time steps: 433, Penalties: 147, Reward: -1735
#
# Training episode 8534
# Time steps: 386, Penalties: 124, Reward: -1481
#
# Training episode 8535
# Time steps: 737, Penalties: 229, Reward: -2777
#
# Training episode 8536
# Time steps: 927, Penalties: 305, Reward: -3651
#
# Training episode 8537
# Time steps: 3160, Penalties: 991, Reward: -12058
#
# Training episode 8538
# Time steps: 262, Penalties: 77, Reward: -934
#
# Training episode 8539
# Time steps: 1402, Penalties: 466, Reward: -5575
#
# Training episode 8540
# Time steps: 926, Penalties: 293, Reward: -3542
#
# Training episode 8541
# Time steps: 870, Penalties: 311, Reward: -3648
#
# Training episode 8542
# Time steps: 601, Penalties: 194, Reward: -2326
#
# Training episode 8543
# Time steps: 146, Penalties: 48, Reward: -557
#
# Training episode 8544
# Time steps: 1088, Penalties: 330, Reward: -4037
#
# Training episode 8545
# Time steps: 2261, Penalties: 748, Reward: -8972
#
# Training episode 8546
# Time steps: 1628, Penalties: 538, Reward: -6449
#
# Training episode 8547
# Time steps: 184, Penalties: 56, Reward: -667
#
# Training episode 8548
# Time steps: 16, Penalties: 5, Reward: -40
#
# Training episode 8549
# Time steps: 198, Penalties: 66, Reward: -771
#
# Training episode 8550
# Time steps: 72, Penalties: 15, Reward: -186
#
# Training episode 8551
# Time steps: 227, Penalties: 74, Reward: -872
#
# Training episode 8552
# Time steps: 443, Penalties: 151, Reward: -1781
#
# Training episode 8553
# Time steps: 723, Penalties: 236, Reward: -2826
#
# Training episode 8554
# Time steps: 742, Penalties: 227, Reward: -2764
#
# Training episode 8555
# Time steps: 225, Penalties: 71, Reward: -843
#
# Training episode 8556
# Time steps: 1149, Penalties: 353, Reward: -4305
#
# Training episode 8557
# Time steps: 48, Penalties: 15, Reward: -162
#
# Training episode 8558
# Time steps: 439, Penalties: 133, Reward: -1615
#
# Training episode 8559
# Time steps: 425, Penalties: 128, Reward: -1556
#
# Training episode 8560
# Time steps: 291, Penalties: 97, Reward: -1143
#
# Training episode 8561
# Time steps: 820, Penalties: 268, Reward: -3211
#
# Training episode 8562
# Time steps: 148, Penalties: 50, Reward: -577
#
# Training episode 8563
# Time steps: 422, Penalties: 148, Reward: -1733
#
# Training episode 8564
# Time steps: 595, Penalties: 213, Reward: -2491
#
# Training episode 8565
# Time steps: 202, Penalties: 67, Reward: -784
#
# Training episode 8566
# Time steps: 393, Penalties: 122, Reward: -1470
#
# Training episode 8567
# Time steps: 55, Penalties: 12, Reward: -142
#
# Training episode 8568
# Time steps: 518, Penalties: 165, Reward: -1982
#
# Training episode 8569
# Time steps: 346, Penalties: 101, Reward: -1234
#
# Training episode 8570
# Time steps: 973, Penalties: 316, Reward: -3796
#
# Training episode 8571
# Time steps: 2911, Penalties: 964, Reward: -11566
#
# Training episode 8572
# Time steps: 999, Penalties: 344, Reward: -4074
#
# Training episode 8573
# Time steps: 630, Penalties: 200, Reward: -2409
#
# Training episode 8574
# Time steps: 161, Penalties: 35, Reward: -455
#
# Training episode 8575
# Time steps: 1218, Penalties: 408, Reward: -4869
#
# Training episode 8576
# Time steps: 1298, Penalties: 431, Reward: -5156
#
# Training episode 8577
# Time steps: 238, Penalties: 72, Reward: -865
#
# Training episode 8578
# Time steps: 43, Penalties: 10, Reward: -112
#
# Training episode 8579
# Time steps: 339, Penalties: 111, Reward: -1317
#
# Training episode 8580
# Time steps: 186, Penalties: 54, Reward: -651
#
# Training episode 8581
# Time steps: 208, Penalties: 58, Reward: -709
#
# Training episode 8582
# Time steps: 812, Penalties: 281, Reward: -3320
#
# Training episode 8583
# Time steps: 108, Penalties: 34, Reward: -393
#
# Training episode 8584
# Time steps: 994, Penalties: 322, Reward: -3871
#
# Training episode 8585
# Time steps: 209, Penalties: 64, Reward: -764
#
# Training episode 8586
# Time steps: 155, Penalties: 48, Reward: -566
#
# Training episode 8587
# Time steps: 862, Penalties: 304, Reward: -3577
#
# Training episode 8588
# Time steps: 1125, Penalties: 331, Reward: -4083
#
# Training episode 8589
# Time steps: 380, Penalties: 112, Reward: -1367
#
# Training episode 8590
# Time steps: 216, Penalties: 78, Reward: -897
#
# Training episode 8591
# Time steps: 727, Penalties: 229, Reward: -2767
#
# Training episode 8592
# Time steps: 4187, Penalties: 1377, Reward: -16559
#
# Training episode 8593
# Time steps: 1446, Penalties: 484, Reward: -5781
#
# Training episode 8594
# Time steps: 99, Penalties: 34, Reward: -384
#
# Training episode 8595
# Time steps: 188, Penalties: 64, Reward: -743
#
# Training episode 8596
# Time steps: 320, Penalties: 103, Reward: -1226
#
# Training episode 8597
# Time steps: 96, Penalties: 29, Reward: -336
#
# Training episode 8598
# Time steps: 852, Penalties: 312, Reward: -3639
#
# Training episode 8599
# Time steps: 967, Penalties: 317, Reward: -3799
#
# Training episode 8600
# Time steps: 1057, Penalties: 347, Reward: -4159
#
# Training episode 8601
# Time steps: 838, Penalties: 268, Reward: -3229
#
# Training episode 8602
# Time steps: 231, Penalties: 68, Reward: -822
#
# Training episode 8603
# Time steps: 224, Penalties: 68, Reward: -815
#
# Training episode 8604
# Time steps: 135, Penalties: 39, Reward: -465
#
# Training episode 8605
# Time steps: 272, Penalties: 102, Reward: -1169
#
# Training episode 8606
# Time steps: 68, Penalties: 14, Reward: -173
#
# Training episode 8607
# Time steps: 103, Penalties: 25, Reward: -307
#
# Training episode 8608
# Time steps: 3686, Penalties: 1203, Reward: -14492
#
# Training episode 8609
# Time steps: 238, Penalties: 89, Reward: -1018
#
# Training episode 8610
# Time steps: 1180, Penalties: 414, Reward: -4885
#
# Training episode 8611
# Time steps: 417, Penalties: 146, Reward: -1710
#
# Training episode 8612
# Time steps: 225, Penalties: 87, Reward: -987
#
# Training episode 8613
# Time steps: 907, Penalties: 302, Reward: -3604
#
# Training episode 8614
# Time steps: 508, Penalties: 159, Reward: -1918
#
# Training episode 8615
# Time steps: 442, Penalties: 134, Reward: -1627
#
# Training episode 8616
# Time steps: 731, Penalties: 225, Reward: -2735
#
# Training episode 8617
# Time steps: 2664, Penalties: 925, Reward: -10968
#
# Training episode 8618
# Time steps: 619, Penalties: 198, Reward: -2380
#
# Training episode 8619
# Time steps: 330, Penalties: 117, Reward: -1362
#
# Training episode 8620
# Time steps: 532, Penalties: 175, Reward: -2086
#
# Training episode 8621
# Time steps: 227, Penalties: 60, Reward: -746
#
# Training episode 8622
# Time steps: 297, Penalties: 91, Reward: -1095
#
# Training episode 8623
# Time steps: 1980, Penalties: 606, Reward: -7413
#
# Training episode 8624
# Time steps: 363, Penalties: 134, Reward: -1548
#
# Training episode 8625
# Time steps: 762, Penalties: 255, Reward: -3036
#
# Training episode 8626
# Time steps: 579, Penalties: 178, Reward: -2160
#
# Training episode 8627
# Time steps: 694, Penalties: 221, Reward: -2662
#
# Training episode 8628
# Time steps: 852, Penalties: 261, Reward: -3180
#
# Training episode 8629
# Time steps: 2298, Penalties: 767, Reward: -9180
#
# Training episode 8630
# Time steps: 1596, Penalties: 456, Reward: -5679
#
# Training episode 8631
# Time steps: 13, Penalties: 2, Reward: -10
#
# Training episode 8632
# Time steps: 219, Penalties: 62, Reward: -756
#
# Training episode 8633
# Time steps: 211, Penalties: 72, Reward: -838
#
# Training episode 8634
# Time steps: 201, Penalties: 76, Reward: -864
#
# Training episode 8635
# Time steps: 737, Penalties: 249, Reward: -2957
#
# Training episode 8636
# Time steps: 133, Penalties: 34, Reward: -418
#
# Training episode 8637
# Time steps: 174, Penalties: 48, Reward: -585
#
# Training episode 8638
# Time steps: 2002, Penalties: 659, Reward: -7912
#
# Training episode 8639
# Time steps: 1181, Penalties: 369, Reward: -4481
#
# Training episode 8640
# Time steps: 428, Penalties: 133, Reward: -1604
#
# Training episode 8641
# Time steps: 2504, Penalties: 857, Reward: -10196
#
# Training episode 8642
# Time steps: 595, Penalties: 219, Reward: -2545
#
# Training episode 8643
# Time steps: 158, Penalties: 34, Reward: -443
#
# Training episode 8644
# Time steps: 834, Penalties: 275, Reward: -3288
#
# Training episode 8645
# Time steps: 488, Penalties: 136, Reward: -1691
#
# Training episode 8646
# Time steps: 1251, Penalties: 409, Reward: -4911
#
# Training episode 8647
# Time steps: 731, Penalties: 236, Reward: -2834
#
# Training episode 8648
# Time steps: 3091, Penalties: 1035, Reward: -12385
#
# Training episode 8649
# Time steps: 2049, Penalties: 679, Reward: -8139
#
# Training episode 8650
# Time steps: 171, Penalties: 52, Reward: -618
#
# Training episode 8651
# Time steps: 204, Penalties: 60, Reward: -723
#
# Training episode 8652
# Time steps: 1165, Penalties: 376, Reward: -4528
#
# Training episode 8653
# Time steps: 1151, Penalties: 398, Reward: -4712
#
# Training episode 8654
# Time steps: 835, Penalties: 280, Reward: -3334
#
# Training episode 8655
# Time steps: 3553, Penalties: 1133, Reward: -13729
#
# Training episode 8656
# Time steps: 128, Penalties: 36, Reward: -431
#
# Training episode 8657
# Time steps: 1239, Penalties: 439, Reward: -5169
#
# Training episode 8658
# Time steps: 2500, Penalties: 790, Reward: -9589
#
# Training episode 8659
# Time steps: 1536, Penalties: 483, Reward: -5862
#
# Training episode 8660
# Time steps: 225, Penalties: 66, Reward: -798
#
# Training episode 8661
# Time steps: 610, Penalties: 196, Reward: -2353
#
# Training episode 8662
# Time steps: 3009, Penalties: 1025, Reward: -12213
#
# Training episode 8663
# Time steps: 2034, Penalties: 700, Reward: -8313
#
# Training episode 8664
# Time steps: 1589, Penalties: 505, Reward: -6113
#
# Training episode 8665
# Time steps: 576, Penalties: 183, Reward: -2202
#
# Training episode 8666
# Time steps: 478, Penalties: 126, Reward: -1591
#
# Training episode 8667
# Time steps: 525, Penalties: 174, Reward: -2070
#
# Training episode 8668
# Time steps: 1952, Penalties: 642, Reward: -7709
#
# Training episode 8669
# Time steps: 264, Penalties: 93, Reward: -1080
#
# Training episode 8670
# Time steps: 538, Penalties: 180, Reward: -2137
#
# Training episode 8671
# Time steps: 222, Penalties: 77, Reward: -894
#
# Training episode 8672
# Time steps: 959, Penalties: 308, Reward: -3710
#
# Training episode 8673
# Time steps: 1385, Penalties: 453, Reward: -5441
#
# Training episode 8674
# Time steps: 605, Penalties: 209, Reward: -2465
#
# Training episode 8675
# Time steps: 703, Penalties: 212, Reward: -2590
#
# Training episode 8676
# Time steps: 505, Penalties: 153, Reward: -1861
#
# Training episode 8677
# Time steps: 320, Penalties: 103, Reward: -1226
#
# Training episode 8678
# Time steps: 214, Penalties: 85, Reward: -958
#
# Training episode 8679
# Time steps: 139, Penalties: 39, Reward: -469
#
# Training episode 8680
# Time steps: 370, Penalties: 132, Reward: -1537
#
# Training episode 8681
# Time steps: 649, Penalties: 233, Reward: -2725
#
# Training episode 8682
# Time steps: 2492, Penalties: 765, Reward: -9356
#
# Training episode 8683
# Time steps: 4513, Penalties: 1485, Reward: -17857
#
# Training episode 8684
# Time steps: 419, Penalties: 131, Reward: -1577
#
# Training episode 8685
# Time steps: 824, Penalties: 292, Reward: -3431
#
# Training episode 8686
# Time steps: 367, Penalties: 118, Reward: -1408
#
# Training episode 8687
# Time steps: 24, Penalties: 5, Reward: -48
#
# Training episode 8688
# Time steps: 1147, Penalties: 376, Reward: -4510
#
# Training episode 8689
# Time steps: 1898, Penalties: 620, Reward: -7457
#
# Training episode 8690
# Time steps: 831, Penalties: 278, Reward: -3312
#
# Training episode 8691
# Time steps: 418, Penalties: 137, Reward: -1630
#
# Training episode 8692
# Time steps: 575, Penalties: 192, Reward: -2282
#
# Training episode 8693
# Time steps: 1057, Penalties: 315, Reward: -3871
#
# Training episode 8694
# Time steps: 623, Penalties: 226, Reward: -2636
#
# Training episode 8695
# Time steps: 1649, Penalties: 542, Reward: -6506
#
# Training episode 8696
# Time steps: 883, Penalties: 253, Reward: -3139
#
# Training episode 8697
# Time steps: 463, Penalties: 132, Reward: -1630
#
# Training episode 8698
# Time steps: 86, Penalties: 32, Reward: -353
#
# Training episode 8699
# Time steps: 1495, Penalties: 507, Reward: -6037
#
# Training episode 8700
# Time steps: 806, Penalties: 259, Reward: -3116
#
# Training episode 8701
# Time steps: 2180, Penalties: 680, Reward: -8279
#
# Training episode 8702
# Time steps: 944, Penalties: 314, Reward: -3749
#
# Training episode 8703
# Time steps: 616, Penalties: 179, Reward: -2206
#
# Training episode 8704
# Time steps: 669, Penalties: 242, Reward: -2826
#
# Training episode 8705
# Time steps: 30, Penalties: 6, Reward: -63
#
# Training episode 8706
# Time steps: 140, Penalties: 35, Reward: -434
#
# Training episode 8707
# Time steps: 543, Penalties: 146, Reward: -1836
#
# Training episode 8708
# Time steps: 4138, Penalties: 1348, Reward: -16249
#
# Training episode 8709
# Time steps: 131, Penalties: 46, Reward: -524
#
# Training episode 8710
# Time steps: 174, Penalties: 59, Reward: -684
#
# Training episode 8711
# Time steps: 45, Penalties: 7, Reward: -87
#
# Training episode 8712
# Time steps: 926, Penalties: 308, Reward: -3677
#
# Training episode 8713
# Time steps: 550, Penalties: 160, Reward: -1969
#
# Training episode 8714
# Time steps: 231, Penalties: 63, Reward: -777
#
# Training episode 8715
# Time steps: 475, Penalties: 130, Reward: -1624
#
# Training episode 8716
# Time steps: 4260, Penalties: 1399, Reward: -16830
#
# Training episode 8717
# Time steps: 74, Penalties: 24, Reward: -269
#
# Training episode 8718
# Time steps: 1173, Penalties: 383, Reward: -4599
#
# Training episode 8719
# Time steps: 1319, Penalties: 418, Reward: -5060
#
# Training episode 8720
# Time steps: 722, Penalties: 237, Reward: -2834
#
# Training episode 8721
# Time steps: 112, Penalties: 33, Reward: -388
#
# Training episode 8722
# Time steps: 56, Penalties: 13, Reward: -152
#
# Training episode 8723
# Time steps: 4609, Penalties: 1444, Reward: -17584
#
# Training episode 8724
# Time steps: 201, Penalties: 69, Reward: -801
#
# Training episode 8725
# Time steps: 324, Penalties: 96, Reward: -1167
#
# Training episode 8726
# Time steps: 1031, Penalties: 320, Reward: -3890
#
# Training episode 8727
# Time steps: 1525, Penalties: 507, Reward: -6067
#
# Training episode 8728
# Time steps: 74, Penalties: 24, Reward: -269
#
# Training episode 8729
# Time steps: 1486, Penalties: 503, Reward: -5992
#
# Training episode 8730
# Time steps: 152, Penalties: 55, Reward: -626
#
# Training episode 8731
# Time steps: 355, Penalties: 113, Reward: -1351
#
# Training episode 8732
# Time steps: 77, Penalties: 25, Reward: -281
#
# Training episode 8733
# Time steps: 734, Penalties: 250, Reward: -2963
#
# Training episode 8734
# Time steps: 94, Penalties: 29, Reward: -334
#
# Training episode 8735
# Time steps: 375, Penalties: 116, Reward: -1398
#
# Training episode 8736
# Time steps: 1203, Penalties: 391, Reward: -4701
#
# Training episode 8737
# Time steps: 3973, Penalties: 1297, Reward: -15625
#
# Training episode 8738
# Time steps: 1761, Penalties: 591, Reward: -7059
#
# Training episode 8739
# Time steps: 689, Penalties: 220, Reward: -2648
#
# Training episode 8740
# Time steps: 743, Penalties: 240, Reward: -2882
#
# Training episode 8741
# Time steps: 694, Penalties: 219, Reward: -2644
#
# Training episode 8742
# Time steps: 2420, Penalties: 776, Reward: -9383
#
# Training episode 8743
# Time steps: 148, Penalties: 44, Reward: -523
#
# Training episode 8744
# Time steps: 182, Penalties: 65, Reward: -746
#
# Training episode 8745
# Time steps: 1330, Penalties: 432, Reward: -5197
#
# Training episode 8746
# Time steps: 430, Penalties: 121, Reward: -1498
#
# Training episode 8747
# Time steps: 1210, Penalties: 423, Reward: -4996
#
# Training episode 8748
# Time steps: 515, Penalties: 181, Reward: -2123
#
# Training episode 8749
# Time steps: 1038, Penalties: 351, Reward: -4176
#
# Training episode 8750
# Time steps: 841, Penalties: 279, Reward: -3331
#
# Training episode 8751
# Time steps: 554, Penalties: 184, Reward: -2189
#
# Training episode 8752
# Time steps: 111, Penalties: 25, Reward: -315
#
# Training episode 8753
# Time steps: 689, Penalties: 213, Reward: -2585
#
# Training episode 8754
# Time steps: 123, Penalties: 42, Reward: -480
#
# Training episode 8755
# Time steps: 1404, Penalties: 461, Reward: -5532
#
# Training episode 8756
# Time steps: 102, Penalties: 21, Reward: -270
#
# Training episode 8757
# Time steps: 1670, Penalties: 535, Reward: -6464
#
# Training episode 8758
# Time steps: 27, Penalties: 6, Reward: -60
#
# Training episode 8759
# Time steps: 96, Penalties: 42, Reward: -453
#
# Training episode 8760
# Time steps: 89, Penalties: 19, Reward: -239
#
# Training episode 8761
# Time steps: 2348, Penalties: 776, Reward: -9311
#
# Training episode 8762
# Time steps: 249, Penalties: 80, Reward: -948
#
# Training episode 8763
# Time steps: 542, Penalties: 199, Reward: -2312
#
# Training episode 8764
# Time steps: 306, Penalties: 95, Reward: -1140
#
# Training episode 8765
# Time steps: 711, Penalties: 233, Reward: -2787
#
# Training episode 8766
# Time steps: 4153, Penalties: 1323, Reward: -16039
#
# Training episode 8767
# Time steps: 93, Penalties: 22, Reward: -270
#
# Training episode 8768
# Time steps: 90, Penalties: 24, Reward: -285
#
# Training episode 8769
# Time steps: 1738, Penalties: 567, Reward: -6820
#
# Training episode 8770
# Time steps: 17, Penalties: 2, Reward: -14
#
# Training episode 8771
# Time steps: 691, Penalties: 211, Reward: -2569
#
# Training episode 8772
# Time steps: 951, Penalties: 338, Reward: -3972
#
# Training episode 8773
# Time steps: 325, Penalties: 111, Reward: -1303
#
# Training episode 8774
# Time steps: 703, Penalties: 226, Reward: -2716
#
# Training episode 8775
# Time steps: 1538, Penalties: 544, Reward: -6413
#
# Training episode 8776
# Time steps: 666, Penalties: 220, Reward: -2625
#
# Training episode 8777
# Time steps: 1754, Penalties: 556, Reward: -6737
#
# Training episode 8778
# Time steps: 688, Penalties: 241, Reward: -2836
#
# Training episode 8779
# Time steps: 1935, Penalties: 600, Reward: -7314
#
# Training episode 8780
# Time steps: 157, Penalties: 58, Reward: -658
#
# Training episode 8781
# Time steps: 1406, Penalties: 473, Reward: -5642
#
# Training episode 8782
# Time steps: 1257, Penalties: 405, Reward: -4881
#
# Training episode 8783
# Time steps: 264, Penalties: 83, Reward: -990
#
# Training episode 8784
# Time steps: 234, Penalties: 67, Reward: -816
#
# Training episode 8785
# Time steps: 91, Penalties: 29, Reward: -331
#
# Training episode 8786
# Time steps: 514, Penalties: 157, Reward: -1906
#
# Training episode 8787
# Time steps: 1240, Penalties: 403, Reward: -4846
#
# Training episode 8788
# Time steps: 1207, Penalties: 383, Reward: -4633
#
# Training episode 8789
# Time steps: 2710, Penalties: 919, Reward: -10960
#
# Training episode 8790
# Time steps: 270, Penalties: 81, Reward: -978
#
# Training episode 8791
# Time steps: 1594, Penalties: 541, Reward: -6442
#
# Training episode 8792
# Time steps: 115, Penalties: 38, Reward: -436
#
# Training episode 8793
# Time steps: 820, Penalties: 251, Reward: -3058
#
# Training episode 8794
# Time steps: 990, Penalties: 294, Reward: -3615
#
# Training episode 8795
# Time steps: 1268, Penalties: 423, Reward: -5054
#
# Training episode 8796
# Time steps: 340, Penalties: 122, Reward: -1417
#
# Training episode 8797
# Time steps: 1886, Penalties: 646, Reward: -7679
#
# Training episode 8798
# Time steps: 451, Penalties: 126, Reward: -1564
#
# Training episode 8799
# Time steps: 413, Penalties: 132, Reward: -1580
#
# Training episode 8800
# Time steps: 903, Penalties: 307, Reward: -3645
#
# Training episode 8801
# Time steps: 1313, Penalties: 443, Reward: -5279
#
# Training episode 8802
# Time steps: 856, Penalties: 258, Reward: -3157
#
# Training episode 8803
# Time steps: 1180, Penalties: 400, Reward: -4759
#
# Training episode 8804
# Time steps: 71, Penalties: 23, Reward: -257
#
# Training episode 8805
# Time steps: 1902, Penalties: 632, Reward: -7569
#
# Training episode 8806
# Time steps: 436, Penalties: 140, Reward: -1675
#
# Training episode 8807
# Time steps: 1762, Penalties: 557, Reward: -6754
#
# Training episode 8808
# Time steps: 443, Penalties: 151, Reward: -1781
#
# Training episode 8809
# Time steps: 197, Penalties: 59, Reward: -707
#
# Training episode 8810
# Time steps: 3255, Penalties: 1018, Reward: -12396
#
# Training episode 8811
# Time steps: 238, Penalties: 68, Reward: -829
#
# Training episode 8812
# Time steps: 102, Penalties: 26, Reward: -315
#
# Training episode 8813
# Time steps: 134, Penalties: 27, Reward: -356
#
# Training episode 8814
# Time steps: 692, Penalties: 213, Reward: -2588
#
# Training episode 8815
# Time steps: 280, Penalties: 84, Reward: -1015
#
# Training episode 8816
# Time steps: 394, Penalties: 115, Reward: -1408
#
# Training episode 8817
# Time steps: 554, Penalties: 172, Reward: -2081
#
# Training episode 8818
# Time steps: 289, Penalties: 100, Reward: -1168
#
# Training episode 8819
# Time steps: 259, Penalties: 78, Reward: -940
#
# Training episode 8820
# Time steps: 536, Penalties: 167, Reward: -2018
#
# Training episode 8821
# Time steps: 845, Penalties: 267, Reward: -3227
#
# Training episode 8822
# Time steps: 817, Penalties: 239, Reward: -2947
#
# Training episode 8823
# Time steps: 1019, Penalties: 311, Reward: -3797
#
# Training episode 8824
# Time steps: 12, Penalties: 0, Reward: 9
#
# Training episode 8825
# Time steps: 1047, Penalties: 358, Reward: -4248
#
# Training episode 8826
# Time steps: 1172, Penalties: 427, Reward: -4994
#
# Training episode 8827
# Time steps: 43, Penalties: 12, Reward: -130
#
# Training episode 8828
# Time steps: 571, Penalties: 162, Reward: -2008
#
# Training episode 8829
# Time steps: 5744, Penalties: 1843, Reward: -22310
#
# Training episode 8830
# Time steps: 88, Penalties: 24, Reward: -283
#
# Training episode 8831
# Time steps: 925, Penalties: 287, Reward: -3487
#
# Training episode 8832
# Time steps: 334, Penalties: 109, Reward: -1294
#
# Training episode 8833
# Time steps: 145, Penalties: 44, Reward: -520
#
# Training episode 8834
# Time steps: 713, Penalties: 217, Reward: -2645
#
# Training episode 8835
# Time steps: 578, Penalties: 193, Reward: -2294
#
# Training episode 8836
# Time steps: 537, Penalties: 168, Reward: -2028
#
# Training episode 8837
# Time steps: 786, Penalties: 260, Reward: -3105
#
# Training episode 8838
# Time steps: 194, Penalties: 68, Reward: -785
#
# Training episode 8839
# Time steps: 99, Penalties: 29, Reward: -339
#
# Training episode 8840
# Time steps: 239, Penalties: 87, Reward: -1001
#
# Training episode 8841
# Time steps: 355, Penalties: 141, Reward: -1603
#
# Training episode 8842
# Time steps: 132, Penalties: 36, Reward: -435
#
# Training episode 8843
# Time steps: 625, Penalties: 163, Reward: -2071
#
# Training episode 8844
# Time steps: 899, Penalties: 285, Reward: -3443
#
# Training episode 8845
# Time steps: 285, Penalties: 86, Reward: -1038
#
# Training episode 8846
# Time steps: 787, Penalties: 236, Reward: -2890
#
# Training episode 8847
# Time steps: 2029, Penalties: 664, Reward: -7984
#
# Training episode 8848
# Time steps: 415, Penalties: 129, Reward: -1555
#
# Training episode 8849
# Time steps: 1207, Penalties: 400, Reward: -4786
#
# Training episode 8850
# Time steps: 777, Penalties: 259, Reward: -3087
#
# Training episode 8851
# Time steps: 318, Penalties: 102, Reward: -1215
#
# Training episode 8852
# Time steps: 214, Penalties: 60, Reward: -733
#
# Training episode 8853
# Time steps: 233, Penalties: 84, Reward: -968
#
# Training episode 8854
# Time steps: 400, Penalties: 104, Reward: -1315
#
# Training episode 8855
# Time steps: 368, Penalties: 122, Reward: -1445
#
# Training episode 8856
# Time steps: 212, Penalties: 66, Reward: -785
#
# Training episode 8857
# Time steps: 1965, Penalties: 671, Reward: -7983
#
# Training episode 8858
# Time steps: 139, Penalties: 34, Reward: -424
#
# Training episode 8859
# Time steps: 631, Penalties: 184, Reward: -2266
#
# Training episode 8860
# Time steps: 408, Penalties: 120, Reward: -1467
#
# Training episode 8861
# Time steps: 1579, Penalties: 524, Reward: -6274
#
# Training episode 8862
# Time steps: 520, Penalties: 159, Reward: -1930
#
# Training episode 8863
# Time steps: 411, Penalties: 125, Reward: -1515
#
# Training episode 8864
# Time steps: 87, Penalties: 27, Reward: -309
#
# Training episode 8865
# Time steps: 587, Penalties: 198, Reward: -2348
#
# Training episode 8866
# Time steps: 1153, Penalties: 345, Reward: -4237
#
# Training episode 8867
# Time steps: 366, Penalties: 109, Reward: -1326
#
# Training episode 8868
# Time steps: 490, Penalties: 143, Reward: -1756
#
# Training episode 8869
# Time steps: 341, Penalties: 113, Reward: -1337
#
# Training episode 8870
# Time steps: 536, Penalties: 147, Reward: -1838
#
# Training episode 8871
# Time steps: 1392, Penalties: 475, Reward: -5646
#
# Training episode 8872
# Time steps: 1568, Penalties: 509, Reward: -6128
#
# Training episode 8873
# Time steps: 363, Penalties: 110, Reward: -1332
#
# Training episode 8874
# Time steps: 372, Penalties: 113, Reward: -1368
#
# Training episode 8875
# Time steps: 1669, Penalties: 552, Reward: -6616
#
# Training episode 8876
# Time steps: 1389, Penalties: 430, Reward: -5238
#
# Training episode 8877
# Time steps: 31, Penalties: 11, Reward: -109
#
# Training episode 8878
# Time steps: 406, Penalties: 138, Reward: -1627
#
# Training episode 8879
# Time steps: 85, Penalties: 30, Reward: -334
#
# Training episode 8880
# Time steps: 463, Penalties: 145, Reward: -1747
#
# Training episode 8881
# Time steps: 58, Penalties: 16, Reward: -181
#
# Training episode 8882
# Time steps: 3398, Penalties: 1156, Reward: -13781
#
# Training episode 8883
# Time steps: 115, Penalties: 36, Reward: -418
#
# Training episode 8884
# Time steps: 653, Penalties: 215, Reward: -2567
#
# Training episode 8885
# Time steps: 468, Penalties: 145, Reward: -1752
#
# Training episode 8886
# Time steps: 656, Penalties: 198, Reward: -2417
#
# Training episode 8887
# Time steps: 44, Penalties: 15, Reward: -158
#
# Training episode 8888
# Time steps: 1115, Penalties: 358, Reward: -4316
#
# Training episode 8889
# Time steps: 829, Penalties: 271, Reward: -3247
#
# Training episode 8890
# Time steps: 83, Penalties: 21, Reward: -251
#
# Training episode 8891
# Time steps: 4368, Penalties: 1436, Reward: -17271
#
# Training episode 8892
# Time steps: 1236, Penalties: 397, Reward: -4788
#
# Training episode 8893
# Time steps: 689, Penalties: 223, Reward: -2675
#
# Training episode 8894
# Time steps: 376, Penalties: 133, Reward: -1552
#
# Training episode 8895
# Time steps: 626, Penalties: 197, Reward: -2378
#
# Training episode 8896
# Time steps: 293, Penalties: 82, Reward: -1010
#
# Training episode 8897
# Time steps: 113, Penalties: 30, Reward: -362
#
# Training episode 8898
# Time steps: 187, Penalties: 55, Reward: -661
#
# Training episode 8899
# Time steps: 278, Penalties: 97, Reward: -1130
#
# Training episode 8900
# Time steps: 735, Penalties: 252, Reward: -2982
#
# Training episode 8901
# Time steps: 2220, Penalties: 755, Reward: -8994
#
# Training episode 8902
# Time steps: 1163, Penalties: 381, Reward: -4571
#
# Training episode 8903
# Time steps: 743, Penalties: 224, Reward: -2738
#
# Training episode 8904
# Time steps: 1724, Penalties: 593, Reward: -7040
#
# Training episode 8905
# Time steps: 3843, Penalties: 1331, Reward: -15801
#
# Training episode 8906
# Time steps: 1232, Penalties: 379, Reward: -4622
#
# Training episode 8907
# Time steps: 1670, Penalties: 540, Reward: -6509
#
# Training episode 8908
# Time steps: 140, Penalties: 34, Reward: -425
#
# Training episode 8909
# Time steps: 525, Penalties: 152, Reward: -1872
#
# Training episode 8910
# Time steps: 370, Penalties: 106, Reward: -1303
#
# Training episode 8911
# Time steps: 2757, Penalties: 906, Reward: -10890
#
# Training episode 8912
# Time steps: 98, Penalties: 29, Reward: -338
#
# Training episode 8913
# Time steps: 964, Penalties: 327, Reward: -3886
#
# Training episode 8914
# Time steps: 28, Penalties: 8, Reward: -79
#
# Training episode 8915
# Time steps: 150, Penalties: 51, Reward: -588
#
# Training episode 8916
# Time steps: 689, Penalties: 195, Reward: -2423
#
# Training episode 8917
# Time steps: 319, Penalties: 110, Reward: -1288
#
# Training episode 8918
# Time steps: 335, Penalties: 101, Reward: -1223
#
# Training episode 8919
# Time steps: 878, Penalties: 295, Reward: -3512
#
# Training episode 8920
# Time steps: 295, Penalties: 92, Reward: -1102
#
# Training episode 8921
# Time steps: 2370, Penalties: 778, Reward: -9351
#
# Training episode 8922
# Time steps: 739, Penalties: 235, Reward: -2833
#
# Training episode 8923
# Time steps: 179, Penalties: 48, Reward: -590
#
# Training episode 8924
# Time steps: 1439, Penalties: 496, Reward: -5882
#
# Training episode 8925
# Time steps: 1472, Penalties: 499, Reward: -5942
#
# Training episode 8926
# Time steps: 1132, Penalties: 335, Reward: -4126
#
# Training episode 8927
# Time steps: 104, Penalties: 29, Reward: -344
#
# Training episode 8928
# Time steps: 1321, Penalties: 395, Reward: -4855
#
# Training episode 8929
# Time steps: 251, Penalties: 73, Reward: -887
#
# Training episode 8930
# Time steps: 638, Penalties: 222, Reward: -2615
#
# Training episode 8931
# Time steps: 3821, Penalties: 1262, Reward: -15158
#
# Training episode 8932
# Time steps: 1273, Penalties: 425, Reward: -5077
#
# Training episode 8933
# Time steps: 855, Penalties: 266, Reward: -3228
#
# Training episode 8934
# Time steps: 2100, Penalties: 666, Reward: -8073
#
# Training episode 8935
# Time steps: 1716, Penalties: 516, Reward: -6339
#
# Training episode 8936
# Time steps: 516, Penalties: 171, Reward: -2034
#
# Training episode 8937
# Time steps: 407, Penalties: 136, Reward: -1610
#
# Training episode 8938
# Time steps: 568, Penalties: 174, Reward: -2113
#
# Training episode 8939
# Time steps: 485, Penalties: 165, Reward: -1949
#
# Training episode 8940
# Time steps: 330, Penalties: 102, Reward: -1227
#
# Training episode 8941
# Time steps: 3453, Penalties: 1170, Reward: -13962
#
# Training episode 8942
# Time steps: 744, Penalties: 235, Reward: -2838
#
# Training episode 8943
# Time steps: 312, Penalties: 95, Reward: -1146
#
# Training episode 8944
# Time steps: 1263, Penalties: 408, Reward: -4914
#
# Training episode 8945
# Time steps: 1030, Penalties: 337, Reward: -4042
#
# Training episode 8946
# Time steps: 67, Penalties: 20, Reward: -226
#
# Training episode 8947
# Time steps: 547, Penalties: 198, Reward: -2308
#
# Training episode 8948
# Time steps: 1379, Penalties: 447, Reward: -5381
#
# Training episode 8949
# Time steps: 2733, Penalties: 855, Reward: -10407
#
# Training episode 8950
# Time steps: 382, Penalties: 122, Reward: -1459
#
# Training episode 8951
# Time steps: 220, Penalties: 75, Reward: -874
#
# Training episode 8952
# Time steps: 647, Penalties: 222, Reward: -2624
#
# Training episode 8953
# Time steps: 1933, Penalties: 633, Reward: -7609
#
# Training episode 8954
# Time steps: 445, Penalties: 142, Reward: -1702
#
# Training episode 8955
# Time steps: 941, Penalties: 328, Reward: -3872
#
# Training episode 8956
# Time steps: 415, Penalties: 130, Reward: -1564
#
# Training episode 8957
# Time steps: 111, Penalties: 25, Reward: -315
#
# Training episode 8958
# Time steps: 1512, Penalties: 507, Reward: -6054
#
# Training episode 8959
# Time steps: 3532, Penalties: 1154, Reward: -13897
#
# Training episode 8960
# Time steps: 494, Penalties: 160, Reward: -1913
#
# Training episode 8961
# Time steps: 358, Penalties: 123, Reward: -1444
#
# Training episode 8962
# Time steps: 2260, Penalties: 713, Reward: -8656
#
# Training episode 8963
# Time steps: 329, Penalties: 92, Reward: -1136
#
# Training episode 8964
# Time steps: 449, Penalties: 156, Reward: -1832
#
# Training episode 8965
# Time steps: 636, Penalties: 206, Reward: -2469
#
# Training episode 8966
# Time steps: 2120, Penalties: 665, Reward: -8084
#
# Training episode 8967
# Time steps: 96, Penalties: 26, Reward: -309
#
# Training episode 8968
# Time steps: 85, Penalties: 18, Reward: -226
#
# Training episode 8969
# Time steps: 787, Penalties: 254, Reward: -3052
#
# Training episode 8970
# Time steps: 666, Penalties: 237, Reward: -2778
#
# Training episode 8971
# Time steps: 177, Penalties: 48, Reward: -588
#
# Training episode 8972
# Time steps: 1299, Penalties: 430, Reward: -5148
#
# Training episode 8973
# Time steps: 297, Penalties: 98, Reward: -1158
#
# Training episode 8974
# Time steps: 70, Penalties: 18, Reward: -211
#
# Training episode 8975
# Time steps: 207, Penalties: 59, Reward: -717
#
# Training episode 8976
# Time steps: 188, Penalties: 44, Reward: -563
#
# Training episode 8977
# Time steps: 70, Penalties: 13, Reward: -166
#
# Training episode 8978
# Time steps: 2123, Penalties: 640, Reward: -7862
#
# Training episode 8979
# Time steps: 959, Penalties: 311, Reward: -3737
#
# Training episode 8980
# Time steps: 579, Penalties: 201, Reward: -2367
#
# Training episode 8981
# Time steps: 836, Penalties: 272, Reward: -3263
#
# Training episode 8982
# Time steps: 35, Penalties: 10, Reward: -104
#
# Training episode 8983
# Time steps: 865, Penalties: 272, Reward: -3292
#
# Training episode 8984
# Time steps: 934, Penalties: 297, Reward: -3586
#
# Training episode 8985
# Time steps: 662, Penalties: 215, Reward: -2576
#
# Training episode 8986
# Time steps: 1229, Penalties: 395, Reward: -4763
#
# Training episode 8987
# Time steps: 603, Penalties: 185, Reward: -2247
#
# Training episode 8988
# Time steps: 1056, Penalties: 383, Reward: -4482
#
# Training episode 8989
# Time steps: 103, Penalties: 40, Reward: -442
#
# Training episode 8990
# Time steps: 252, Penalties: 93, Reward: -1068
#
# Training episode 8991
# Time steps: 497, Penalties: 129, Reward: -1637
#
# Training episode 8992
# Time steps: 1688, Penalties: 539, Reward: -6518
#
# Training episode 8993
# Time steps: 2595, Penalties: 842, Reward: -10152
#
# Training episode 8994
# Time steps: 577, Penalties: 206, Reward: -2410
#
# Training episode 8995
# Time steps: 250, Penalties: 88, Reward: -1021
#
# Training episode 8996
# Time steps: 648, Penalties: 205, Reward: -2472
#
# Training episode 8997
# Time steps: 677, Penalties: 221, Reward: -2645
#
# Training episode 8998
# Time steps: 181, Penalties: 61, Reward: -709
#
# Training episode 8999
# Time steps: 371, Penalties: 143, Reward: -1637
#
# Training episode 9000
# Time steps: 258, Penalties: 77, Reward: -930
#
# Training episode 9001
# Time steps: 478, Penalties: 158, Reward: -1879
#
# Training episode 9002
# Time steps: 1722, Penalties: 557, Reward: -6714
#
# Training episode 9003
# Time steps: 351, Penalties: 110, Reward: -1320
#
# Training episode 9004
# Time steps: 2713, Penalties: 928, Reward: -11044
#
# Training episode 9005
# Time steps: 405, Penalties: 129, Reward: -1545
#
# Training episode 9006
# Time steps: 1992, Penalties: 688, Reward: -8163
#
# Training episode 9007
# Time steps: 962, Penalties: 310, Reward: -3731
#
# Training episode 9008
# Time steps: 347, Penalties: 117, Reward: -1379
#
# Training episode 9009
# Time steps: 2932, Penalties: 950, Reward: -11461
#
# Training episode 9010
# Time steps: 1102, Penalties: 375, Reward: -4456
#
# Training episode 9011
# Time steps: 86, Penalties: 23, Reward: -272
#
# Training episode 9012
# Time steps: 1216, Penalties: 412, Reward: -4903
#
# Training episode 9013
# Time steps: 432, Penalties: 150, Reward: -1761
#
# Training episode 9014
# Time steps: 291, Penalties: 112, Reward: -1278
#
# Training episode 9015
# Time steps: 803, Penalties: 278, Reward: -3284
#
# Training episode 9016
# Time steps: 819, Penalties: 265, Reward: -3183
#
# Training episode 9017
# Time steps: 925, Penalties: 284, Reward: -3460
#
# Training episode 9018
# Time steps: 775, Penalties: 249, Reward: -2995
#
# Training episode 9019
# Time steps: 349, Penalties: 112, Reward: -1336
#
# Training episode 9020
# Time steps: 254, Penalties: 79, Reward: -944
#
# Training episode 9021
# Time steps: 117, Penalties: 36, Reward: -420
#
# Training episode 9022
# Time steps: 288, Penalties: 85, Reward: -1032
#
# Training episode 9023
# ...
# Time steps: 603, Penalties: 193, Reward: -2319
#
# Training episode 9772
# Time steps: 266, Penalties: 73, Reward: -902
#
# Training episode 9773
# Time steps: 99, Penalties: 30, Reward: -348
#
# Training episode 9774
# Time steps: 181, Penalties: 51, Reward: -619
#
# Training episode 9775
# Time steps: 47, Penalties: 16, Reward: -170
#
# Training episode 9776
# Time steps: 167, Penalties: 53, Reward: -623
#
# Training episode 9777
# Time steps: 1090, Penalties: 327, Reward: -4012
#
# Training episode 9778
# Time steps: 83, Penalties: 22, Reward: -260
#
# Training episode 9779
# Time steps: 47, Penalties: 8, Reward: -98
#
# Training episode 9780
# Time steps: 843, Penalties: 276, Reward: -3306
#
# Training episode 9781
# Time steps: 152, Penalties: 42, Reward: -509
#
# Training episode 9782
# Time steps: 1766, Penalties: 562, Reward: -6803
#
# Training episode 9783
# Time steps: 967, Penalties: 317, Reward: -3799
#
# Training episode 9784
# Time steps: 194, Penalties: 63, Reward: -740
#
# Training episode 9785
# Time steps: 2517, Penalties: 820, Reward: -9876
#
# Training episode 9786
# Time steps: 580, Penalties: 175, Reward: -2134
#
# Training episode 9787
# Time steps: 130, Penalties: 34, Reward: -415
#
# Training episode 9788
# Time steps: 1877, Penalties: 604, Reward: -7292
#
# Training episode 9789
# Time steps: 375, Penalties: 100, Reward: -1254
#
# Training episode 9790
# Time steps: 222, Penalties: 65, Reward: -786
#
# Training episode 9791
# Time steps: 747, Penalties: 222, Reward: -2724
#
# Training episode 9792
# Time steps: 541, Penalties: 178, Reward: -2122
#
# Training episode 9793
# Time steps: 469, Penalties: 149, Reward: -1789
#
# Training episode 9794
# Time steps: 598, Penalties: 191, Reward: -2296
#
# Training episode 9795
# Time steps: 764, Penalties: 248, Reward: -2975
#
# Training episode 9796
# Time steps: 203, Penalties: 56, Reward: -686
#
# Training episode 9797
# Time steps: 805, Penalties: 272, Reward: -3232
#
# Training episode 9798
# Time steps: 816, Penalties: 254, Reward: -3081
#
# Training episode 9799
# Time steps: 1793, Penalties: 569, Reward: -6893
#
# Training episode 9800
# Time steps: 3098, Penalties: 1017, Reward: -12230
#
# Training episode 9801
# Time steps: 39, Penalties: 6, Reward: -72
#
# Training episode 9802
# Time steps: 309, Penalties: 102, Reward: -1206
#
# Training episode 9803
# Time steps: 1673, Penalties: 569, Reward: -6773
#
# Training episode 9804
# Time steps: 1424, Penalties: 462, Reward: -5561
#
# Training episode 9805
# Time steps: 566, Penalties: 172, Reward: -2093
#
# Training episode 9806
# Time steps: 948, Penalties: 289, Reward: -3528
#
# Training episode 9807
# Time steps: 1897, Penalties: 625, Reward: -7501
#
# Training episode 9808
# Time steps: 3593, Penalties: 1175, Reward: -14147
#
# Training episode 9809
# Time steps: 181, Penalties: 45, Reward: -565
#
# Training episode 9810
# Time steps: 50, Penalties: 15, Reward: -164
#
# Training episode 9811
# Time steps: 873, Penalties: 274, Reward: -3318
#
# Training episode 9812
# Time steps: 2025, Penalties: 656, Reward: -7908
#
# Training episode 9813
# Time steps: 90, Penalties: 34, Reward: -375
#
# Training episode 9814
# Time steps: 397, Penalties: 132, Reward: -1564
#
# Training episode 9815
# Time steps: 963, Penalties: 313, Reward: -3759
#
# Training episode 9816
# Time steps: 223, Penalties: 60, Reward: -742
#
# Training episode 9817
# Time steps: 736, Penalties: 240, Reward: -2875
#
# Training episode 9818
# Time steps: 85, Penalties: 24, Reward: -280
#
# Training episode 9819
# Time steps: 280, Penalties: 97, Reward: -1132
#
# Training episode 9820
# Time steps: 298, Penalties: 93, Reward: -1114
#
# Training episode 9821
# Time steps: 1798, Penalties: 601, Reward: -7186
#
# Training episode 9822
# Time steps: 79, Penalties: 21, Reward: -247
#
# Training episode 9823
# Time steps: 1720, Penalties: 600, Reward: -7099
#
# Training episode 9824
# Time steps: 195, Penalties: 64, Reward: -750
#
# Training episode 9825
# Time steps: 148, Penalties: 50, Reward: -577
#
# Training episode 9826
# Time steps: 1836, Penalties: 600, Reward: -7215
#
# Training episode 9827
# Time steps: 1232, Penalties: 370, Reward: -4541
#
# Training episode 9828
# Time steps: 883, Penalties: 300, Reward: -3562
#
# Training episode 9829
# Time steps: 43, Penalties: 15, Reward: -157
#
# Training episode 9830
# Time steps: 983, Penalties: 325, Reward: -3887
#
# Training episode 9831
# Time steps: 912, Penalties: 286, Reward: -3465
#
# Training episode 9832
# Time steps: 796, Penalties: 249, Reward: -3016
#
# Training episode 9833
# Time steps: 414, Penalties: 151, Reward: -1752
#
# Training episode 9834
# Time steps: 215, Penalties: 75, Reward: -869
#
# Training episode 9835
# Time steps: 240, Penalties: 69, Reward: -840
#
# Training episode 9836
# Time steps: 508, Penalties: 149, Reward: -1828
#
# Training episode 9837
# Time steps: 3193, Penalties: 1035, Reward: -12487
#
# Training episode 9838
# Time steps: 228, Penalties: 67, Reward: -810
#
# Training episode 9839
# Time steps: 202, Penalties: 64, Reward: -757
#
# Training episode 9840
# Time steps: 410, Penalties: 134, Reward: -1595
#
# Training episode 9841
# Time steps: 713, Penalties: 242, Reward: -2870
#
# Training episode 9842
# Time steps: 113, Penalties: 38, Reward: -434
#
# Training episode 9843
# Time steps: 650, Penalties: 228, Reward: -2681
#
# Training episode 9844
# Time steps: 495, Penalties: 167, Reward: -1977
#
# Training episode 9845
# Time steps: 643, Penalties: 220, Reward: -2602
#
# Training episode 9846
# Time steps: 114, Penalties: 34, Reward: -399
#
# Training episode 9847
# Time steps: 523, Penalties: 182, Reward: -2140
#
# Training episode 9848
# Time steps: 740, Penalties: 215, Reward: -2654
#
# Training episode 9849
# Time steps: 340, Penalties: 117, Reward: -1372
#
# Training episode 9850
# Time steps: 584, Penalties: 180, Reward: -2183
#
# Training episode 9851
# Time steps: 1944, Penalties: 632, Reward: -7611
#
# Training episode 9852
# Time steps: 251, Penalties: 90, Reward: -1040
#
# Training episode 9853
# Time steps: 918, Penalties: 284, Reward: -3453
#
# Training episode 9854
# Time steps: 251, Penalties: 75, Reward: -905
#
# Training episode 9855
# Time steps: 1347, Penalties: 428, Reward: -5178
#
# Training episode 9856
# Time steps: 41, Penalties: 10, Reward: -110
#
# Training episode 9857
# Time steps: 569, Penalties: 184, Reward: -2204
#
# Training episode 9858
# Time steps: 557, Penalties: 191, Reward: -2255
#
# Training episode 9859
# Time steps: 240, Penalties: 76, Reward: -903
#
# Training episode 9860
# Time steps: 1867, Penalties: 625, Reward: -7471
#
# Training episode 9861
# Time steps: 971, Penalties: 326, Reward: -3884
#
# Training episode 9862
# Time steps: 264, Penalties: 81, Reward: -972
#
# Training episode 9863
# Time steps: 1579, Penalties: 512, Reward: -6166
#
# Training episode 9864
# Time steps: 4254, Penalties: 1356, Reward: -16437
#
# Training episode 9865
# Time steps: 88, Penalties: 24, Reward: -283
#
# Training episode 9866
# Time steps: 443, Penalties: 122, Reward: -1520
#
# Training episode 9867
# Time steps: 1577, Penalties: 478, Reward: -5858
#
# Training episode 9868
# Time steps: 1512, Penalties: 494, Reward: -5937
#
# Training episode 9869
# Time steps: 1329, Penalties: 442, Reward: -5286
#
# Training episode 9870
# Time steps: 106, Penalties: 29, Reward: -346
#
# Training episode 9871
# Time steps: 1109, Penalties: 408, Reward: -4760
#
# Training episode 9872
# Time steps: 405, Penalties: 113, Reward: -1401
#
# Training episode 9873
# Time steps: 446, Penalties: 141, Reward: -1694
#
# Training episode 9874
# Time steps: 1853, Penalties: 614, Reward: -7358
#
# Training episode 9875
# Time steps: 147, Penalties: 47, Reward: -549
#
# Training episode 9876
# Time steps: 917, Penalties: 265, Reward: -3281
#
# Training episode 9877
# Time steps: 1166, Penalties: 398, Reward: -4727
#
# Training episode 9878
# Time steps: 1508, Penalties: 492, Reward: -5915
#
# Training episode 9879
# Time steps: 735, Penalties: 209, Reward: -2595
#
# Training episode 9880
# Time steps: 663, Penalties: 220, Reward: -2622
#
# Training episode 9881
# Time steps: 2435, Penalties: 805, Reward: -9659
#
# Training episode 9882
# Time steps: 139, Penalties: 35, Reward: -433
#
# Training episode 9883
# Time steps: 773, Penalties: 222, Reward: -2750
#
# Training episode 9884
# Time steps: 158, Penalties: 49, Reward: -578
#
# Training episode 9885
# Time steps: 1177, Penalties: 387, Reward: -4639
#
# Training episode 9886
# Time steps: 908, Penalties: 300, Reward: -3587
#
# Training episode 9887
# Time steps: 835, Penalties: 288, Reward: -3406
#
# Training episode 9888
# Time steps: 233, Penalties: 72, Reward: -860
#
# Training episode 9889
# Time steps: 392, Penalties: 126, Reward: -1505
#
# Training episode 9890
# Time steps: 1120, Penalties: 367, Reward: -4402
#
# Training episode 9891
# Time steps: 425, Penalties: 117, Reward: -1457
#
# Training episode 9892
# Time steps: 893, Penalties: 282, Reward: -3410
#
# Training episode 9893
# Time steps: 1199, Penalties: 392, Reward: -4706
#
# Training episode 9894
# Time steps: 27, Penalties: 9, Reward: -87
#
# Training episode 9895
# Time steps: 575, Penalties: 202, Reward: -2372
#
# Training episode 9896
# Time steps: 926, Penalties: 323, Reward: -3812
#
# Training episode 9897
# Time steps: 203, Penalties: 64, Reward: -758
#
# Training episode 9898
# Time steps: 561, Penalties: 191, Reward: -2259
#
# Training episode 9899
# Time steps: 1130, Penalties: 372, Reward: -4457
#
# Training episode 9900
# Time steps: 981, Penalties: 309, Reward: -3741
#
# Training episode 9901
# Time steps: 1284, Penalties: 437, Reward: -5196
#
# Training episode 9902
# Time steps: 843, Penalties: 260, Reward: -3162
#
# Training episode 9903
# Time steps: 524, Penalties: 159, Reward: -1934
#
# Training episode 9904
# Time steps: 934, Penalties: 322, Reward: -3811
#
# Training episode 9905
# Time steps: 236, Penalties: 69, Reward: -836
#
# Training episode 9906
# Time steps: 1645, Penalties: 517, Reward: -6277
#
# Training episode 9907
# Time steps: 1210, Penalties: 409, Reward: -4870
#
# Training episode 9908
# Time steps: 201, Penalties: 62, Reward: -738
#
# Training episode 9909
# Time steps: 86, Penalties: 25, Reward: -290
#
# Training episode 9910
# Time steps: 107, Penalties: 29, Reward: -347
#
# Training episode 9911
# Time steps: 2834, Penalties: 932, Reward: -11201
#
# Training episode 9912
# Time steps: 2315, Penalties: 746, Reward: -9008
#
# Training episode 9913
# Time steps: 527, Penalties: 179, Reward: -2117
#
# Training episode 9914
# Time steps: 682, Penalties: 222, Reward: -2659
#
# Training episode 9915
# Time steps: 474, Penalties: 147, Reward: -1776
#
# Training episode 9916
# Time steps: 1715, Penalties: 577, Reward: -6887
#
# Training episode 9917
# Time steps: 147, Penalties: 39, Reward: -477
#
# Training episode 9918
# Time steps: 1756, Penalties: 570, Reward: -6865
#
# Training episode 9919
# Time steps: 12, Penalties: 1, Reward: 0
#
# Training episode 9920
# Time steps: 441, Penalties: 139, Reward: -1671
#
# Training episode 9921
# Time steps: 116, Penalties: 39, Reward: -446
#
# Training episode 9922
# Time steps: 94, Penalties: 32, Reward: -361
#
# Training episode 9923
# Time steps: 676, Penalties: 239, Reward: -2806
#
# Training episode 9924
# Time steps: 633, Penalties: 196, Reward: -2376
#
# Training episode 9925
# Time steps: 340, Penalties: 102, Reward: -1237
#
# Training episode 9926
# Time steps: 1387, Penalties: 437, Reward: -5299
#
# Training episode 9927
# Time steps: 233, Penalties: 78, Reward: -914
#
# Training episode 9928
# Time steps: 393, Penalties: 130, Reward: -1542
#
# Training episode 9929
# Time steps: 1697, Penalties: 555, Reward: -6671
#
# Training episode 9930
# Time steps: 133, Penalties: 39, Reward: -463
#
# Training episode 9931
# Time steps: 1086, Penalties: 367, Reward: -4368
#
# Training episode 9932
# Time steps: 149, Penalties: 51, Reward: -587
#
# Training episode 9933
# Time steps: 302, Penalties: 98, Reward: -1163
#
# Training episode 9934
# Time steps: 1567, Penalties: 519, Reward: -6217
#
# Training episode 9935
# Time steps: 320, Penalties: 112, Reward: -1307
#
# Training episode 9936
# Time steps: 33, Penalties: 7, Reward: -75
#
# Training episode 9937
# Time steps: 192, Penalties: 60, Reward: -711
#
# Training episode 9938
# Time steps: 127, Penalties: 36, Reward: -430
#
# Training episode 9939
# Time steps: 1636, Penalties: 567, Reward: -6718
#
# Training episode 9940
# Time steps: 564, Penalties: 183, Reward: -2190
#
# Training episode 9941
# Time steps: 473, Penalties: 156, Reward: -1856
#
# Training episode 9942
# Time steps: 373, Penalties: 105, Reward: -1297
#
# Training episode 9943
# Time steps: 3790, Penalties: 1201, Reward: -14578
#
# Training episode 9944
# Time steps: 69, Penalties: 11, Reward: -147
#
# Training episode 9945
# Time steps: 1501, Penalties: 509, Reward: -6061
#
# Training episode 9946
# Time steps: 2345, Penalties: 778, Reward: -9326
#
# Training episode 9947
# Time steps: 1120, Penalties: 340, Reward: -4159
#
# Training episode 9948
# Time steps: 60, Penalties: 19, Reward: -210
#
# Training episode 9949
# Time steps: 96, Penalties: 25, Reward: -300
#
# Training episode 9950
# Time steps: 227, Penalties: 68, Reward: -818
#
# Training episode 9951
# Time steps: 135, Penalties: 35, Reward: -429
#
# Training episode 9952
# Time steps: 443, Penalties: 141, Reward: -1691
#
# Training episode 9953
# Time steps: 1089, Penalties: 380, Reward: -4488
#
# Training episode 9954
# Time steps: 688, Penalties: 213, Reward: -2584
#
# Training episode 9955
# Time steps: 777, Penalties: 251, Reward: -3015
#
# Training episode 9956
# Time steps: 151, Penalties: 36, Reward: -454
#
# Training episode 9957
# Time steps: 342, Penalties: 113, Reward: -1338
#
# Training episode 9958
# Time steps: 1081, Penalties: 348, Reward: -4192
#
# Training episode 9959
# Time steps: 1318, Penalties: 432, Reward: -5185
#
# Training episode 9960
# Time steps: 1084, Penalties: 342, Reward: -4141
#
# Training episode 9961
# Time steps: 5062, Penalties: 1608, Reward: -19513
#
# Training episode 9962
# Time steps: 277, Penalties: 91, Reward: -1075
#
# Training episode 9963
# Time steps: 837, Penalties: 275, Reward: -3291
#
# Training episode 9964
# Time steps: 95, Penalties: 16, Reward: -218
#
# Training episode 9965
# Time steps: 103, Penalties: 25, Reward: -307
#
# Training episode 9966
# Time steps: 102, Penalties: 34, Reward: -387
#
# Training episode 9967
# Time steps: 595, Penalties: 207, Reward: -2437
#
# Training episode 9968
# Time steps: 684, Penalties: 242, Reward: -2841
#
# Training episode 9969
# Time steps: 788, Penalties: 281, Reward: -3296
#
# Training episode 9970
# Time steps: 1827, Penalties: 610, Reward: -7296
#
# Training episode 9971
# Time steps: 252, Penalties: 87, Reward: -1014
#
# Training episode 9972
# Time steps: 661, Penalties: 210, Reward: -2530
#
# Training episode 9973
# Time steps: 4511, Penalties: 1475, Reward: -17765
#
# Training episode 9974
# Time steps: 453, Penalties: 139, Reward: -1683
#
# Training episode 9975
# Time steps: 1272, Penalties: 388, Reward: -4743
#
# Training episode 9976
# Time steps: 353, Penalties: 125, Reward: -1457
#
# Training episode 9977
# Time steps: 828, Penalties: 279, Reward: -3318
#
# Training episode 9978
# Time steps: 692, Penalties: 223, Reward: -2678
#
# Training episode 9979
# Time steps: 216, Penalties: 79, Reward: -906
#
# Training episode 9980
# Time steps: 29, Penalties: 6, Reward: -62
#
# Training episode 9981
# Time steps: 566, Penalties: 182, Reward: -2183
#
# Training episode 9982
# Time steps: 3382, Penalties: 1088, Reward: -13153
#
# Training episode 9983
# Time steps: 1401, Penalties: 483, Reward: -5727
#
# Training episode 9984
# Time steps: 380, Penalties: 113, Reward: -1376
#
# Training episode 9985
# Time steps: 737, Penalties: 260, Reward: -3056
#
# Training episode 9986
# Time steps: 318, Penalties: 109, Reward: -1278
#
# Training episode 9987
# Time steps: 289, Penalties: 94, Reward: -1114
#
# Training episode 9988
# Time steps: 1899, Penalties: 635, Reward: -7593
#
# Training episode 9989
# Time steps: 426, Penalties: 134, Reward: -1611
#
# Training episode 9990
# Time steps: 1194, Penalties: 384, Reward: -4629
#
# Training episode 9991
# Time steps: 1137, Penalties: 400, Reward: -4716
#
# Training episode 9992
# Time steps: 1644, Penalties: 501, Reward: -6132
#
# Training episode 9993
# Time steps: 526, Penalties: 175, Reward: -2080
#
# Training episode 9994
# Time steps: 112, Penalties: 33, Reward: -388
#
# Training episode 9995
# Time steps: 995, Penalties: 320, Reward: -3854
#
# Training episode 9996
# Time steps: 838, Penalties: 271, Reward: -3256
#
# Training episode 9997
# Time steps: 1898, Penalties: 632, Reward: -7565
#
# Training episode 9998
# Time steps: 24, Penalties: 2, Reward: -21
#
# Training episode 9999
# Time steps: 381, Penalties: 138, Reward: -1602
#
# Training episode 10000
# Time steps: 2667, Penalties: 824, Reward: -10062
# Training finished.
